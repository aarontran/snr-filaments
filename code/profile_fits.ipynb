# %% [markdown]
# # Profile fits and stuff

# %%
# %pylab --no-import-all
# %matplotlib inline
# ('gtk', 'inline', 'osx', 'qt', 'qt4', 'tk', 'wx')
from fplot import fplot, show_mplrc_settings

import os
import re
import scipy as sp
from scipy import optimize
from scipy import signal  # LAZINESS
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
show_mplrc_settings()
# Out:
# Using /Users/atran3/snr-research/code/matplotlibrc
# Font sizes for axes: 9; (x,y) ticks: (9, 9): legend 9
# Font family serif uses face ['Times']
# Figure size: (6.0, 4.0), dpi: 80

# %% [markdown]
# ## Utility methods (for main method -- maybe useful for a small library/module)

# %% [markdown]
# For loading regions, getting information about regions

# %%
def count_files_regexp(stem):
    """Number of grouped spectra with given directory stem"""
    pattern = os.path.basename(stem)
    if os.path.dirname(stem) == '':
        files = [f for f in os.listdir('.') if re.match(pattern,f)]
    else:
        files = [f for f in os.listdir(os.path.dirname(stem))
                 if re.match(pattern, f)]
    return len(files)


def load_check_file(fname):
    """Returns list of region strings for ds9 region, with headers checked for correctness"""
    with open(fname, 'r') as f:
        header = f.readline()
        settings = f.readline()
        coordsys = f.readline()
        if 'DS9 version 4.1' not in header:
            print 'WARNING: potentially invalid region file'
            print 'First line was: {}'.format(header)
        if 'physical' not in coordsys:
            raise Exception('Invalid coordinate system: {}'.format(coordsys))
        regstrs = list(f)
    return regstrs


def parse_regstr(regstr):
    """Break a region specification into pieces.
    Returns three items: rtype (str), rnums (list of floats), rprops (str)"""
    rtype, rnums, rprops = re.split('[\(\)]', regstr)  # This assumes there are no other parentheses floating around...
    rnums = [float(x) for x in re.split('\s*,\s*', rnums)]   # Could improve by only matching first set of parentheses
    return rtype, rnums, rprops


def get_proj_dims(regstrs):
    """Get projection dimensions from list of regions, must all be projections
    Input: list of region strings
    Output: list of 2-tuples
        1st element is length (radial distance)
        2nd element is thickness (dist. along which projection integrates)
        
    WARNING: DIMENSIONS ARE NOT THE SAME.  Length is in arcsec., thickness is in PIXELS / PHYSICAL UNITS.
    """
    pixel2arcsec = 0.5  # Chandra spatial resolution
    
    dims = []
    for line in regstrs:
        rtype, rnums, rprops = parse_regstr(line)
        if 'projection' not in rtype:
            print 'WARNING: region not of type projection encountered'
            print 'Type was: {}'.format(rtype)
        x1,y1,x2,y2,w = rnums
        length = np.sqrt((x2-x1)**2 + (y2-y1)**2) * pixel2arcsec
        dims.append((length, w))
    
    return dims

# %% [markdown]
# ## Individual profile work (i.e., fit/describe rims in each band)

# %% [markdown]
# ### Fitting functions

# %% [markdown]
# First, we need a profile function.  _Ressler et al._ [2014, _in press_] used a piecewise function to fit the upstream and downstream sides of the rim profiles:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right)
#                           + B \exp \left( \frac{-(x-x_1)^2}{2\pi \sigma^2} \right)
#                           + C_d
# \end{align*}
#
# Some outstanding questions -- how do you decide the location of up/down-stream?  Is this part of the fitting procedure?
# The peak intensity may be located at either $x_0$ or $x_1$ -- okay, seems physically reasonable given projection effects.  But how to decide where to split the fit.
#
# I first try a continuous piecewise two exponential function of form:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right) + C_d
# \end{align*}
#
# where the upstream/downstream split occurs at $x=x_s$ and $x_s$ is used as a fit parameter instead of $A_u$.  Once $x_s$ is determined, $A_u$ is constrained to be:
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_0}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_0}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# Alternately we may constrain $A_d$ and use $A_u$ as a fit parameter:
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_0 - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_0 - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %% [markdown]
# I could also let one more parameter run free in the two exponential function:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_u-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_d}{w_d}\right) + C_d
# \end{align*}
#
# Again, $x=x_s$ is a fit parameter for the upstream/downstream split, which can be used in place of $A_u$ or $A_d$.
# Because the upstream side is generally easier to fit / the data is better, it's probably better to pin $A_d$ and let $A_u$ be a free fit parameter.
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_u}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_d}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_d - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_u - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %% [markdown]
# A cookbook on curve fitting with SciPy: [wiki.scipy.org/Cookbook/FittingData](http://wiki.scipy.org/Cookbook/FittingData).
#
# And, signal smoothing (maybe useful for peak/trough identification): [wiki.scipy.org/Cookbook/SignalSmooth](http://wiki.scipy.org/Cookbook/SignalSmooth).

# %%
def two_exp_function(x, xs, x0, wu, Cu, Ad, wd, Cd):
    """Two exponential profile function, with the upstream amplitude Au set by the split xs"""
    
    Au = two_exp_function_Au(xs, x0, wu, Cu, Ad, wd, Cd)
    
    if x > xs:  # Upstream, ahead of shock
        return Au * np.exp((x0-x)/wu) + Cu
    else:
        return Ad * np.exp((x-x0)/wd) + Cd


def two_exp_function_Au(xs, x0, wu, Cu, Ad, wd, Cd):
    """Value of Au set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xs-x0)/wu) * ( Ad * np.exp((xs-x0)/wd) + Cd - Cu )


def ressler_function(x, Au, x0, wu, Cu, xs, Ad, wd, B, x1, sigma, Cd):
    """Big fat piecewise function with a million parameters to try fitting.
    Note -- the functions should be piecewise continuous -- a constraint that has to be enforced!
    Inputs (all floats):
        x = radial position (arcsec.)
        Au, x0, wu, Cu = parameters for upstream function
        xs = location of upstream/downstream divide
        Ad, wd, B, x1, sigma, Cd = parameters for downstream function
    Output (float): value of function at radial position x
    """
    if x > xs:  # Upstream, ahead of shock
        return Au * np.exp((x0-x)/wu) + Cu
    else:
        return Ad * np.exp((x-x0)/wd) + B * np.exp( -(x-x1)**2 / (2*np.pi*sigma**2)) + Cd

# %% [markdown]
# ### Data manipulation (smooth profiles to identify minima/maxima for initial guesses, fit domain)

# %%
def ind_first_smoothed_min(y):
    """Smooths data and returns index of first minimum to left of global max, in smoothed data"""
    inds = sp.signal.argrelmin(std_smooth(y))[0]  # Unpack the tuple...
    if len(inds) is 0:
        return -1
    ind_max = ind_smoothed_max(y)
    return inds[np.searchsorted(inds, ind_max) - 1]


def ind_smoothed_max(y):
    """Smooths data and returns index of global maximum in smoothed data"""
    ysmooth = std_smooth(y)
    # Get indices of relative maxima
    inds_relmax = sp.signal.argrelmax(ysmooth)[0]  # Unpack the tuple...
    # Get index of the largest relative maximum
    best_ind = inds_relmax[0]
    for ind in inds_relmax[1:]:
        if ysmooth[best_ind] < ysmooth[ind]:
            best_ind = ind
    return best_ind


def std_smooth(x):
    """Standardized smoothing"""
    wlen = 15  # Arbitrary pick
    xsmooth = smooth(x, window_len=wlen, window='hanning')
    padlen = (len(xsmooth) - len(x))/2  # Should be an integer
    return xsmooth[padlen:-padlen]


def smooth(x,window_len=11,window='hanning'):
    """stolen from scipy cookbook (reimplement whatever later)"""
    if window_len < 3:
        return x
    if not window in ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']:
        raise ValueError, "Window is on of 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'"
    
    s = numpy.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    if window == 'flat': #moving average
        w = numpy.ones(window_len,'d')
    else:
        w = eval('numpy.{}(window_len)'.format(window))
    
    y=numpy.convolve(w/w.sum(), s, mode='valid')
    return y

# %% [markdown]
# ## Region work (i.e., assess energy dependence of FWHMs)

# %% [markdown]
# ## Main method

# %% [markdown]
# Structure of a region dict:
#
#     region = {'red': {},
#               'green': {},
#               'blue': {}}
#
# So that I can get useful information by, e.g., calling:
#
#     region['red']['r']  # Radial distance (units?)
#     region['green']['i']  # Intensity (units?)
#     region['blue']['fwhm']  # FWHM value (same units as radial distance)
#
# This script (as well as `ds9projplotter.py`) will need to be updated later if we are to try different energy bands.
# In principle I could deduce the bands from the filenames...

# %% [markdown]
# Roughly speaking:
# * 1 blue count <--> 5e-9 intensity units
# * 1 green count <--> 2.8e-9 intensity units
# * 1 red count <--> 8e-9 intensity units (wat? -- this makes no sense, ask Brian what's going on)

# %%
ds9physreg = '../data/regions-good-3-allback.physreg'
inroot = '../data/profiles/good-3-allback/prf'

# Count number of regions
n_regions = count_files_regexp(inroot + r'_[0-9]+_blue\.dat')

# Get radial lengths of each region (convert physical pixels to arcseconds)
dims = get_proj_dims(load_check_file(ds9physreg))

# For estimating errors on data (x errors I have no idea...?????)
flux2ct_red = 1./(8e-9)  # ?!?!?!?!?!?!?!?!?!?!?!?!?!?!
flux2ct_green = 1./(2.8e-9)
flux2ct_blue = 1./(5e-9)


# Process and store information on each region
for i in xrange(n_regions):
    
    region = {}
    length, thickness = dims[i]  # length is in arcsec., thickness is in PIXELS...!
    thickness = np.floor(thickness)  # Apply floor, following what DS9 does
    
    f, (ax_red, ax_green, ax_blue) = plt.subplots(1,3, figsize=(15,5))
    
    for clr in ['red', 'green', 'blue']:
        # Set-up for each energy band
        region[clr] = {}
        ax = eval('ax_{}'.format(clr))
        
        # Import projection data
        infile = '{0}_{1:02d}_{2}.dat'.format(inroot, i+1, clr)
        if not os.path.isfile(infile):
            print 'BAD PATH: {}'.format(infile)
            raise Exception('Bad path')
        print infile
        data = np.loadtxt(infile)
        x = region[clr]['r'] = (data[:,0] - 1) * length / (len(data[:,0]) - 1)
        y = region[clr]['i'] = data[:,1] * eval('flux2ct_{}'.format(clr))
        
        flux2ct = eval('flux2ct_{}'.format(clr))
        # y_err = 1./flux2ct * np.sqrt( y * flux2ct / thickness)
        y_err = np.sqrt( y / thickness)
        
        ################################
        # Apply fit to profiles and save
        # fit parameters/errors/chi^2
        ################################
        
        # RESTRICT THE FIT DOMAIN...
        leftcut = ind_first_smoothed_min(y)
        print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
        print 'Global smoothed maximum at: {}'.format(x[ind_smoothed_max(y)])
        x_fit = x[leftcut:]
        y_fit = y[leftcut:]
        y_err_fit = y_err[leftcut:]
        
        # FIRST FIT ATTEMPT (freeze xs, x0, Cu, Cd; supply ad hoc initial guesses)
        xs_fr = x[ind_smoothed_max(y)] + 0.5
        x0_fr = xs_fr + 1.
        Cu_fr = np.mean(y_fit[-3:])
        Cd_fr = np.mean(y_fit[:3]) / 2.  # Because it usually shoots under the trough
        
        # two_exp_function(x, xs, x0, wu, Cu, Ad, wd, Cd)
        fit_func = np.vectorize(lambda xval, x0,wu,Ad,wd: two_exp_function(xval, xs_fr,x0,wu,Cu_fr,Ad,wd,Cd_fr))
        # [xs, x0, wu, Cu, Ad, wd, Cd]
        init_guesses = [xs_fr + 1.,          # x0 = exponential location???
                        0.5,                # wu = upstream width
                        np.amax(y_fit)*4,   # Ad = downstream amplitude
                        2.5]                # wd = downstream width
        popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guesses, sigma=y_err_fit, absolute_sigma=True)
        print ('{} fit (xs frozen): xs = {:5.4g}, x0 = {:5.4g}, wu = {:5.4g}, Cu = {:5.4g}, '
               'Ad = {:5.4g}, wd = {:5.4g}, Cd = {:5.4g}').format(clr, xs_fr, popt[0], popt[1], Cu_fr, popt[2], popt[3], Cd_fr)
        
        # SECOND FIT (unfreeze xs, use values from last fit as initial guesses)
        fit_func = np.vectorize(two_exp_function)
        init_guesses = np.insert(popt, [0,2,4], [xs_fr, Cu_fr, Cd_fr])
        popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guesses, sigma=y_err_fit, absolute_sigma=True)
        print ('{} fit (xs thawed): xs = {:5.4g}, x0 = {:5.4g}, wu = {:5.4g}, Cu = {:5.4g}, '
               'Ad = {:5.4g}, wd = {:5.4g}, Cd = {:5.4g}').format(clr, *popt)
        print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
        
        # GIVE FIT PARAMETERS
        chi2 = np.sum(((y - fit_func(x, *popt)) / y_err)**2)
        chi2red = chi2 / (len(y) - 7)
        print 'Reduced chi-squared: {}'.format(chi2red)
        
        print 'Covariance matrix, variables: ' + str(['xs','x0','wu','Cu','Ad','wd','Cd'])
        np.set_printoptions(precision=1)
        print pcov
        print ''
        
        ################################
        # Calculate FWHM
        # Calculate uncertainty in FWHM
        ################################
        
        ################################
        # Plot the data and fits
        ################################
        # Data NOT used in fit
        ax.errorbar(x[:leftcut], y[:leftcut], yerr=y_err[:leftcut], fmt='{}x'.format(clr[0]), alpha=0.4)
        # Data used in fit
        ax.errorbar(x_fit, y_fit, yerr=y_err_fit, fmt='{}o'.format(clr[0]), alpha=0.7)
        # Smoothed line to visualize fit cutoffs/guesses
        ax.plot(x, std_smooth(y), '-y', alpha = 0.4)
        # Best fit model
        x_m = np.linspace(x[0], x[-1], num=200)
        ax.plot(x_m, fit_func(x_m, *popt), '-k', alpha=0.7)
    
    plt.show()
    print ''
    
    # Do stuff to estimate FWHM dependence

# Compute average values of FWHM-energy scaling
# Out:
# ../data/profiles/good-3-allback/prf_01_red.dat
# Left-of-peak smoothed minimum at: 16.6547773303
# Global smoothed maximum at: 21.1969893294
# red fit (xs frozen): xs =  21.7, x0 = 22.41, wu = 1.306, Cu = 0.3786, Ad = 5.357, wd =   2.5, Cd = 0.7793
# red fit (xs thawed): xs = 22.07, x0 = 22.77, wu = 0.9844, Cu = 0.3991, Ad = 5.567, wd = 1.916, Cd = 1.311
# Errors: [  1.2e-01   8.2e+06   1.1e-01   2.8e-02   2.4e+07   7.3e-01   3.8e-01]
# Reduced chi-squared: 4.55304875865
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.5e-02   2.5e+05  -5.7e-03   2.9e-04   7.2e+05   4.8e-02  -2.0e-02]
#  [  2.5e+05   6.7e+13  -1.1e+05   9.2e+03   1.9e+14  -1.1e+06   2.6e+05]
#  [ -5.7e-03  -1.1e+05   1.2e-02  -1.0e-03  -3.2e+05   1.9e-03  -4.3e-04]
#  [  2.9e-04   9.2e+03  -1.0e-03   7.8e-04   2.7e+04  -1.6e-04   3.6e-05]
#  [  7.2e+05   1.9e+14  -3.2e+05   2.7e+04   5.6e+14  -3.3e+06   7.5e+05]
#  [  4.8e-02  -1.1e+06   1.9e-03  -1.6e-04  -3.3e+06   5.3e-01  -2.6e-01]
#  [ -2.0e-02   2.6e+05  -4.3e-04   3.6e-05   7.5e+05  -2.6e-01   1.5e-01]]
#
# ../data/profiles/good-3-allback/prf_01_green.dat
# Left-of-peak smoothed minimum at: 15.1407066639
# Global smoothed maximum at: 21.7016795515
# green fit (xs frozen): xs =  22.2, x0 = 22.17, wu = 0.9216, Cu = 1.442, Ad = 41.78, wd = 2.683, Cd = 5.432
# green fit (xs thawed): xs = 22.15, x0 = 22.09, wu = 0.9035, Cu =  1.51, Ad = 40.62, wd =  1.83, Cd = 9.558
# Errors: [  3.0e-02   1.8e+06   2.5e-02   5.5e-02   4.0e+07   1.4e-01   5.8e-01]
# Reduced chi-squared: 19.6735531065
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  9.3e-04   8.7e+02  -2.6e-04   9.3e-05   1.9e+04   2.7e-03  -7.7e-03]
#  [  8.7e+02   3.2e+12  -8.6e+03   3.7e+03   7.1e+13   9.1e+03   2.6e+03]
#  [ -2.6e-04  -8.6e+03   6.1e-04  -4.3e-04  -1.9e+05  -2.4e-05  -7.0e-06]
#  [  9.3e-05   3.7e+03  -4.3e-04   3.1e-03   8.1e+04   1.0e-05   3.0e-06]
#  [  1.9e+04   7.1e+13  -1.9e+05   8.1e+04   1.6e+15   2.0e+05   5.8e+04]
#  [  2.7e-03   9.1e+03  -2.4e-05   1.0e-05   2.0e+05   1.9e-02  -6.8e-02]
#  [ -7.7e-03   2.6e+03  -7.0e-06   3.0e-06   5.8e+04  -6.8e-02   3.4e-01]]
#
# ../data/profiles/good-3-allback/prf_01_blue.dat
# Left-of-peak smoothed minimum at: 15.1407066639
# Global smoothed maximum at: 21.7016795515
# blue fit (xs frozen): xs =  22.2, x0 = 223.5, wu = 2.594, Cu = 0.6099, Ad =  6750, wd = 2.446, Cd = 2.271
# blue fit (xs thawed): xs =  22.2, x0 = 90.82, wu = 2.594, Cu = 0.6099, Ad =  6750, wd = 2.446, Cd = 2.271
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 50.2809384893
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_02_red.dat
# Left-of-peak smoothed minimum at: 6.60070483814
# Global smoothed maximum at: 9.13943746819
# red fit (xs frozen): xs = 9.639, x0 = 265.8, wu =  2.23, Cu = 0.4808, Ad =  1421, wd = 2.916, Cd = 1.294
# red fit (xs thawed): xs = 9.639, x0 = 265.8, wu =  2.23, Cu = 0.4808, Ad =  1421, wd = 2.916, Cd = 1.294
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 12.7617122126
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_02_green.dat
# Left-of-peak smoothed minimum at: 5.58521178612
# Global smoothed maximum at: 9.13943746819
# green fit (xs frozen): xs = 9.639, x0 =  26.7, wu = 1.246, Cu = 1.226, Ad = 1.335e+04, wd = 2.726, Cd = 8.165
# green fit (xs thawed): xs = 10.51, x0 = 30.54, wu = 0.7102, Cu = 1.537, Ad =  1800, wd = 4.779, Cd = 5.285
# Errors: [  4.3e-02   3.9e+06   2.8e-02   4.4e-02   1.5e+09   2.1e+00   7.0e+00]
# Reduced chi-squared: 33.3313463825
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.8e-03  -9.0e+04  -5.4e-04   1.2e-04  -3.4e+07   4.3e-02  -1.2e-01]
#  [ -9.0e+04   1.6e+13   8.1e+03  -3.8e+03   5.8e+15  -9.7e+04  -5.4e+05]
#  [ -5.4e-04   8.1e+03   8.1e-04  -3.1e-04   3.0e+06  -5.0e-05  -2.8e-04]
#  [  1.2e-04  -3.8e+03  -3.1e-04   1.9e-03  -1.4e+06   2.4e-05   1.3e-04]
#  [ -3.4e+07   5.8e+15   3.0e+06  -1.4e+06   2.2e+18  -3.6e+07  -2.0e+08]
#  [  4.3e-02  -9.7e+04  -5.0e-05   2.4e-05  -3.6e+07   4.5e+00  -1.5e+01]
#  [ -1.2e-01  -5.4e+05  -2.8e-04   1.3e-04  -2.0e+08  -1.5e+01   5.0e+01]]
#
# ../data/profiles/good-3-allback/prf_02_blue.dat
# Left-of-peak smoothed minimum at: 4.5697187341
# Global smoothed maximum at: 9.13943746819
# blue fit (xs frozen): xs = 9.639, x0 = 272.5, wu = 2.531, Cu = 0.499, Ad =  7109, wd = 2.644, Cd = 3.461
# blue fit (xs thawed): xs = 9.639, x0 =  1175, wu = 2.531, Cu = 0.499, Ad =  7109, wd = 2.644, Cd = 3.461
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 52.1153361425
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_03_red.dat
# Left-of-peak smoothed minimum at: 4.02618960859
# Global smoothed maximum at: 7.54910551611
# red fit (xs frozen): xs = 8.049, x0 = 8.502, wu = 1.067, Cu = 0.6719, Ad =  4.68, wd = 2.834, Cd = 1.286
# red fit (xs thawed): xs = 8.809, x0 =  10.5, wu = 0.7051, Cu = 0.5069, Ad = 6.495, wd = 3.116, Cd = 1.629
# Errors: [ 0.1  nan  0.1  0.   nan  2.4  1.4]
# Reduced chi-squared: 3.62986407632
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.0e-02  -6.0e+05  -5.5e-03   6.8e-05  -1.2e+06   1.0e-01  -4.9e-02]
#  [ -6.0e+05  -1.7e+14   3.2e+05  -5.7e+04  -3.5e+14  -7.2e+06   3.6e+06]
#  [ -5.5e-03   3.2e+05   9.6e-03  -6.1e-04   6.7e+05   1.4e-02  -6.8e-03]
#  [  6.8e-05  -5.7e+04  -6.1e-04   7.3e-04  -1.2e+05  -2.4e-03   1.2e-03]
#  [ -1.2e+06  -3.5e+14   6.7e+05  -1.2e+05  -7.3e+14  -1.5e+07   7.4e+06]
#  [  1.0e-01  -7.2e+06   1.4e-02  -2.4e-03  -1.5e+07   5.9e+00  -3.3e+00]
#  [ -4.9e-02   3.6e+06  -6.8e-03   1.2e-03   7.4e+06  -3.3e+00   1.9e+00]]
#
# ../data/profiles/good-3-allback/prf_03_green.dat
# Left-of-peak smoothed minimum at: 4.02618960859
# Global smoothed maximum at: 8.05237921718
# green fit (xs frozen): xs = 8.552, x0 = 244.3, wu =  2.75, Cu = 1.656, Ad = 1.593e+04, wd = 2.533, Cd = 7.378
# green fit (xs thawed): xs = 8.552, x0 = 244.3, wu =  2.75, Cu = 1.656, Ad = 1.593e+04, wd = 2.533, Cd = 7.378
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 109.545637871
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_03_blue.dat
# Left-of-peak smoothed minimum at: 4.02618960859
# Global smoothed maximum at: 8.05237921718
# blue fit (xs frozen): xs = 8.552, x0 = 276.2, wu = 3.124, Cu = 0.5499, Ad =  7832, wd =  2.37, Cd = 2.506
# blue fit (xs thawed): xs = 8.552, x0 = 276.2, wu = 3.124, Cu = 0.5499, Ad =  7832, wd =  2.37, Cd = 2.506
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 54.9938824172
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_04_red.dat
# Left-of-peak smoothed minimum at: 5.03894668563
# Global smoothed maximum at: 12.0934720455
# red fit (xs frozen): xs = 12.59, x0 = 14.16, wu = 1.466, Cu = 0.4376, Ad = 13.33, wd =  2.96, Cd = 1.546
# red fit (xs thawed): xs = 12.64, x0 = 12.79, wu = 1.284, Cu = 0.4195, Ad = 9.122, wd = 1.204, Cd = 3.156
# Errors: [  4.7e-02   1.4e+06   5.6e-02   1.6e-02   1.1e+07   9.8e-02   9.8e-02]
# Reduced chi-squared: 3.82837398045
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  2.2e-03   1.3e+04  -1.8e-03   1.1e-04   1.0e+05   1.5e-03  -4.9e-04]
#  [  1.3e+04   2.1e+12  -1.3e+04   9.4e+02   1.6e+13  -1.6e+04   1.6e+04]
#  [ -1.8e-03  -1.3e+04   3.2e-03  -3.0e-04  -1.0e+05   1.1e-04  -1.0e-04]
#  [  1.1e-04   9.4e+02  -3.0e-04   2.6e-04   7.1e+03  -7.5e-06   7.2e-06]
#  [  1.0e+05   1.6e+13  -1.0e+05   7.1e+03   1.2e+14  -1.2e+05   1.2e+05]
#  [  1.5e-03  -1.6e+04   1.1e-04  -7.5e-06  -1.2e+05   9.6e-03  -6.2e-03]
#  [ -4.9e-04   1.6e+04  -1.0e-04   7.2e-06   1.2e+05  -6.2e-03   9.6e-03]]
#
# ../data/profiles/good-3-allback/prf_04_green.dat
# Left-of-peak smoothed minimum at: 4.53505201707
# Global smoothed maximum at: 12.5973667141
# green fit (xs frozen): xs =  13.1, x0 = 386.9, wu = 4.631, Cu = 1.172, Ad = 4.46e+04, wd = 2.569, Cd = 6.171
# green fit (xs thawed): xs =  13.1, x0 = 386.9, wu = 4.631, Cu = 1.172, Ad = 4.46e+04, wd = 2.569, Cd = 6.171
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 464.894499424
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_04_blue.dat
# Left-of-peak smoothed minimum at: 5.03894668563
# Global smoothed maximum at: 12.5973667141
# blue fit (xs frozen): xs =  13.1, x0 =   366, wu = 4.795, Cu = 0.3977, Ad = 1.976e+04, wd = 2.436, Cd =  2.12
# blue fit (xs thawed): xs =  13.1, x0 =   366, wu = 4.795, Cu = 0.3977, Ad = 1.976e+04, wd = 2.436, Cd =  2.12
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 202.744478331
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_05_red.dat
# Left-of-peak smoothed minimum at: 3.50596027705
# Global smoothed maximum at: 7.51277202224
# red fit (xs frozen): xs = 8.013, x0 = 9.013, wu =   0.5, Cu = 0.4875, Ad =  16.5, wd =   2.5, Cd = 0.7261
# red fit (xs thawed): xs = 8.013, x0 = 9.013, wu =   0.5, Cu = 0.4875, Ad =  16.5, wd =   2.5, Cd = 0.7261
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: inf
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_05_green.dat
# Left-of-peak smoothed minimum at: 3.0051088089
# Global smoothed maximum at: 7.51277202224
# green fit (xs frozen): xs = 8.013, x0 = 270.2, wu = 3.025, Cu = 1.295, Ad = 1.002e+04, wd = 2.627, Cd =  4.74
# green fit (xs thawed): xs = 8.013, x0 = 270.2, wu = 3.025, Cu = 1.295, Ad = 1.002e+04, wd = 2.627, Cd =  4.74
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 55.2455203405
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_05_blue.dat
# Left-of-peak smoothed minimum at: 3.50596027705
# Global smoothed maximum at: 8.01362349039
# blue fit (xs frozen): xs = 8.514, x0 = 249.3, wu = 2.057, Cu = 0.5494, Ad =  4878, wd = 2.483, Cd = 1.629
# blue fit (xs thawed): xs = 8.514, x0 = 249.3, wu = 2.057, Cu = 0.5494, Ad =  4878, wd = 2.483, Cd = 1.629
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 28.5724871948
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_06_red.dat
# Left-of-peak smoothed minimum at: 10.0890149042
# Global smoothed maximum at: 15.6379731015
# red fit (xs frozen): xs = 16.14, x0 = 20.99, wu = 1.499, Cu = 0.3532, Ad = 11.07, wd = 3.863, Cd = 0.8724
# red fit (xs thawed): xs = 17.45, x0 = 25.87, wu = 0.5624, Cu = 0.3983, Ad = 18.11, wd = 4.985, Cd = 0.889
# Errors: [  1.1e-01   2.1e+07   9.8e-02   2.7e-02   7.8e+07   3.3e+00   1.0e+00]
# Reduced chi-squared: 5.4285633305
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.1e-02  -7.4e+05  -6.5e-03   2.7e-04  -2.7e+06   1.4e-01  -3.8e-02]
#  [ -7.4e+05   4.6e+14   8.6e+04  -1.6e+03   1.7e+15  -8.5e+06   2.3e+06]
#  [ -6.5e-03   8.6e+04   9.5e-03  -6.8e-04   3.1e+05  -1.6e-03   4.3e-04]
#  [  2.7e-04  -1.6e+03  -6.8e-04   7.3e-04  -5.9e+03   3.0e-05  -8.1e-06]
#  [ -2.7e+06   1.7e+15   3.1e+05  -5.9e+03   6.1e+15  -3.1e+07   8.3e+06]
#  [  1.4e-01  -8.5e+06  -1.6e-03   3.0e-05  -3.1e+07   1.1e+01  -3.4e+00]
#  [ -3.8e-02   2.3e+06   4.3e-04  -8.1e-06   8.3e+06  -3.4e+00   1.1e+00]]
#
# ../data/profiles/good-3-allback/prf_06_green.dat
# Left-of-peak smoothed minimum at: 10.5934656494
# Global smoothed maximum at: 16.1424238467
# green fit (xs frozen): xs = 16.64, x0 = 441.2, wu = 4.131, Cu = 1.324, Ad = 2.326e+04, wd = 2.459, Cd = 3.732
# green fit (xs thawed): xs = 16.64, x0 = 441.2, wu = 4.131, Cu = 1.324, Ad = 2.326e+04, wd = 2.459, Cd = 3.732
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 120.886311254
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_06_blue.dat
# Left-of-peak smoothed minimum at: 10.5934656494
# Global smoothed maximum at: 16.1424238467
# blue fit (xs frozen): xs = 16.64, x0 = 480.5, wu = 4.593, Cu = 0.4007, Ad = 1.125e+04, wd = 2.254, Cd = 1.231
# blue fit (xs thawed): xs = 16.64, x0 = 480.5, wu = 4.593, Cu = 0.4007, Ad = 1.125e+04, wd = 2.254, Cd = 1.231
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 54.0165164932
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_07_red.dat
# Left-of-peak smoothed minimum at: 5.50611110268
# Global smoothed maximum at: 16.0177777532
# red fit (xs frozen): xs = 16.52, x0 = 17.52, wu =   0.5, Cu = 0.2911, Ad = 13.64, wd =   2.5, Cd = 0.7255
# red fit (xs thawed): xs = 16.52, x0 = 17.52, wu =   0.5, Cu = 0.2911, Ad = 13.64, wd =   2.5, Cd = 0.7255
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: inf
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_07_green.dat
# Left-of-peak smoothed minimum at: 5.00555554789
# Global smoothed maximum at: 17.5194444176
# green fit (xs frozen): xs = 18.02, x0 = 716.3, wu = 3.813, Cu = 1.052, Ad = 1.787e+04, wd = 3.815, Cd = 4.128
# green fit (xs thawed): xs = 18.02, x0 = 716.3, wu = 3.813, Cu = 1.052, Ad = 1.787e+04, wd = 3.815, Cd = 4.128
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 91.0493316102
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_07_blue.dat
# Left-of-peak smoothed minimum at: 5.50611110268
# Global smoothed maximum at: 17.5194444176
# blue fit (xs frozen): xs = 18.02, x0 = 459.5, wu = 3.215, Cu = 0.5168, Ad =  7939, wd = 3.651, Cd = 1.905
# blue fit (xs thawed): xs = 18.02, x0 = 459.5, wu = 3.215, Cu = 0.5168, Ad =  7939, wd = 3.651, Cd = 1.905
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 38.6921126972
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_08_red.dat
# Left-of-peak smoothed minimum at: 4.05879286524
# Global smoothed maximum at: 9.1322839468
# red fit (xs frozen): xs = 9.632, x0 = 17.53, wu = 1.428, Cu = 0.3465, Ad = 18.47, wd = 4.241, Cd = 1.247
# red fit (xs thawed): xs = 10.39, x0 = 16.02, wu = 0.944, Cu = 0.3392, Ad = 36.76, wd = 1.895, Cd = 2.334
# Errors: [  1.9e-01   1.6e+07   1.2e-01   2.1e-02   3.1e+08   1.1e+00   3.0e-01]
# Reduced chi-squared: 2.07043988805
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  3.8e-02  -2.3e+06  -1.2e-02   3.5e-04  -4.5e+07   1.2e-01  -3.0e-02]
#  [ -2.3e+06   2.5e+14   4.1e+05  -9.3e+03   4.8e+15  -5.7e+06   2.1e+06]
#  [ -1.2e-02   4.1e+05   1.4e-02  -7.5e-04   8.0e+06  -9.5e-03   3.4e-03]
#  [  3.5e-04  -9.3e+03  -7.5e-04   4.5e-04  -1.8e+05   2.2e-04  -7.8e-05]
#  [ -4.5e+07   4.8e+15   8.0e+06  -1.8e+05   9.4e+16  -1.1e+08   4.0e+07]
#  [  1.2e-01  -5.7e+06  -9.5e-03   2.2e-04  -1.1e+08   1.2e+00  -3.0e-01]
#  [ -3.0e-02   2.1e+06   3.4e-03  -7.8e-05   4.0e+07  -3.0e-01   9.1e-02]]
#
# ../data/profiles/good-3-allback/prf_08_green.dat
# Left-of-peak smoothed minimum at: 3.55144375709
# Global smoothed maximum at: 9.63963305495
# green fit (xs frozen): xs = 10.14, x0 = 14.85, wu = 1.101, Cu =  1.53, Ad = 94.87, wd = 3.853, Cd = 8.748
# green fit (xs thawed): xs = 10.41, x0 = 12.77, wu = 0.8903, Cu = 1.376, Ad = 114.7, wd = 1.552, Cd = 16.81
# Errors: [  3.7e-02   2.3e+06   2.9e-02   4.3e-02   1.7e+08   1.6e-01   5.1e-01]
# Reduced chi-squared: 3.0913342389
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.4e-03   3.7e+04  -5.6e-04   1.1e-04   2.7e+06   3.0e-03  -6.0e-03]
#  [  3.7e+04   5.5e+12  -8.1e+03  -1.6e+03   4.1e+14   2.1e+04  -1.5e+05]
#  [ -5.6e-04  -8.1e+03   8.4e-04  -3.2e-04  -6.0e+05  -3.2e-05   2.3e-04]
#  [  1.1e-04  -1.6e+03  -3.2e-04   1.8e-03  -1.2e+05  -6.2e-06   4.5e-05]
#  [  2.7e+06   4.1e+14  -6.0e+05  -1.2e+05   3.0e+16   1.6e+06  -1.1e+07]
#  [  3.0e-03   2.1e+04  -3.2e-05  -6.2e-06   1.6e+06   2.7e-02  -6.6e-02]
#  [ -6.0e-03  -1.5e+05   2.3e-04   4.5e-05  -1.1e+07  -6.6e-02   2.6e-01]]
#
# ../data/profiles/good-3-allback/prf_08_blue.dat
# Left-of-peak smoothed minimum at: 3.55144375709
# Global smoothed maximum at: 9.63963305495
# blue fit (xs frozen): xs = 10.14, x0 = 297.1, wu = 2.775, Cu = 0.314, Ad =  7606, wd = 2.712, Cd = 3.374
# blue fit (xs thawed): xs = 10.14, x0 = 297.1, wu = 2.775, Cu = 0.314, Ad =  7606, wd = 2.712, Cd = 3.374
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 46.5613730501
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_09_red.dat
# Left-of-peak smoothed minimum at: 8.59763204095
# Global smoothed maximum at: 17.1952640819
# red fit (xs frozen): xs =  17.7, x0 = 452.5, wu = 5.188, Cu = 0.2721, Ad =  3211, wd = 3.405, Cd = 1.032
# red fit (xs thawed): xs =  17.7, x0 = 452.5, wu = 5.188, Cu = 0.2721, Ad =  3211, wd = 3.405, Cd = 1.032
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 20.6965122668
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_09_green.dat
# Left-of-peak smoothed minimum at: 9.10337510218
# Global smoothed maximum at: 17.1952640819
# green fit (xs frozen): xs =  17.7, x0 = 517.8, wu = 3.773, Cu = 1.139, Ad = 2.931e+04, wd = 3.022, Cd = 5.843
# green fit (xs thawed): xs =  17.7, x0 = 517.8, wu = 3.773, Cu = 1.139, Ad = 2.931e+04, wd = 3.022, Cd = 5.843
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 187.759779834
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_09_blue.dat
# Left-of-peak smoothed minimum at: 9.60911816341
# Global smoothed maximum at: 17.7010071431
# blue fit (xs frozen): xs =  18.2, x0 = 478.2, wu = 3.237, Cu = 0.463, Ad = 1.399e+04, wd = 2.963, Cd = 2.161
# blue fit (xs thawed): xs =  18.2, x0 = 478.2, wu = 3.237, Cu = 0.463, Ad = 1.399e+04, wd = 2.963, Cd = 2.161
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 88.2945953539
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_10_red.dat
# Left-of-peak smoothed minimum at: 11.6216375989
# Global smoothed maximum at: 16.6745235115
# red fit (xs frozen): xs = 17.17, x0 = 18.97, wu = 1.137, Cu = 0.4136, Ad = 6.517, wd = 3.458, Cd = 1.377
# red fit (xs thawed): xs = 18.36, x0 = 20.76, wu = 0.4837, Cu = 0.3644, Ad = 6.472, wd = 5.451, Cd = 1.084
# Errors: [  1.2e-01   1.7e+07   1.0e-01   2.5e-02   2.1e+07   4.6e+00   1.9e+00]
# Reduced chi-squared: 5.40228694632
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.5e-02  -8.6e+04  -9.9e-03   3.6e-04  -1.0e+05   1.4e-01  -4.9e-02]
#  [ -8.6e+04   3.0e+14  -5.6e+04  -1.4e+03   3.6e+14  -2.1e+07   9.1e+06]
#  [ -9.9e-03  -5.6e+04   1.0e-02  -5.6e-04  -6.7e+04   3.9e-03  -1.7e-03]
#  [  3.6e-04  -1.4e+03  -5.6e-04   6.3e-04  -1.6e+03   9.5e-05  -4.1e-05]
#  [ -1.0e+05   3.6e+14  -6.7e+04  -1.6e+03   4.3e+14  -2.5e+07   1.1e+07]
#  [  1.4e-01  -2.1e+07   3.9e-03   9.5e-05  -2.5e+07   2.1e+01  -8.8e+00]
#  [ -4.9e-02   9.1e+06  -1.7e-03  -4.1e-05   1.1e+07  -8.8e+00   3.7e+00]]
#
# ../data/profiles/good-3-allback/prf_10_green.dat
# Left-of-peak smoothed minimum at: 11.6216375989
# Global smoothed maximum at: 16.6745235115
# green fit (xs frozen): xs = 17.17, x0 = 453.6, wu = 2.426, Cu = 1.375, Ad = 3.022e+04, wd = 2.792, Cd = 8.366
# green fit (xs thawed): xs = 17.17, x0 = 453.6, wu = 2.426, Cu = 1.375, Ad = 3.022e+04, wd = 2.792, Cd = 8.366
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 110.275196551
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_10_blue.dat
# Left-of-peak smoothed minimum at: 11.6216375989
# Global smoothed maximum at: 17.1798121027
# blue fit (xs frozen): xs = 17.68, x0 = 463.8, wu = 2.196, Cu = 0.5553, Ad = 1.459e+04, wd = 2.652, Cd = 2.569
# blue fit (xs thawed): xs = 17.68, x0 = 463.8, wu = 2.196, Cu = 0.5553, Ad = 1.459e+04, wd = 2.652, Cd = 2.569
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 59.7132629895
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_11_red.dat
# Left-of-peak smoothed minimum at: 4.02819365263
# Global smoothed maximum at: 9.06343571841
# red fit (xs frozen): xs = 9.563, x0 = 12.75, wu = 1.226, Cu = 0.3315, Ad = 17.63, wd =  2.35, Cd = 0.6465
# red fit (xs thawed): xs = 10.09, x0 = 14.77, wu = 0.8908, Cu = 0.3282, Ad = 19.41, wd = 3.453, Cd = 0.1803
# Errors: [ 0.1  nan  0.1  0.   nan  0.7  0.5]
# Reduced chi-squared: 4.76960620553
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  1.8e-02  -2.9e+05  -1.3e-02   4.9e-04  -1.6e+06   5.4e-02  -2.7e-02]
#  [ -2.9e+05  -7.2e+14  -1.2e+06   9.2e+04  -4.1e+15   2.4e+07  -1.4e+07]
#  [ -1.3e-02  -1.2e+06   1.4e-02  -7.1e-04  -6.9e+06   4.1e-02  -2.3e-02]
#  [  4.9e-04   9.2e+04  -7.1e-04   5.5e-04   5.1e+05  -3.1e-03   1.7e-03]
#  [ -1.6e+06  -4.1e+15  -6.9e+06   5.1e+05  -2.3e+16   1.4e+08  -7.7e+07]
#  [  5.4e-02   2.4e+07   4.1e-02  -3.1e-03   1.4e+08   5.6e-01  -3.5e-01]
#  [ -2.7e-02  -1.4e+07  -2.3e-02   1.7e-03  -7.7e+07  -3.5e-01   2.5e-01]]
#
# ../data/profiles/good-3-allback/prf_11_green.dat
# Left-of-peak smoothed minimum at: 4.02819365263
# Global smoothed maximum at: 9.56695992499
# green fit (xs frozen): xs = 10.07, x0 = 12.66, wu = 0.8629, Cu = 1.409, Ad = 142.4, wd =  2.33, Cd = 4.523
# green fit (xs thawed): xs = 9.986, x0 = 12.45, wu = 0.8811, Cu = 1.388, Ad = 160.2, wd = 2.054, Cd = 5.476
# Errors: [ 0.   nan  0.   0.1  nan  0.2  0.9]
# Reduced chi-squared: 31.1317049117
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  8.4e-04   1.6e+03  -2.4e-04   8.3e-05   1.2e+05   3.0e-03  -1.3e-02]
#  [  1.6e+03  -2.4e+12  -2.3e+03   3.2e+02  -1.9e+14  -6.1e+03   7.7e+04]
#  [ -2.4e-04  -2.3e+03   5.2e-04  -3.5e-04  -1.8e+05  -6.1e-06   7.6e-05]
#  [  8.3e-05   3.2e+02  -3.5e-04   2.5e-03   2.5e+04   8.2e-07  -1.0e-05]
#  [  1.2e+05  -1.9e+14  -1.8e+05   2.5e+04  -1.5e+16  -4.8e+05   6.1e+06]
#  [  3.0e-03  -6.1e+03  -6.1e-06   8.2e-07  -4.8e+05   2.6e-02  -1.4e-01]
#  [ -1.3e-02   7.7e+04   7.6e-05  -1.0e-05   6.1e+06  -1.4e-01   8.3e-01]]
#
# ../data/profiles/good-3-allback/prf_11_blue.dat
# Left-of-peak smoothed minimum at: 4.5317178592
# Global smoothed maximum at: 9.56695992499
# blue fit (xs frozen): xs = 10.07, x0 = 184.8, wu = 4.054, Cu = 0.4673, Ad =  8565, wd = 2.341, Cd = 1.558
# blue fit (xs thawed): xs = 10.07, x0 = 184.8, wu = 4.054, Cu = 0.4673, Ad =  8565, wd = 2.341, Cd = 1.558
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 63.9188003564
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# ../data/profiles/good-3-allback/prf_12_red.dat
# Left-of-peak smoothed minimum at: 6.02044688262
# Global smoothed maximum at: 12.0408937652
# red fit (xs frozen): xs = 12.54, x0 = 16.57, wu = 1.351, Cu = 0.2565, Ad = 20.35, wd = 2.831, Cd = 1.004
# red fit (xs thawed): xs = 12.93, x0 = 15.13, wu = 0.8844, Cu = 0.3827, Ad = 18.08, wd = 1.722, Cd = 1.819
# Errors: [ 0.1  nan  0.1  0.   nan  0.5  0.3]
# Reduced chi-squared: 1.82572614645
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[  9.3e-03   3.3e+05  -4.0e-03   2.0e-04   3.4e+06   3.4e-02  -1.2e-02]
#  [  3.3e+05  -5.0e+13  -3.9e+04   4.6e+03  -5.3e+14  -1.8e+05   1.4e+05]
#  [ -4.0e-03  -3.9e+04   9.0e-03  -9.0e-04  -4.1e+05  -1.4e-04   1.1e-04]
#  [  2.0e-04   4.6e+03  -9.0e-04   1.0e-03   4.8e+04   1.7e-05  -1.3e-05]
#  [  3.4e+06  -5.3e+14  -4.1e+05   4.8e+04  -5.6e+15  -1.9e+06   1.5e+06]
#  [  3.4e-02  -1.8e+05  -1.4e-04   1.7e-05  -1.9e+06   2.4e-01  -1.1e-01]
#  [ -1.2e-02   1.4e+05   1.1e-04  -1.3e-05   1.5e+06  -1.1e-01   7.1e-02]]
#
# ../data/profiles/good-3-allback/prf_12_green.dat
# Left-of-peak smoothed minimum at: 6.02044688262
# Global smoothed maximum at: 12.0408937652
# green fit (xs frozen): xs = 12.54, x0 = 358.3, wu = 2.831, Cu = 1.468, Ad = 2.92e+04, wd =  2.63, Cd = 6.984
# green fit (xs thawed): xs = 12.54, x0 = 358.3, wu = 2.831, Cu = 1.468, Ad = 2.92e+04, wd =  2.63, Cd = 6.984
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 111.373462654
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
#
# ../data/profiles/good-3-allback/prf_12_blue.dat
# Left-of-peak smoothed minimum at: 5.51874297574
# Global smoothed maximum at: 12.5425976721
# blue fit (xs frozen): xs = 13.04, x0 = 414.8, wu = 3.033, Cu = 0.3824, Ad = 1.696e+04, wd = 2.546, Cd =  2.55
# blue fit (xs thawed): xs = 13.04, x0 =  1580, wu = 3.033, Cu = 0.3824, Ad = 1.696e+04, wd = 2.546, Cd =  2.55
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: 57.3677922598
# Covariance matrix, variables: ['xs', 'x0', 'wu', 'Cu', 'Ad', 'wd', 'Cd']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
