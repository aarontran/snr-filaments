# %% [markdown]
# # Profile fits and stuff

# %%
# %pylab --no-import-all
# %matplotlib inline
# ('gtk', 'inline', 'osx', 'qt', 'qt4', 'tk', 'wx')
from fplot import fplot, show_mplrc_settings

import os
import re
import scipy as sp
from scipy import optimize
from scipy import signal  # LAZINESS

import regparse  # Utility methods for region file parsing
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
show_mplrc_settings()
# Out:
# Using /Users/atran3/snr-research/code/matplotlibrc
# Font sizes for axes: 9; (x,y) ticks: (9, 9): legend 9
# Font family serif uses face ['Times']
# Figure size: (6.0, 4.0), dpi: 80

# %% [markdown]
# ## Individual profile fitting (i.e. fits for each band's rim)

# %% [markdown]
# Note: the code is really badly designed.  I need an XSPEC like functionality for freezing parameters, and a lot of code refactoring.  But, dammit, it works for now.

# %% [markdown]
# ### Fitting functions

# %% [markdown]
# First, we need a profile function.  _Ressler et al._ [2014, _in press_] used a piecewise function to fit the upstream and downstream sides of the rim profiles:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right)
#                           + B \exp \left( \frac{-(x-x_1)^2}{2\pi \sigma^2} \right)
#                           + C_d
# \end{align*}
#
# Some outstanding questions -- how do you decide the location of up/down-stream?  Is this part of the fitting procedure?
# The peak intensity may be located at either $x_0$ or $x_1$ -- okay, seems physically reasonable given projection effects.  But how to decide where to split the fit.

# %%
def ressler_function(x, x0, x1, Cu, Cd, wu, wd, sigma, Au, B):
    """Big fat piecewise function with a million parameters to try fitting.
    Note -- the functions should be piecewise continuous -- a constraint that has to be enforced!
    Inputs (all floats):
        x = radial position (arcsec.)
        Au, x0, wu, Cu = parameters for upstream function
        xs = location of upstream/downstream divide
        Ad, wd, B, x1, sigma, Cd = parameters for downstream function
    Output (float): value of function at radial position x
    """
    Ad = ressler_function_Ad(x0, x1, Cu, Cd, sigma, Au, B)
    def ressler_help(x, x0, x1, Cu, Cd, wu, wd, sigma, Au, B, Ad):
        if x > x0:  # Upstream, ahead of shock
            return Au * np.exp((x0-x)/wu) + Cu
        else:
            return Ad * np.exp((x-x0)/wd) + B * np.exp( -(x-x1)**2 / (2*np.pi*sigma**2)) + Cd
    ressler_vec = np.vectorize(ressler_help)
    return ressler_vec(x, x0, x1, Cu, Cd, wu, wd, sigma, Au, B, Ad)

def ressler_function_Ad(x0, x1, Cu, Cd, sigma, Au, B):
    return Au + Cu - Cd - B * np.exp( -(x0-x1)**2 / (2*np.pi*sigma**2))

# %% [markdown]
# ### Two exponential function

# %% [markdown]
# I first try a continuous piecewise two exponential function of form:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right) + C_d
# \end{align*}
#
# where the upstream/downstream split occurs at $x=x_s$ and $x_s$ is used as a fit parameter instead of $A_u$.  Once $x_s$ is determined, $A_u$ is constrained to be:
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_0}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_0}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# Alternately we may constrain $A_d$ and use $A_u$ as a fit parameter:
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_0 - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_0 - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %%
def two_exp_function(x, xs, x0, Cu, Cd, wu, wd, Au):
    """Two exponential profile function, vectorized in x
    downstream amplitude Ad set by the split xs + continuity requirement
    """
    Ad = two_exp_function_Ad(xs, x0, Cu, Cd, wu, wd, Au)
    def two_exp_help(x, xs, x0, Cu, Cd, wu, wd, Au, Ad):
        if x > xs:  # Upstream, ahead of shock
            return Au * np.exp((x0-x)/wu) + Cu
        else:
            return Ad * np.exp((x-x0)/wd) + Cd
    two_exp_vec = np.vectorize(two_exp_help)
    return two_exp_vec(x, xs, x0, Cu, Cd, wu, wd, Au, Ad)

def two_exp_function_Au(xs, x0, Cu, Cd, wu, wd, Ad):
    """Value of Au set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xs-x0)/wu) * ( Ad * np.exp((xs-x0)/wd) + Cd - Cu )

def two_exp_function_Ad(xs, x0, Cu, Cd, wu, wd, Au):
    """Value of Ad set by split location xs + continuity requirement for two exponential function"""
    return np.exp((x0-xs)/wd) * ( Au * np.exp((x0-xs)/wu) + Cu - Cd )

# %% [markdown]
# ### Two exponential function, decoupled (one more free parameter)

# %% [markdown]
# I could also let one more parameter run free in the two exponential function:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_u-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_d}{w_d}\right) + C_d
# \end{align*}
#
# Again, $x=x_s$ is a fit parameter for the upstream/downstream split, which can be used in place of $A_u$ or $A_d$.
# Because the upstream side is generally easier to fit / the data is better, it's probably better to pin $A_d$ and let $A_u$ be a free fit parameter.
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_u}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_d}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_d - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_u - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %%
def two_exp_function_dec(x, xs, xu, xd, Cu, Cd, wu, wd, Au):
    """Two exponential profile function, with one more free parameter, vectorized in x
    downstream amplitude Ad set by the split xs + continuity requirement
    """
    Ad = two_exp_function_dec_Ad(xs, xu, xd, Cu, Cd, wu, wd, Au)
    def two_exp_help(x, xs, xu, xd, Cu, Cd, wu, wd, Au, Ad):
        if x > xs:  # Upstream, ahead of shock
            return Au * np.exp((xu-x)/wu) + Cu
        else:
            return Ad * np.exp((x-xd)/wd) + Cd
    two_exp_vec = np.vectorize(two_exp_help)
    return two_exp_vec(x, xs, xu, xd, Cu, Cd, wu, wd, Au, Ad)

def two_exp_function_dec_Au(xs, xu, xd, Cu, Cd, wu, wd, Ad):
    """Value of Au set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xs-xu)/wu) * ( Ad * np.exp((xs-xd)/wd) + Cd - Cu )

def two_exp_function_dec_Ad(xs, xu, xd, Cu, Cd, wu, wd, Au):
    """Value of Ad set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xd-xs)/wd) * ( Au * np.exp((xu-xs)/wu) + Cu - Cd )

# %% [markdown]
# ### Two exponential function, split at $x_0$

# %% [markdown]
# Now instead of using a free split location $x_s$, try throwing that away and using $x_0$ as the split location (following what Satoru did?):
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right) + C_d
# \end{align*}
#
# where the upstream/downstream split occurs at $x=x_0$.  Continuity then allows us constrain one of $\{A_u, A_d, C_u, C_d\}$.
# Consistent with above, let's constrain $A_d$ and let $A_u$ run free (try changing this up as well).
#
# \begin{align*}
#     A_d &= A_u + (C_u - C_d) \\
#     A_u &= A_d + (C_d - C_u)
# \end{align*}

# %%
def two_exp_function_simp(x, x0, Cu, Cd, wu, wd, Au):
    """Two exponential profile function, vectorized in x
    downstream amplitude Ad set by the split xs + continuity requirement
    """
    Ad = two_exp_function_simp_Ad(Cu, Cd, Au)
    def two_exp_help(x, x0, Cu, Cd, wu, wd, Au, Ad):
        if x > x0:  # Upstream, ahead of shock
            return Au * np.exp((x0-x)/wu) + Cu
        else:
            return Ad * np.exp((x-x0)/wd) + Cd
    two_exp_vec = np.vectorize(two_exp_help)
    return two_exp_vec(x, x0, Cu, Cd, wu, wd, Au, Ad)

# Careful with the parameter signatures!
def two_exp_function_simp_Au(Cu, Cd, Ad):
    return Ad + Cd - Cu

def two_exp_function_simp_Ad(Cu, Cd, Au):
    return Au + Cu - Cd

# %% [markdown]
# ### Data manipulation (smooth profiles to identify minima/maxima for initial guesses, fit domain)

# %% [markdown]
# A cookbook on curve fitting with SciPy: [wiki.scipy.org/Cookbook/FittingData](http://wiki.scipy.org/Cookbook/FittingData).
#
# And, signal smoothing (maybe useful for peak/trough identification): [wiki.scipy.org/Cookbook/SignalSmooth](http://wiki.scipy.org/Cookbook/SignalSmooth).

# %%
def ind_first_smoothed_min(y):
    """Smooths data and returns index of first minimum to left of global max, in smoothed data
    If no such minimum is found, return 0 (i.e., don't cut the fit domain)"""
    # List of indices of relative minima in smoothed-y
    inds_relmin = sp.signal.argrelmin(std_smooth(y))[0]  # Unpack the tuple...
    if len(inds_relmin) is 0:
        return 0
    # Index of global (non-edge) maximum in y
    ind_max = ind_smoothed_max(y)
    
    # Want to find the largest value in inds_relmin, that's smaller than ind_max
    max_left_min = 0
    for ind_min in inds_relmin:
        if ind_min > max_left_min and ind_min < ind_max:
            max_left_min = ind_min
    
    return max_left_min


def ind_smoothed_max(y):
    """Smooths data and returns index of global maximum in smoothed data"""
    ysmooth = std_smooth(y)
    # Get indices of relative maxima
    inds_relmax = sp.signal.argrelmax(ysmooth)[0]  # Unpack the tuple...
    # Get index of the largest relative maximum
    best_ind = inds_relmax[0]
    for ind in inds_relmax[1:]:
        if ysmooth[best_ind] < ysmooth[ind]:
            best_ind = ind
    return best_ind


def std_smooth(x):
    """Standardized smoothing -- SMOOTHING WINDOW CHOICE AFFECTS FIT!!!!!"""
    wlen = 21  # Arbitrary pick
    xsmooth = smooth(x, window_len=wlen, window='hanning')
    padlen = (len(xsmooth) - len(x))/2  # Should be an integer
    return xsmooth[padlen:-padlen]


def smooth(x,window_len=11,window='hanning'):
    """stolen from scipy cookbook (reimplement whatever later)"""
    if window_len < 3:
        return x
    if not window in ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']:
        raise ValueError, "Window is on of 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'"
    
    s = numpy.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    if window == 'flat': #moving average
        w = numpy.ones(window_len,'d')
    else:
        w = eval('numpy.{}(window_len)'.format(window))
    
    y=numpy.convolve(w/w.sum(), s, mode='valid')
    return y

# %% [markdown]
# ### Routines to actually perform profile fit

# %% [markdown]
# Fit using two exponential model (with shared parameter $x_0$).

# %%
def fit_profile_2exp(x, y, y_err, lab):
    """FIT THE PROFILE"""
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    ###################
    # First fit attempt
    ###################
    
    # Freeze: xs, x0
    xs_fr = x_of_max + 1.5  # Smoothing shifts peak slightly left
    x0_fr = xs_fr + 0.5  # xs left of x0 in good fit (empirically speaking)
    
    # Free parameters: Cu, Cd, wu, wd, Au
    Cu_g = np.mean(y_fit[-3:])  # The obvious guess
    Cd_g = np.mean(y_fit[:3]) / 2.  # Usually shoots under trough
    wu_g = 0.5  # Upstream width
    wd_g = 2.5  # Downstream width
    Au_g = np.amax(y_fit)/3.  # Upstream amplitude
    init_guess = [Cu_g, Cd_g, wu_g, wd_g, Au_g]
    
    # Show initial guesses for comparison
    print ('{} initial guesses: xs = {:5.4g}, x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, xs_fr, x0_fr, *init_guess)

    # Perform fit!
    fit_func = lambda xval, Cu,Cd,wu,wd,Au: two_exp_function(xval, xs_fr,x0_fr, Cu,Cd,wu,wd,Au)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                       sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0 frozen): xs = {:5.4g}, x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, xs_fr, x0_fr, *popt)
    
    ####################
    # Second fit attempt
    ####################
    
    # Unfreeze: xs, x0, Cu, Cd
    # All parameters free
    init_guess = np.concatenate(([xs_fr, x0_fr], popt))
    
    # Perform fit!
    fit_func = two_exp_function
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0,Cu,Cd thawed): xs = {:5.4g}, x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, *popt)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y_fit) - 7)  # Seven free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','x0','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, two_exp_function, leftcut

# %% [markdown]
# As above, but now for the decoupled model (modify guesses etc).

# %%
def fit_profile_2exp_dec(x, y, y_err, lab):
    """FIT THE PROFILE
    
    VERY DIFFERENT METHOD THAN ABOVE
    """
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    ##################
    # Manually step xs
    ##################
    
    # Maybe pull out some old code
    
    xs_range = np.linspace(x_of_max - 1.5, x_of_max + 3.5, num=50)
    chi2_best = float('inf')
    chi2s = []
    
    for xs_fr in xs_range:
        
        # Free parameters: xu, xd, Cu, Cd, wu, wd, Au
        xu_g = xs_fr + 0.5
        xd_g = xs_fr - 0.5
        Cu_g = np.mean(y_fit[-3:])  # The obvious guess
        Cd_g = np.mean(y_fit[:3]) / 2.  # Usually shoots under trough
        wu_g = 0.5  # Upstream width
        wd_g = 2.5  # Downstream width
        Au_g = np.amax(y_fit)/3.  # Upstream amplitude
        init_guess = [xu_g, xd_g, Cu_g, Cd_g, wu_g, wd_g, Au_g]
        
        # Perform fit!
        fit_func = lambda xval, xu,xd,Cu,Cd,wu,wd,Au: two_exp_function_dec(xval, xs_fr, xu,xd,Cu,Cd,wu,wd,Au)
        popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                           sigma=y_err_fit, absolute_sigma=True,
                                           maxfev=3200)
                                           #maxfev=200*(len(init_guess)+1))  # DOUBLE THE MAX ITERATIONS to 3200
        print ('{} fit (xs frozen): xs = {:5.4g}, xu = {:5.4g}, xd = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
               'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, xs_fr, *popt)
        
        # Check chi2, try to find best value of xs_fr
        chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
        chi2red = chi2 / (len(y) - 8)
        print 'chi2 = {:5.4g}, chi2red = {:5.4g}'.format(chi2, chi2red)
        chi2s.append(chi2)
        if chi2 < chi2_best:
            xs_fr_best = xs_fr
            popt_best = popt
            chi2_best = chi2
    
    # Plot the ch^2 space result
    f = plt.figure(figsize=(5,5))
    ax = f.add_subplot(111)
    ax.plot(xs_range, chi2s, '-o')
    
    # NOW, use best parameters to do stuff!
    # Unfreeze: xs
    # All parameters free
    init_guess = np.concatenate(([xs_fr_best], popt_best))

    # Perform fit!
    fit_func = two_exp_function_dec
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True)
    print ''
    print ('{} fit (xs thawed): xs = {:5.4g}, xu = {:5.4g}, xd = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, *popt)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y_fit) - 8)  # EIGHT free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','xu','xd','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, two_exp_function_dec, leftcut

# %%
def fit_profile_2exp_simp(x, y, y_err, lab):
    """FIT THE PROFILE"""
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    ###################
    # First fit attempt
    ###################
    
    # Freeze: x0
    x0_fr = x_of_max + 1.5
    
    # Free parameters: Cu, Cd, wu, wd, Au
    Cu_g = np.mean(y_fit[-3:])  # The obvious guess
    Cd_g = np.mean(y_fit[:3]) / 3.  # Usually shoots under trough
    wu_g = 0.5  # Upstream width
    wd_g = 2.5  # Downstream width
    Au_g = np.amax(y_fit)/1.  # Upstream amplitude
    init_guess = [Cu_g, Cd_g, wu_g, wd_g, Au_g]

    # Perform fit!
    fit_func = lambda xval, Cu,Cd,wu,wd,Au: two_exp_function_simp(xval ,x0_fr, Cu,Cd,wu,wd,Au)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                       sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0,Cu,Cd frozen): x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, x0_fr, *popt)
    
    ####################
    # Second fit attempt
    ####################
    
    # Unfreeze: x0
    # All parameters free
    init_guess = np.concatenate(([x0_fr], popt))
    
    # Perform fit!
    fit_func = two_exp_function_simp
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0,Cu,Cd thawed): x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(lab, *popt)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y_fit) - 6)  # SIX free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','x0','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, two_exp_function_simp, leftcut  ## UPDATE THIS THINGGGLJKSDFLKJLSF

# %%
def fit_profile_ressler(x, y, y_err, lab):
    """Attempt to fit data to function from Ressler et al. [2014]"""
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    # CALL SIGNATURE: ressler_function(x, x0, x1, Cu, Cd, wu, wd, sigma, Au, B)
    
    ###################
    # First fit attempt
    ###################
    
    # Freeze: x0, Cu, Cd
    x0_fr = x_of_max + 1.5
    Cu_fr = np.mean(y_fit[-3:])  # The obvious guess
    Cd_fr = np.mean(y_fit[:3]) / 3.  # Usually shoots under trough
    
    # Free parameters: Cu, Cd, wu, wd, Au
    x1_g = x_of_max - 1.5  # Gaussian center
    wu_g = 0.5  # Upstream width
    wd_g = 2.5  # Downstream width
    sigma_g = 2  # Gaussian width
    Au_g = np.amax(y_fit)/1.  # Upstream amplitude
    B_g = Au_g / 6.
    init_guess = [x1_g, wu_g, wd_g, sigma_g, Au_g, B_g]

    # Perform fit!
    fit_func = lambda xval, x1,wu,wd,sigma,Au,B: ressler_function(xval ,x0_fr, x1,Cu_fr,Cd_fr,wu,wd,sigma,Au,B)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                       sigma=y_err_fit, absolute_sigma=True, maxfev=8000)
    allparams = np.concatenate(([x0_fr], [popt[0]], [Cu_fr, Cd_fr], popt[1:]))
    print ('{} fit (x0,Cu,Cd frozen): x0 = {:5.4g}, x1 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, sigma = {:5.4g}, Au = {:5.4g}, B = {:5.4g}').format(lab, *allparams)
    
    ####################
    # Second fit attempt
    ####################
    
    # Unfreeze: x0
    # Leave Cu, Cd frozen
    init_guess = np.delete(allparams, [2,3])
    
    # Perform fit!
    fit_func = lambda xval, x0,x1,wu,wd,sigma,Au,B: ressler_function(xval ,x0,x1, Cu_fr,Cd_fr, wu,wd,sigma,Au,B)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True, maxfev=8000)
    allparams = np.insert(popt, 2, [Cu_fr, Cd_fr])
    print ('{} fit (x0 thawed): x0 = {:5.4g}, x1 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, sigma = {:5.4g}, Au = {:5.4g}, B = {:5.4g}').format(lab, *allparams)
    
    ###################
    # Third fit attempt
    ###################
    
    # Unfreeze: Cu
    # Leave Cd frozen
    init_guess = np.delete(allparams, 3)
    
    # Perform fit!
    fit_func = lambda xval, x0,x1,Cu,wu,wd,sigma,Au,B: ressler_function(xval ,x0,x1,Cu, Cd_fr, wu,wd,sigma,Au,B)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True, maxfev=8000)
    allparams = np.insert(popt, 3, Cd_fr)
    print ('{} fit (x0 thawed): x0 = {:5.4g}, x1 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, sigma = {:5.4g}, Au = {:5.4g}, B = {:5.4g}').format(lab, *allparams)
    
    ####################
    # Fourth fit attempt
    ####################
    # In lieu of final fit with all free parameters
    init_guess = allparams
    fit_func = ressler_function
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True, maxfev=8000)
    allparams = popt
    print ('{} fit (x0 thawed): x0 = {:5.4g}, x1 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, sigma = {:5.4g}, Au = {:5.4g}, B = {:5.4g}').format(lab, *allparams)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y_fit) - 9)  # NINE free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','x0','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, ressler_function, leftcut  ## UPDATE THIS THINGGGLJKSDFLKJLSF

# %% [markdown]
# ## Individual profile FWHM work

# %% [markdown]
# For each profile (every band, every region), we need to:
# 1. calculate FWHM
# 2. estimate uncertainties on FWHM
# 3. check that FWHM uncertainties are reasonable (i.e., $\chi^2$ space is not too weird)
# 4. give information to allow plotting/visualization of uncertainties.

# %% [markdown]
# THESE FUNCTIONS DESPERATELY NEED UNIT TESTS -- TO ENSURE THEY DO WHAT I THINK THEY DO.
#
# TRY STRETCHING A GAUSSIAN / FITTING GAUSSIAN DATA.

# %%
def get_fwhm(a, b, f, pars, x_max=None):
    """Manually calculate FWHM given a bracketing interval, location of maximum, and function.
    Assumptions -- there exists a single local maximum, from which the function
    MONOTONICALLY DECREASES on both sides
    
    Inputs:
        a, b (float): bounding interval
        f (function): scalar function in first argument, with form f(x, *popt)
        pars (list): list of parameters for function f
        x_max (float): location of maximum if known (skip maximization step)
    
    Output:
        3-tuple of FWHM and left, right locations of FWHM measurement
    """
    if x_max is None:
        # Multiply by -1 to maximize
        res = sp.optimize.minimize_scalar(lambda x: -1*f(x,*pars), bounds=(a,b), method='Bounded')
        x_max = res.x
    y_hm = f(x_max, *pars) / 2.
    y_lims = f([a,b], *pars)  # Assumes that f is vectorized in x

    if any(y_lims >= y_hm):  # Function must fall below half max on both sides
        print 'Cannot calculate FWHM, peak not resolved in interval'
        return -1, a, b

    fwhm_left = sp.optimize.brentq(lambda x: f(x, *pars) - y_hm, a, x_max)
    fwhm_right = sp.optimize.brentq(lambda x: f(x, *pars) - y_hm, x_max, b)
    return fwhm_right - fwhm_left, fwhm_left, fwhm_right

def chi2red(x, y, y_err, f, pars):
    """Reduced chi-squared for a scalar function fitted to data with y-errors
    
    N.B. for a non-linear model fit, assigning 1 degree of freedom
    to each parameter may be an OVERestimate?
    (there may be other caveats/issues at hand)
    
    Inputs:
        x, y, y_err (iterable): the usual suspects
        f (function): function with call signature f(x, *pars)
        pars (list):  list of parameters for function f
    Output:
        reduced chi-squared value (float)
    """
    chi2 = np.sum( ((y - f(x, *pars))/y_err)**2 )
    return chi2 / (len(y) - len(popt))

def stretch_x(x, xi, x0):
    """Parabolic stretch centered on x=x0, fixed points at x=0, x=x0
    Follows Ressler et al. [2014]
    
    Constant here is 50 arcsec instead of 200 arcsec.
    Doesn't matter, mainly scales the input range of xi
    
    Inputs:
        x (float / iterable): original x-values
        xi (float): stretch factor
        x0 (float): fixed point of stretch
    Output:
        stretched version of x (float/iterable depending on input)
    """
    return x * (1 + xi * (x - x0)/(50 - x0))

def stretch_func(f, xi, x_max):
    """Stretched version of a function with call signature f(x, *pars)
    If function f is vectorized in x, output function will also be vectorized"""
    return lambda x, *pars: f(stretch_x(x, xi, x_max), *pars)

def get_fwhm_str(a, b, f, pars, xi, x_max):
    """Calculate FWHM for a stretched function.
    xmax is required this time, for the stretch.
    See docstring for get_fwhm(...)
    """
    a2 = a#stretch_x(a, xi, x_max)
    b2 = b#stretch_x(b, xi, x_max)
    f2 = stretch_func(f, xi, x_max)
    return get_fwhm(a2, b2, f2, pars, x_max)

# %% [markdown]
# ## Region work (i.e., assess energy dependence of FWHMs)

# %% [markdown]
# ## Main method

# %% [markdown]
# A utility method for parsing projections

# %%
def get_proj_dims(regstrs):
    """Get projection dimensions from list of regions, must all be projections
    Input: list of region strings
    Output: list of 2-tuples
        1st element is length (radial distance)
        2nd element is thickness (dist. along which projection integrates)
        
    WARNING: DIMENSIONS ARE NOT THE SAME.  Length is in arcsec., thickness is in PIXELS / PHYSICAL UNITS.
    """
    pixel2arcsec = 0.5  # Chandra spatial resolution
    
    dims = []
    for line in regstrs:
        rtype, rnums, rprops = regparse.regparse(line)
        if 'projection' not in rtype:
            print 'WARNING: region not of type projection encountered'
            print 'Type was: {}'.format(rtype)
        x1,y1,x2,y2,w = rnums
        length = np.sqrt((x2-x1)**2 + (y2-y1)**2) * pixel2arcsec
        dims.append((length, w))
    
    return dims

# %% [markdown]
# Structure of a region dict:
#
#     region = {'red': {},
#               'green': {},
#               'blue': {}}
#
# So that I can get useful information by, e.g., calling:
#
#     region['red']['r']  # Radial distance (units?)
#     region['green']['i']  # Intensity (units?)
#     region['blue']['fwhm']  # FWHM value (same units as radial distance)
#
# This script (as well as `ds9projplotter.py`) will need to be updated later if we are to try different energy bands.
# In principle I could deduce the bands from the filenames...

# %% [markdown]
# Roughly speaking:
# * (0.7-1 keV) count <--> 8e-9 intensity units (wat? -- this makes no sense, ask Brian what's going on)
# * (1-2 keV) count <--> 2.8e-9 intensity units
# * (2-7 keV) count <--> 5e-9 intensity units
#
# For further subdivided bands:
# * (2-3 keV) count <--> 4.5e-9 units
# * (2-4 keV) count <--> 4.5e-9 units
# * (3-4.5 keV) count <--> 4e-9 units
# * (4-7 keV) count <--> 6e-9 units
# * (4.5-7 keV) count <--> 6.5e-9 units

# %%
ds9physreg = '../data/regions-good-3-allback.physreg'
inroot = '../data/profiles/good-3-allback/prf'

## Uncomment the appropriate set of labels / flux ct. estimates
## THREE BAND ##
labels = ['0.7-1kev', '1-2kev', '2-7kev']
fluxes = [8e-9, 2.8e-9, 5e-9]
## FOUR BAND ##
# labels = ['0.7-1kev', '1-2kev', '2-4kev', '4-7kev']
# fluxes = [8e-9, 2.8e-9, 4.5e-9, 6e-9]
## FIVE BAND ##
# labels = ['0.7-1kev', '1-2kev', '2-3kev', '3-4p5kev', '4p5-7kev']
# fluxes = [8e-9, 2.8e-9, 4.5e-9, 4e-9, 6.5e-9]


# Build a flux2ct dict
flux2ct_dict = {lab:1./flux for lab, flux in zip(labels,fluxes)}

# Count number of regions
n_regions = regparse.count_files_regexp(inroot + r'_[0-9]+_band_{}\.dat'.format(labels[0]))

# Get radial lengths of each region (convert physical pixels to arcseconds)
dims = get_proj_dims(regparse.load_ds9reg(ds9physreg))

# %%
# Process and store information on each region
for i in xrange(n_regions):
    
    region = {}
    region['length'] = dims[i][0]  # Units: arcsec
    region['thickness'] = np.floor(dims[i][1])  # Units: PIXELS (apply floor to be consistent with DS9)
    
    # For plotting whatever is necessary
    fig1, axes1 = plt.subplots(1, len(labels), figsize=(5*len(labels),5))
    fig2, axes2 = plt.subplots(1, len(labels), figsize=(5*len(labels),5))
    fig3, axes3 = plt.subplots(1, len(labels), figsize=(5*len(labels),5))
    # Tuple of each subplot axis is assigned to label
    #label_axes = {lab:axes_all for (lab,axes_all) in zip(labels, zip(axes1,axes2,axes3))}
    label_axes = {lab:(ax1,ax2,ax3) for (lab,ax1,ax2,ax3) in zip(labels, axes1,axes2,axes3)}
    
    # Fit and find FWHM for each band
    for lab in labels:
        # Information for each labeled band
        region[lab] = {}  # Energy band dictionary
        ax1, ax2, ax3 = label_axes[lab]  # Subplot axes for 3 sets of subplots
        flux2ct = flux2ct_dict[lab]  # Ad hoc flux-count conversion
        
        ########################
        # Import projection data
        ########################
        infile = '{0}_{1:02d}_band_{2}.dat'.format(inroot, i+1, lab)
        print infile
        data = np.loadtxt(infile)
        x = (data[:,0] - 1) * region['length'] / (len(data[:,0]) - 0.9)  # Convert to arcsec
        y = data[:,1]
        y_err = 1./flux2ct * np.sqrt( y * flux2ct / region['thickness'] )
        y_err[y_err ==0] = 1./flux2ct * np.sqrt(1 / region['thickness'])  # Give zero counts a non-zero error for fits!
        y, y_err = y*flux2ct, y_err*flux2ct  # Uncomment if you want to change units to counts, instaed of intensity
        
        ##############
        # Fit profiles
        ##############
        popt, pcov, fit_func, cut = fit_profile_2exp_simp(x, y, y_err, lab)
        x_fit, y_fit, y_err_fit = x[cut:], y[cut:], y_err[cut:]
        
        ##################
        # FWHM calculation
        ##################
        
        # For background subtraction, replace `fit_func` with
        # lambda x, *pars: fix_func(x,*pars) - y_bkg
        
        xmax = popt[0]  # xmax = x0 for simple two-exponential fit
        fwhm, fwhm_left, fwhm_right = get_fwhm(x_fit[0], x_fit[-1], fit_func, popt, xmax)
        
        ##########################
        # FWHM uncertainty, set-up
        ##########################
        
        # Baseline chi2red
        chi2red_min = chi2red(x_fit, y_fit, y_err_fit, fit_func, popt)
        
        # Useful functions
        def chi2red_str(xi):
            """Calculate chi2red as a function of xi, for fit function.
            Input: xi (scalar), stretch parameter, may be pos. or neg.
            Output: chi2red for stretched function
            """
            return chi2red(x_fit, y_fit, y_err_fit,
                           stretch_func(fit_func, xi, xmax), popt)
        
        # Vectorize in xi for convenience
        chi2red_str = np.vectorize(chi2red_str)
        
        def chi2red_threshold(xi):
            """Threshold for chi^2 uncertainty.  Output > 0 if \Delta\chi^2_{red} > 2.7"""
            return chi2red_str(xi) - chi2red_min - 2.7
        
        ##############################
        # FWHM uncertainty calculation
        ##############################
        
        # Increasing positive xi (decreasing FWHM) uncertainty
        # Empirically, positive xi is better behaved than negative xi
        xi_max = 0.5
        while chi2red_threshold(xi_max) < 0:  # Stretch until \Delta\chi^2_{red} > 2.7
            xi_max += 0.5
        xi_bound_pos = sp.optimize.brentq(chi2red_threshold, 0, xi_max)
        
        # Decreasing negative xi (increasing FWHM) uncertainty
        # Empirically, this can blow up quickly (stretch becomes meaningless if too far)
        xi_min = -0.1
        while chi2red_threshold(xi_min) < 0:  # Stretch until \Delta\chi^2_{red} > 2.7
            xi_min -= 0.1
        xi_bound_neg = sp.optimize.brentq(chi2red_threshold, xi_min, 0)
        
        # Get FWHM uncertainties
        fwhm_min, fwhm_min_left, fwhm_min_right = get_fwhm_str(x_fit[0], x_fit[-1], fit_func, popt, xi_bound_pos, xmax)
        print 'Attempted to get min FWHM: {}, {}, {}'.format(fwhm_min, fwhm_min_left, fwhm_min_right)
        fwhm_max, fwhm_max_left, fwhm_max_right = get_fwhm_str(x_fit[0], x_fit[-1], fit_func, popt, xi_bound_neg, xmax)
        print 'Attempted to get max FWHM: {}, {}, {}'.format(fwhm_max, fwhm_max_left, fwhm_max_right)
        fwhm_err = (fwhm_min + fwhm_max)/2  # For 1) averaging fwhm, 2) fwhm scaling error
        
        # Store FWHM and FWHM uncertainties in region dict
        # as tuple of (fwhm, pos_err, neg_err)
        region[lab]['fwhm'] = fwhm, fwhm-fwhm_min, fwhm_max-fwhm
        
        if fwhm >= 0:
            print 'FWHM = {:5.4g}, errors -{:5.4g}, +{:5.4g}'.format(*region[lab]['fwhm'])
        
        ############################
        # Plot the data, fits, FWHM,
        # and FWHM left/right bounds
        ############################
        ax1.errorbar(x[:cut], y[:cut], yerr=y_err[:cut], fmt='rx', alpha=0.4)  # Data NOT used in fit
        ax1.errorbar(x_fit, y_fit, yerr=y_err_fit, fmt='bo', alpha=0.7)  # Data used in fit
        ax1.plot(x, std_smooth(y), '-y', alpha = 0.4)  # Smoothed data used to help fit
        
        x_m = np.linspace(x[0], x[-1], num=200)  # x values for best fit model
        ax1.plot(x_m, fit_func(x_m, *popt), '-k', alpha=0.7)  # Best fit model
        
        # Delineate FWHM, if measurable
        if fwhm >= 0:
            ax1.axvline(fwhm_left, alpha=0.5, ls='--', c='k')
            ax1.axvline(fwhm_right, alpha=0.5, ls='--', c='k')
            
        ax1.set_xlabel('Radial dist. (arcsec.)')
        ax1.set_ylabel('Est. counts ~ intensity')
        ax1.set_title(lab)
        
        #############################
        # Plot reduced chi-squared as
        # a function of stretch (xi)
        #############################
        ax2.plot(0, [chi2red_min], 'ro')
        # Positive xi values
        xi_vals = np.linspace(0, xi_max, 100)
        ax2.plot(xi_vals, chi2red_str(xi_vals), '-k.')
        # Negative xi values
        xi_vals = np.linspace(0, xi_min, 100)
        ax2.plot(xi_vals, chi2red_str(xi_vals), '-k.')
        ax2.axvline(xi_bound_pos)
        ax2.axvline(xi_bound_neg)
        ax2.axhline(chi2red_min+2.7, c='r')
        
        ax2.set_xlabel(r'Stretch factor $\xi$')
        ax2.set_ylabel(r'Reduced $\chi^2$')
        
        ##############################
        # Plot profile function spread
        # (just to help visualization)
        ##############################
        fit_func_small = stretch_func(fit_func, xi_bound_pos, xmax)
        fit_func_large = stretch_func(fit_func, xi_bound_neg, xmax)
        
        ax3.plot(x_m, fit_func(x_m, *popt), '-k')  # Best fit model
        ax3.plot(x_m, fit_func_small(x_m, *popt), '--b', alpha=0.7)  # Stretching is still plottable
        ax3.plot(x_m, fit_func_large(x_m, *popt), '--r', alpha=0.7)  # even if FWHM cannot be calculated
        
        if fwhm >= 0:
            ax3.axvline(fwhm_left, alpha=0.5, ls='-', c='k')
            ax3.axvline(fwhm_right, alpha=0.5, ls='-', c='k')
            ax3.axvline(fwhm_min_left, alpha=0.5, ls='--', c='b')
            ax3.axvline(fwhm_min_right, alpha=0.5, ls='--', c='b')
            ax3.axvline(fwhm_max_left, alpha=0.5, ls='--', c='r')
            ax3.axvline(fwhm_max_right, alpha=0.5, ls='--', c='r')
        
        ax3.set_xlabel('Radial dist. (arcsec.)')
        ax3.set_ylabel('Est. counts ~ intensity')
    
    # Show the full array of subplots
    plt.show()
    
    # Plot FWHM dependence for all bands (single region)
    plt.figure(figsize=(5,5))
    for lab, n in zip(labels, xrange(len(labels))):
        fwhm, pos_err, neg_err = region[lab]['fwhm']
        if fwhm >= 0:
            plt.errorbar([n+1], [fwhm], yerr=[[pos_err],[neg_err]], fmt='bo')
    plt.xlim([0,len(labels)+2])
    plt.show()
    print ''
    
    # Do stuff to estimate FWHM dependence

# Compute average values of FWHM-energy scaling
# Out:
# ../data/profiles/good-3-allback/prf_01_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 15.121068912
# Global smoothed maximum at: 21.1694964768
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 22.67, Cu = 0.4049, Cd = 0.8974, wu = 0.7783, wd = 4.592, Au = 3.554
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 22.01, Cu = 0.3991, Cd = 1.602, wu = 0.9831, wd = 1.474, Au = 4.957
#
# Errors: [ 0.11  0.03  0.17  0.11  0.4   0.46]
# Reduced chi-squared: 0.849870438634
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.2e-02   2.6e-04  -6.4e-03  -5.3e-03   2.6e-02  -2.4e-02]
#  [  2.6e-04   7.8e-04  -1.2e-13  -1.0e-03  -1.7e-11  -1.2e-04]
#  [ -6.4e-03  -1.2e-13   2.9e-02   4.9e-11  -5.3e-02   3.2e-02]
#  [ -5.3e-03  -1.0e-03   4.9e-11   1.2e-02  -1.4e-10  -1.2e-02]
#  [  2.6e-02  -1.7e-11  -5.3e-02  -1.4e-10   1.6e-01  -1.3e-01]
#  [ -2.4e-02  -1.2e-04   3.2e-02  -1.2e-02  -1.3e-01   2.1e-01]]
# TEST 2.60527583952
# Attempted to get min FWHM: 0.958526241891, 21.3242940278, 22.2828202697
# Attempted to get max FWHM: 3.96312011398, 19.2922646416, 23.2553847556
# FWHM = 2.605, errors -1.647, +1.358
# ../data/profiles/good-3-allback/prf_01_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 14.1129976512
# Global smoothed maximum at: 21.1694964768
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 22.67, Cu =  1.58, Cd = 7.998, wu = 0.6551, wd = 2.828, Au = 43.98
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 22.45, Cu = 1.565, Cd = 9.662, wu = 0.7185, wd = 2.059, Au = 50.38
#
# Errors: [ 0.03  0.05  0.49  0.03  0.12  1.24]
# Reduced chi-squared: 2.46307424629
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  7.7e-04   1.4e-04  -3.6e-03  -4.1e-04   1.5e-03  -9.1e-03]
#  [  1.4e-04   3.0e-03  -1.5e-10  -3.7e-04   2.7e-11   1.3e-05]
#  [ -3.6e-03  -1.5e-10   2.4e-01   2.7e-11  -5.0e-02   2.5e-01]
#  [ -4.1e-04  -3.7e-04   2.7e-11   6.4e-04  -5.9e-12  -8.0e-03]
#  [  1.5e-03   2.7e-11  -5.0e-02  -5.9e-12   1.6e-02  -1.1e-01]
#  [ -9.1e-03   1.3e-05   2.5e-01  -8.0e-03  -1.1e-01   1.5e+00]]
# TEST 2.48195712494
# Attempted to get min FWHM: 2.05901223058, 20.8189679761, 22.8779802067
# Attempted to get max FWHM: 2.88318445883, 20.1841403757, 23.0673248345
# FWHM = 2.482, errors -0.4229, +0.4012
# ../data/profiles/good-3-allback/prf_01_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 8.56860571682
# Global smoothed maximum at: 21.1694964768
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 22.67, Cu = 0.5584, Cd = 4.142, wu = 0.6431, wd = 2.148, Au = 23.46
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 22.38, Cu = 0.5498, Cd = 4.333, wu = 0.7263, wd = 1.647, Au = 27.72
#
# Errors: [ 0.04  0.03  0.13  0.03  0.09  0.87]
# Reduced chi-squared: 1.6031075642
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.3e-03   1.2e-04  -5.9e-04  -7.8e-04   1.2e-03  -1.5e-03]
#  [  1.2e-04   1.1e-03   1.7e-11  -2.8e-04  -1.9e-11   7.1e-04]
#  [ -5.9e-04   1.7e-11   1.6e-02  -8.2e-12  -6.1e-03   2.3e-02]
#  [ -7.8e-04  -2.8e-04  -8.2e-12   1.1e-03   7.4e-12  -1.1e-02]
#  [  1.2e-03  -1.9e-11  -6.1e-03   7.4e-12   7.7e-03  -4.7e-02]
#  [ -1.5e-03   7.1e-04   2.3e-02  -1.1e-02  -4.7e-02   7.7e-01]]
# TEST 1.9880965303
# Attempted to get min FWHM: 1.4816754994, 21.2813520095, 22.7630275089
# Attempted to get max FWHM: 2.45256028599, 20.5812580986, 23.0338183846
# FWHM = 1.988, errors -0.5064, +0.4645
# ../data/profiles/good-3-allback/prf_02_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 6.08247129266
# Global smoothed maximum at: 8.10996172355
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 =  9.61, Cu = 0.4267, Cd = 2.263, wu = 1.262, wd = 0.764, Au =  3.65
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 10.88, Cu = 0.4451, Cd = -3867, wu = 0.538, wd = 1.367e+04, Au = 3.028
# Errors: [  1.26e-01   2.32e-02   1.25e+07   1.23e-01   4.40e+07   2.53e-01]
# Reduced chi-squared: 0.863169883577
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.6e-02   3.5e-04  -3.1e+05  -1.2e-02   1.1e+06  -7.6e-03]
#  [  3.5e-04   5.4e-04   4.0e-01  -7.1e-04  -1.4e+00  -4.4e-04]
#  [ -3.1e+05   4.0e-01   1.6e+14  -2.1e+00  -5.5e+14   1.8e+06]
#  [ -1.2e-02  -7.1e-04  -2.1e+00   1.5e-02   7.2e+00  -2.6e-03]
#  [  1.1e+06  -1.4e+00  -5.5e+14   7.2e+00   1.9e+15  -6.2e+06]
#  [ -7.6e-03  -4.4e-04   1.8e+06  -2.6e-03  -6.2e+06   6.4e-02]]
# Cannot calculate FWHM, peak not resolved in interval
# TEST -1
# Attempted to get min FWHM: 2.92567785524, 8.12564471246, 11.0513225677
# Cannot calculate FWHM, peak not resolved in interval
# Attempted to get max FWHM: -1, 6.08247129266, 29.3986112479
# ../data/profiles/good-3-allback/prf_02_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 5.06872607722
# Global smoothed maximum at: 8.61683433127
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 10.12, Cu = 1.499, Cd = 13.89, wu = 0.9123, wd = 1.996, Au = 32.73
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 10.12, Cu =   1.5, Cd = 13.81, wu = 0.9115, wd = 2.034, Au =  32.6
#
# Errors: [ 0.04  0.04  1.41  0.03  0.47  1.42]
# Reduced chi-squared: 4.25392718972
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.0e-03   6.8e-05  -3.7e-02  -3.4e-04   1.5e-02  -5.0e-02]
#  [  6.8e-05   2.0e-03  -6.7e-11  -3.5e-04   1.8e-11  -1.3e-03]
#  [ -3.7e-02  -6.7e-11   2.0e+00   1.2e-10  -6.3e-01   1.3e+00]
#  [ -3.4e-04  -3.5e-04   1.2e-10   7.7e-04  -4.9e-11  -3.0e-03]
#  [  1.5e-02   1.8e-11  -6.3e-01  -4.9e-11   2.2e-01  -5.5e-01]
#  [ -5.0e-02  -1.3e-03   1.3e+00  -3.0e-03  -5.5e-01   2.0e+00]]
# TEST 4.40463683496
# Attempted to get min FWHM: 3.67985682977, 6.96950153832, 10.6493583681
# Attempted to get max FWHM: 4.89231849, 6.03242502641, 10.9247435164
# FWHM = 4.405, errors -0.7248, +0.4877
# ../data/profiles/good-3-allback/prf_02_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 4.05498086177
# Global smoothed maximum at: 8.61683433127
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 10.12, Cu = 0.4914, Cd = 5.998, wu = 0.8422, wd = 1.869, Au = 19.52
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 10.05, Cu = 0.4906, Cd = 6.282, wu = 0.8544, wd = 1.623, Au = 20.46
#
# Errors: [ 0.05  0.03  0.45  0.03  0.25  0.94]
# Reduced chi-squared: 2.43361006704
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.1e-03   4.9e-05  -9.4e-03  -5.1e-04   7.6e-03  -2.9e-02]
#  [  4.9e-05   6.4e-04  -4.3e-11  -2.0e-04   4.6e-11  -2.0e-04]
#  [ -9.4e-03  -4.3e-11   2.1e-01   4.2e-11  -9.8e-02   2.3e-01]
#  [ -5.1e-04  -2.0e-04   4.2e-11   1.0e-03  -3.7e-11  -4.4e-03]
#  [  7.6e-03   4.6e-11  -9.8e-02  -3.7e-11   6.2e-02  -1.8e-01]
#  [ -2.9e-02  -2.0e-04   2.3e-01  -4.4e-03  -1.8e-01   8.9e-01]]
# TEST 2.64568283552
# Attempted to get min FWHM: 2.01941763575, 8.48162202115, 10.5010396569
# Attempted to get max FWHM: 3.09708342079, 7.70794042852, 10.8050238493
# FWHM = 2.646, errors -0.6263, +0.4514
# ../data/profiles/good-3-allback/prf_03_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 4.01901280002
# Global smoothed maximum at: 7.03327240004
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 8.533, Cu = 0.5011, Cd = 2.043, wu = 0.8691, wd =   2.2, Au = 4.954
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 8.793, Cu = 0.5069, Cd = 1.629, wu = 0.7039, wd =  3.11, Au = 4.893
#
# Errors: [ 0.11  0.03  1.41  0.1   2.5   0.48]
# Reduced chi-squared: 0.961450912497
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.2e-02   2.7e-04  -6.1e-02  -6.6e-03   1.3e-01  -2.2e-02]
#  [  2.7e-04   7.5e-04  -4.6e-11  -7.1e-04   1.1e-10  -4.2e-04]
#  [ -6.1e-02  -4.6e-11   2.0e+00   2.4e-11  -3.4e+00   4.2e-01]
#  [ -6.6e-03  -7.1e-04   2.4e-11   1.0e-02  -1.1e-10  -7.3e-03]
#  [  1.3e-01   1.1e-10  -3.4e+00  -1.1e-10   6.2e+00  -8.8e-01]
#  [ -2.2e-02  -4.2e-04   4.2e-01  -7.3e-03  -8.8e-01   2.3e-01]]
# TEST 4.48053380407
# Attempted to get min FWHM: 1.64894796516, 7.32931937537, 8.97826734053
# Attempted to get max FWHM: 5.40453614543, 4.22572695877, 9.6302631042
# FWHM = 4.481, errors -2.832, +0.924
# ../data/profiles/good-3-allback/prf_03_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 4.01901280002
# Global smoothed maximum at: 7.53564900004
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 9.036, Cu =  1.76, Cd = -21.31, wu = 0.7783, wd = 8.014, Au = 40.23
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 8.824, Cu = 1.748, Cd = 5.466, wu = 0.8333, wd = 2.838, Au = 46.13
#
# Errors: [ 0.03  0.05  3.05  0.03  0.48  1.33]
# Reduced chi-squared: 1.81785592466
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.2e-03   1.5e-04  -4.6e-02  -5.2e-04   8.6e-03  -2.0e-02]
#  [  1.5e-04   2.7e-03  -1.5e-10  -4.0e-04   2.6e-12  -5.5e-04]
#  [ -4.6e-02  -1.5e-10   9.3e+00   6.4e-11  -1.4e+00   2.5e+00]
#  [ -5.2e-04  -4.0e-04   6.4e-11   8.3e-04  -9.9e-12  -7.4e-03]
#  [  8.6e-03   2.6e-12  -1.4e+00  -9.9e-12   2.3e-01  -4.7e-01]
#  [ -2.0e-02  -5.5e-04   2.5e+00  -7.4e-03  -4.7e-01   1.8e+00]]
# TEST 2.96837453638
# Attempted to get min FWHM: 2.49988671917, 6.81586137903, 9.3157480982
# Attempted to get max FWHM: 3.34043500351, 6.20350667736, 9.54394168086
# FWHM = 2.968, errors -0.4685, +0.3721
# ../data/profiles/good-3-allback/prf_03_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 3.51663620002
# Global smoothed maximum at: 8.03802560004
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 9.538, Cu = 0.5967, Cd = -138.5, wu = 0.5155, wd = 61.42, Au = 17.48
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 9.164, Cu = 0.5862, Cd = -0.5484, wu = 0.6465, wd = 3.432, Au = 22.24
# Errors: [ 0.05  0.03  1.75  0.04  0.59  0.78]
# Reduced chi-squared: 1.24450079616
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.6e-03   1.6e-04  -2.2e-02  -1.6e-03   8.8e-03  -3.8e-04]
#  [  1.6e-04   8.9e-04  -1.2e-11  -2.6e-04  -6.2e-12   2.1e-04]
#  [ -2.2e-02  -1.2e-11   3.0e+00   7.8e-11  -1.0e+00   7.4e-01]
#  [ -1.6e-03  -2.6e-04   7.8e-11   1.8e-03  -1.9e-11  -1.1e-02]
#  [  8.8e-03  -6.2e-12  -1.0e+00  -1.9e-11   3.5e-01  -3.0e-01]
#  [ -3.8e-04   2.1e-04   7.4e-01  -1.1e-02  -3.0e-01   6.1e-01]]
# TEST 2.76440210625
# Attempted to get min FWHM: 2.13709130743, 7.36851342169, 9.50560472911
# Attempted to get max FWHM: 3.2962775061, 6.4665146337, 9.7627921398
# FWHM = 2.764, errors -0.6273, +0.5319
# ../data/profiles/good-3-allback/prf_04_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 5.53445581508
# Global smoothed maximum at: 12.0751763238
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 13.58, Cu = 0.4328, Cd = 1.212, wu = 1.011, wd = 6.052, Au = 6.902
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 12.62, Cu = 0.4195, Cd = 3.231, wu = 1.282, wd =  1.16, Au = 10.85
# Errors: [ 0.05  0.02  0.1   0.06  0.1   0.34]
# Reduced chi-squared: 1.60589863574
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.0e-03   1.1e-04  -6.4e-04  -1.7e-03   1.6e-03   3.1e-03]
#  [  1.1e-04   2.6e-04   4.0e-12  -2.9e-04  -1.5e-11   4.8e-04]
#  [ -6.4e-04   4.0e-12   1.1e-02  -1.3e-11  -6.7e-03   5.4e-03]
#  [ -1.7e-03  -2.9e-04  -1.3e-11   3.1e-03   3.1e-11  -1.1e-02]
#  [  1.6e-03  -1.5e-11  -6.7e-03   3.1e-11   9.5e-03  -1.3e-02]
#  [  3.1e-03   4.8e-04   5.4e-03  -1.1e-02  -1.3e-02   1.1e-01]]
# TEST 2.33986057218
# Attempted to get min FWHM: 1.80552152308, 11.5246406249, 13.330162148
# Attempted to get max FWHM: 2.78325519959, 10.9831101142, 13.7663653138
# FWHM =  2.34, errors -0.5343, +0.4434
# ../data/profiles/good-3-allback/prf_04_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 5.03132346826
# Global smoothed maximum at: 12.0751763238
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 13.58, Cu = 1.362, Cd = 1.692, wu = 1.113, wd = 4.602, Au = 57.08
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 12.47, Cu = 1.271, Cd = 14.01, wu = 1.414, wd = 1.162, Au = 90.21
#
# Errors: [ 0.02  0.03  0.22  0.01  0.03  1.04]
# Reduced chi-squared: 5.0244459506
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.6e-04   3.2e-05  -1.1e-03  -7.9e-05   3.5e-04  -8.5e-03]
#  [  3.2e-05   8.6e-04  -1.1e-11  -1.3e-04   1.2e-12   1.3e-03]
#  [ -1.1e-03  -1.1e-11   4.8e-02   6.3e-12  -4.4e-03   7.0e-02]
#  [ -7.9e-05  -1.3e-04   6.3e-12   2.1e-04  -6.6e-13  -5.1e-03]
#  [  3.5e-04   1.2e-12  -4.4e-03  -6.6e-13   9.9e-04  -2.3e-02]
#  [ -8.5e-03   1.3e-03   7.0e-02  -5.1e-03  -2.3e-02   1.1e+00]]
# TEST 2.03723371975
# Attempted to get min FWHM: 1.90892997632, 11.4925762798, 13.4015062562
# Attempted to get max FWHM: 2.15101613324, 11.3791203801, 13.5301365134
# FWHM = 2.037, errors -0.1283, +0.1138
# ../data/profiles/good-3-allback/prf_04_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 5.03132346826
# Global smoothed maximum at: 12.5783086706
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 14.08, Cu = 0.4323, Cd = -8.72, wu = 1.133, wd = 9.893, Au = 19.89
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 12.47, Cu = 0.3974, Cd = 4.675, wu = 1.472, wd = 1.101, Au = 40.18
#
# Errors: [ 0.02  0.02  0.12  0.02  0.04  0.67]
# Reduced chi-squared: 3.24379266805
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  5.5e-04   2.8e-05  -8.6e-04  -1.7e-04   6.7e-04  -7.4e-03]
#  [  2.8e-05   2.9e-04  -1.6e-11  -1.2e-04   1.6e-12   6.1e-04]
#  [ -8.6e-04  -1.6e-11   1.5e-02   7.0e-12  -3.0e-03   2.4e-02]
#  [ -1.7e-04  -1.2e-04   7.0e-12   4.6e-04  -6.3e-13  -5.3e-03]
#  [  6.7e-04   1.6e-12  -3.0e-03  -6.3e-13   1.6e-03  -1.8e-02]
#  [ -7.4e-03   6.1e-04   2.4e-02  -5.3e-03  -1.8e-02   4.5e-01]]
# TEST 1.95220231707
# Attempted to get min FWHM: 1.77501209796, 11.6277161675, 13.4027282655
# Attempted to get max FWHM: 2.10161106025, 11.4866440357, 13.5882550959
# FWHM = 1.952, errors -0.1772, +0.1494
# ../data/profiles/good-3-allback/prf_05_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 3.49675828157
# Global smoothed maximum at: 6.99351656314
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 8.494, Cu = 0.4006, Cd = -7.025, wu = 1.061, wd = 19.92, Au = 3.142
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 8.713, Cu = 0.4125, Cd = -5239, wu = 0.8872, wd = 1.169e+04, Au = 3.111
#
# Errors: [  2.26e-01   5.61e-02   1.79e+07   2.38e-01   3.99e+07   3.80e-01]
# Reduced chi-squared: 0.431473347705
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  5.1e-02   2.4e-03  -1.3e+06  -3.7e-02   2.9e+06  -2.3e-02]
#  [  2.4e-03   3.1e-03   8.5e-01  -5.8e-03  -1.9e+00  -2.1e-03]
#  [ -1.3e+06   8.5e-01   3.2e+14  -1.4e+01  -7.1e+14   4.5e+06]
#  [ -3.7e-02  -5.8e-03  -1.4e+01   5.6e-02   3.2e+01  -1.1e-02]
#  [  2.9e+06  -1.9e+00  -7.1e+14   3.2e+01   1.6e+15  -1.0e+07]
#  [ -2.3e-02  -2.1e-03   4.5e+06  -1.1e-02  -1.0e+07   1.4e-01]]
# TEST 4.67166261017
# Attempted to get min FWHM: 2.40008869469, 6.64615575679, 9.04624445149
# Attempted to get max FWHM: 6.08297507214, 3.95616547218, 10.0391405443
# FWHM = 4.672, errors -2.272, +1.411
# ../data/profiles/good-3-allback/prf_05_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 2.9972213842
# Global smoothed maximum at: 7.4930534605
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 8.993, Cu = 1.203, Cd = -82.51, wu = 0.8282, wd =    34, Au = 23.93
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 9.083, Cu = 1.222, Cd = -180.8, wu = 0.7723, wd = 69.06, Au = 23.84
#
# Errors: [  8.20e-02   9.49e-02   9.62e+02   6.92e-02   3.38e+02   9.89e-01]
# Reduced chi-squared: 1.9566647021
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.7e-03   1.5e-03  -2.1e+01  -4.3e-03   7.6e+00  -1.4e-02]
#  [  1.5e-03   9.0e-03  -3.1e-06  -2.6e-03   1.1e-06  -4.4e-03]
#  [ -2.1e+01  -3.1e-06   9.2e+05   2.2e-06  -3.3e+05   6.6e+02]
#  [ -4.3e-03  -2.6e-03   2.2e-06   4.8e-03  -7.7e-07  -1.0e-02]
#  [  7.6e+00   1.1e-06  -3.3e+05  -7.7e-07   1.1e+05  -2.4e+02]
#  [ -1.4e-02  -4.4e-03   6.6e+02  -1.0e-02  -2.4e+02   9.8e-01]]
# TEST 4.91351877509
# Attempted to get min FWHM: 3.97785806968, 5.52346038895, 9.50131845863
# Attempted to get max FWHM: 5.56735192356, 4.26378183747, 9.83113376103
# FWHM = 4.914, errors -0.9357, +0.6538
# ../data/profiles/good-3-allback/prf_05_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 2.9972213842
# Global smoothed maximum at: 7.99259035787
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 9.493, Cu = 0.3577, Cd = -9.495, wu = 0.601, wd =  11.1, Au =  11.7
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 9.626, Cu = 0.3692, Cd = -11.09, wu = 0.5141, wd = 12.35, Au =  11.8
#
# Errors: [  0.1    0.05  16.57   0.08  11.68   0.7 ]
# Reduced chi-squared: 2.03420677948
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.0e-02   8.7e-04  -3.3e-01  -6.7e-03   2.5e-01  -2.9e-03]
#  [  8.7e-04   2.4e-03  -1.9e-08  -1.2e-03   1.3e-08  -7.9e-04]
#  [ -3.3e-01  -1.9e-08   2.7e+02   1.0e-08  -1.9e+02   7.6e+00]
#  [ -6.7e-03  -1.2e-03   1.0e-08   6.5e-03  -6.9e-09  -1.1e-02]
#  [  2.5e-01   1.3e-08  -1.9e+02  -6.9e-09   1.4e+02  -5.7e+00]
#  [ -2.9e-03  -7.9e-04   7.6e+00  -1.1e-02  -5.7e+00   4.9e-01]]
# TEST 4.11573416141
# Attempted to get min FWHM: 2.94581751123, 6.9207740027, 9.86659151393
# Attempted to get max FWHM: 5.03398697448, 5.14458826266, 10.1785752371
# FWHM = 4.116, errors - 1.17, +0.9183
# ../data/profiles/good-3-allback/prf_06_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 15.1095389611
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 16.61, Cu = 0.3765, Cd = 1.489, wu = 1.112, wd = 2.617, Au = 3.916
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 17.42, Cu = 0.3983, Cd = 0.889, wu = 0.5615, wd = 4.977, Au = 3.833
#
# Errors: [ 0.1   0.03  1.04  0.1   3.24  0.35]
# Reduced chi-squared: 1.0453049717
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.0e-02   2.6e-04  -3.4e-02  -6.3e-03   1.2e-01  -1.2e-02]
#  [  2.6e-04   7.3e-04   1.3e-10  -6.7e-04  -4.8e-10  -5.5e-04]
#  [ -3.4e-02   1.3e-10   1.1e+00  -1.8e-10  -3.3e+00   2.3e-01]
#  [ -6.3e-03  -6.7e-04  -1.8e-10   9.5e-03   6.9e-10  -3.6e-03]
#  [  1.2e-01  -4.8e-10  -3.3e+00   6.9e-10   1.0e+01  -8.4e-01]
#  [ -1.2e-02  -5.5e-04   2.3e-01  -3.6e-03  -8.4e-01   1.2e-01]]
# TEST 5.4392401646
# Attempted to get min FWHM: 2.48754522404, 15.1267514199, 17.6142966439
# Attempted to get max FWHM: 7.76021652078, 10.5302951243, 18.2905116451
# FWHM = 5.439, errors -2.952, +2.321
# ../data/profiles/good-3-allback/prf_06_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 16.1168415585
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 17.62, Cu =  1.45, Cd = -10.98, wu = 0.5993, wd = 7.488, Au = 31.41
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 17.28, Cu = 1.424, Cd = -0.0826, wu = 0.7227, wd = 3.741, Au = 36.88
#
# Errors: [ 0.04  0.05  1.4   0.03  0.35  0.87]
# Reduced chi-squared: 7.04380874618
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.4e-03   2.5e-04  -1.2e-02  -8.6e-04   3.9e-03  -1.6e-03]
#  [  2.5e-04   2.8e-03   1.1e-10  -4.9e-04  -7.1e-12  -2.7e-04]
#  [ -1.2e-02   1.1e-10   1.9e+00  -3.7e-12  -4.7e-01   6.3e-01]
#  [ -8.6e-04  -4.9e-04  -3.7e-12   1.1e-03  -7.7e-12  -8.4e-03]
#  [  3.9e-03  -7.1e-12  -4.7e-01  -7.7e-12   1.2e-01  -2.0e-01]
#  [ -1.6e-03  -2.7e-04   6.3e-01  -8.4e-03  -2.0e-01   7.6e-01]]
# TEST 3.11414981232
# Attempted to get min FWHM: 2.6849365534, 15.0467555575, 17.731692111
# Attempted to get max FWHM: 3.55430647753, 14.3512967299, 17.9056032074
# FWHM = 3.114, errors -0.4292, +0.4402
# ../data/profiles/good-3-allback/prf_06_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 16.1168415585
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 17.62, Cu = 0.4654, Cd = -1.472, wu = 0.6328, wd = 4.292, Au = 15.37
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 17.19, Cu = 0.4499, Cd = 0.7406, wu = 0.7963, wd = 2.479, Au = 18.59
#
# Errors: [ 0.05  0.03  0.41  0.05  0.21  0.63]
# Reduced chi-squared: 3.63336871152
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.9e-03   2.4e-04  -4.1e-03  -2.0e-03   3.0e-03   6.8e-03]
#  [  2.4e-04   9.4e-04   7.7e-11  -4.3e-04  -4.4e-11   8.5e-04]
#  [ -4.1e-03   7.7e-11   1.7e-01  -3.8e-11  -8.0e-02   9.6e-02]
#  [ -2.0e-03  -4.3e-04  -3.8e-11   2.4e-03   2.2e-11  -1.4e-02]
#  [  3.0e-03  -4.4e-11  -8.0e-02   2.2e-11   4.4e-02  -7.1e-02]
#  [  6.8e-03   8.5e-04   9.6e-02  -1.4e-02  -7.1e-02   3.9e-01]]
# TEST 2.39194357711
# Attempted to get min FWHM: 1.91991950333, 15.7166043685, 17.6365238718
# Attempted to get max FWHM: 2.86110756526, 15.0272677098, 17.8883752751
# FWHM = 2.392, errors -0.472, +0.4692
# ../data/profiles/good-3-allback/prf_07_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 5.99784629527
# Global smoothed maximum at: 15.9942567874
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 17.49, Cu = 0.2288, Cd = 1.321, wu = 2.146, wd = 6.589, Au = 2.652
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 18.72, Cu = 0.2607, Cd = -0.9861, wu = 1.227, wd = 32.76, Au = 2.469
#
# Errors: [  2.22e-01   2.74e-02   1.10e+01   2.11e-01   1.19e+02   2.13e-01]
# Reduced chi-squared: 2.05747139429
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  4.9e-02   9.2e-04  -8.4e-01  -3.1e-02   9.4e+00  -1.9e-02]
#  [  9.2e-04   7.5e-04  -1.1e-09  -2.2e-03   1.1e-08  -6.5e-04]
#  [ -8.4e-01  -1.1e-09   1.2e+02   1.0e-09  -1.3e+03   1.7e+00]
#  [ -3.1e-02  -2.2e-03   1.0e-09   4.5e-02  -8.1e-09  -1.3e-03]
#  [  9.4e+00   1.1e-08  -1.3e+03  -8.1e-09   1.4e+04  -1.9e+01]
#  [ -1.9e-02  -6.5e-04   1.7e+00  -1.3e-03  -1.9e+01   4.5e-02]]
# Cannot calculate FWHM, peak not resolved in interval
# TEST -1
# Attempted to get min FWHM: 6.61729716595, 12.4231059747, 19.0404031407
# Cannot calculate FWHM, peak not resolved in interval
# Attempted to get max FWHM: -1, 5.99784629527, 33.9877956732
# ../data/profiles/good-3-allback/prf_07_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 5.49802577066
# Global smoothed maximum at: 16.494077312
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 17.99, Cu = 1.108, Cd = 6.733, wu = 1.372, wd = 5.829, Au = 25.52
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 18.99, Cu = 1.226, Cd = -1.468, wu = 0.8145, wd = 13.71, Au = 23.73
#
# Errors: [ 0.04  0.05  4.69  0.04  4.07  0.7 ]
# Reduced chi-squared: 2.09883622167
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.6e-03   1.4e-04  -8.1e-02  -7.0e-04   7.7e-02  -1.5e-02]
#  [  1.4e-04   2.9e-03  -6.1e-10  -6.2e-04   5.0e-10  -2.6e-03]
#  [ -8.1e-02  -6.1e-10   2.2e+01   1.0e-10  -1.9e+01   2.4e+00]
#  [ -7.0e-04  -6.2e-04   1.0e-10   1.4e-03  -7.7e-11  -7.2e-04]
#  [  7.7e-02   5.0e-10  -1.9e+01  -7.7e-11   1.7e+01  -2.2e+00]
#  [ -1.5e-02  -2.6e-03   2.4e+00  -7.2e-04  -2.2e+00   4.9e-01]]
# TEST 9.37222774438
# Attempted to get min FWHM: 7.57970456605, 11.8518616369, 19.431566203
# Attempted to get max FWHM: 10.6391175204, 9.14653581076, 19.7856533311
# FWHM = 9.372, errors -1.793, +1.267
# ../data/profiles/good-3-allback/prf_07_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 4.99820524606
# Global smoothed maximum at: 16.9938978366
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 18.49, Cu = 0.3524, Cd = 2.231, wu = 1.343, wd = 7.009, Au = 11.27
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 19.21, Cu = 0.3864, Cd = -0.5608, wu = 0.9307, wd = 13.28, Au = 10.58
#
# Errors: [ 0.08  0.03  2.37  0.07  4.71  0.41]
# Reduced chi-squared: 1.64300461997
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.8e-03   3.0e-04  -5.7e-02  -3.9e-03   1.3e-01  -9.6e-03]
#  [  3.0e-04   9.7e-04   2.6e-10  -6.4e-04  -3.6e-10  -7.1e-04]
#  [ -5.7e-02   2.6e-10   5.6e+00   1.9e-10  -1.1e+01   6.5e-01]
#  [ -3.9e-03  -6.4e-04   1.9e-10   4.8e-03  -5.9e-10  -2.7e-03]
#  [  1.3e-01  -3.6e-10  -1.1e+01  -5.9e-10   2.2e+01  -1.4e+00]
#  [ -9.6e-03  -7.1e-04   6.5e-01  -2.7e-03  -1.4e+00   1.7e-01]]
# TEST 9.25179546415
# Attempted to get min FWHM: 6.61096384869, 13.0323204681, 19.6432843168
# Attempted to get max FWHM: 10.9587598883, 9.23713772823, 20.1958976166
# FWHM = 9.252, errors -2.641, +1.707
# ../data/profiles/good-3-allback/prf_08_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 4.55828286501
# Global smoothed maximum at: 8.10361398224
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 9.604, Cu = 0.3284, Cd = 2.535, wu = 1.303, wd = 0.6049, Au = 4.679
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 9.608, Cu = 0.3284, Cd = 2.534, wu = 1.302, wd = 0.612, Au = 4.664
#
# Errors: [ 0.25  0.02  0.14  0.1   0.46  0.91]
# Reduced chi-squared: 1.52717711077
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.4e-02   1.0e-04  -1.5e-02  -2.8e-03   1.0e-01  -2.1e-01]
#  [  1.0e-04   4.7e-04  -1.3e-11  -7.9e-04   8.4e-11  -5.0e-05]
#  [ -1.5e-02  -1.3e-11   2.0e-02   7.0e-11  -3.9e-02   5.2e-02]
#  [ -2.8e-03  -7.9e-04   7.0e-11   1.0e-02  -3.4e-10  -1.1e-02]
#  [  1.0e-01   8.4e-11  -3.9e-02  -3.4e-10   2.1e-01  -3.7e-01]
#  [ -2.1e-01  -5.0e-05   5.2e-02  -1.1e-02  -3.7e-01   8.2e-01]]
# Cannot calculate FWHM, peak not resolved in interval
# TEST -1
# Cannot calculate FWHM, peak not resolved in interval
# Attempted to get min FWHM: -1, 4.55828286501, 29.3756006856
# Cannot calculate FWHM, peak not resolved in interval
# Attempted to get max FWHM: -1, 4.55828286501, 29.3756006856
# ../data/profiles/good-3-allback/prf_08_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 4.05180699112
# Global smoothed maximum at: 8.61008985613
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 10.11, Cu =  1.34, Cd = 17.28, wu = 1.055, wd = 1.249, Au = 40.71
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 10.05, Cu = 1.338, Cd = 17.53, wu = 1.064, wd = 1.097, Au = 42.46
#
# Errors: [ 0.04  0.04  0.45  0.03  0.14  1.55]
# Reduced chi-squared: 3.09601609959
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.7e-03   7.4e-05  -7.4e-03  -3.0e-04   4.2e-03  -4.8e-02]
#  [  7.4e-05   1.9e-03  -1.1e-10  -3.4e-04   8.8e-12  -8.8e-05]
#  [ -7.4e-03  -1.1e-10   2.0e-01   2.6e-11  -4.5e-02   3.0e-01]
#  [ -3.0e-04  -3.4e-04   2.6e-11   7.2e-04   8.7e-14  -6.9e-03]
#  [  4.2e-03   8.8e-12  -4.5e-02   8.7e-14   1.9e-02  -1.7e-01]
#  [ -4.8e-02  -8.8e-05   3.0e-01  -6.9e-03  -1.7e-01   2.4e+00]]
# TEST 2.74014461018
# Attempted to get min FWHM: 2.31587832508, 8.36764904899, 10.6835273741
# Attempted to get max FWHM: 3.05976453599, 7.87718219389, 10.9369467299
# FWHM =  2.74, errors -0.4243, +0.3196
# ../data/profiles/good-3-allback/prf_08_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 3.54533111723
# Global smoothed maximum at: 9.11656573002
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 10.62, Cu = 0.4228, Cd = 5.705, wu = 0.8501, wd = 2.212, Au = 17.99
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 10.41, Cu = 0.4186, Cd = 6.307, wu = 0.9007, wd = 1.535, Au = 20.39
#
# Errors: [ 0.04  0.02  0.31  0.04  0.18  0.79]
# Reduced chi-squared: 1.4394989089
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.0e-03   8.8e-05  -4.3e-03  -8.5e-04   4.5e-03  -1.5e-02]
#  [  8.8e-05   5.7e-04  -5.2e-12  -2.4e-04  -2.5e-11   2.5e-04]
#  [ -4.3e-03  -5.2e-12   9.8e-02   8.3e-12  -4.6e-02   9.8e-02]
#  [ -8.5e-04  -2.4e-04   8.3e-12   1.4e-03   1.4e-11  -7.8e-03]
#  [  4.5e-03  -2.5e-11  -4.6e-02   1.4e-11   3.4e-02  -1.0e-01]
#  [ -1.5e-02   2.5e-04   9.8e-02  -7.8e-03  -1.0e-01   6.2e-01]]
# TEST 2.58305913952
# Attempted to get min FWHM: 1.95214685414, 8.92959529621, 10.8817421504
# Attempted to get max FWHM: 3.03905283958, 8.1663622191, 11.2054150587
# FWHM = 2.583, errors -0.6309, +0.456
# ../data/profiles/good-3-allback/prf_09_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 8.58618379588
# Global smoothed maximum at: 16.6672979567
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 18.17, Cu = 0.3511, Cd = 1.641, wu = 1.164, wd = 4.252, Au = 4.621
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 18.54, Cu = 0.3587, Cd = 1.315, wu = 0.9326, wd = 5.787, Au = 4.489
#
# Errors: [ 0.09  0.02  0.63  0.09  2.39  0.28]
# Reduced chi-squared: 0.993811433372
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  9.0e-03   1.5e-04  -2.3e-02  -4.5e-03   1.1e-01  -1.2e-02]
#  [  1.5e-04   3.9e-04   4.1e-13  -4.9e-04  -5.6e-11  -2.9e-04]
#  [ -2.3e-02   4.1e-13   4.0e-01  -8.4e-11  -1.5e+00   1.1e-01]
#  [ -4.5e-03  -4.9e-04  -8.4e-11   7.5e-03   4.6e-10  -2.3e-03]
#  [  1.1e-01  -5.6e-11  -1.5e+00   4.6e-10   5.7e+00  -5.1e-01]
#  [ -1.2e-02  -2.9e-04   1.1e-01  -2.3e-03  -5.1e-01   7.9e-02]]
# TEST 7.43000147034
# Attempted to get min FWHM: 3.99149724442, 14.8990098292, 18.8905070736
# Attempted to get max FWHM: 9.53877349439, 10.1768431808, 19.7156166752
# FWHM =  7.43, errors -3.439, +2.109
# ../data/profiles/good-3-allback/prf_09_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 9.09125343094
# Global smoothed maximum at: 17.1723675918
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 18.67, Cu = 1.303, Cd = 3.265, wu = 0.8483, wd = 5.278, Au = 43.72
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 18.59, Cu = 1.298, Cd = 5.078, wu = 0.8717, wd = 4.574, Au = 45.31
#
# Errors: [ 0.03  0.04  1.19  0.02  0.37  0.88]
# Reduced chi-squared: 3.38744420892
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.3e-04   6.4e-05  -1.3e-02  -2.5e-04   4.7e-03  -1.1e-02]
#  [  6.4e-05   1.4e-03   1.9e-10  -2.1e-04  -6.4e-11  -8.5e-04]
#  [ -1.3e-02   1.9e-10   1.4e+00  -4.2e-11  -4.2e-01   6.5e-01]
#  [ -2.5e-04  -2.1e-04  -4.2e-11   4.4e-04   1.4e-11  -2.1e-03]
#  [  4.7e-03  -6.4e-11  -4.2e-01   1.4e-11   1.4e-01  -2.5e-01]
#  [ -1.1e-02  -8.5e-04   6.5e-01  -2.1e-03  -2.5e-01   7.7e-01]]
# TEST 4.39667833377
# Attempted to get min FWHM: 3.85285041309, 15.2798036374, 19.1326540505
# Attempted to get max FWHM: 4.88540564551, 14.4310851513, 19.3164907969
# FWHM = 4.397, errors -0.5438, +0.4887
# ../data/profiles/good-3-allback/prf_09_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 9.09125343094
# Global smoothed maximum at: 17.1723675918
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 18.67, Cu = 0.4806, Cd = 0.8359, wu = 0.8685, wd = 4.714, Au = 20.49
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 18.56, Cu = 0.4782, Cd = 1.747, wu = 0.901, wd = 3.961, Au = 21.57
#
# Errors: [ 0.04  0.02  0.58  0.03  0.36  0.58]
# Reduced chi-squared: 2.48748311445
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.3e-03   6.2e-05  -8.3e-03  -5.5e-04   6.7e-03  -9.5e-03]
#  [  6.2e-05   5.4e-04  -9.2e-11  -1.9e-04   5.0e-11  -2.3e-04]
#  [ -8.3e-03  -9.2e-11   3.3e-01   3.5e-11  -2.0e-01   2.0e-01]
#  [ -5.5e-04  -1.9e-04   3.5e-11   9.1e-04  -2.1e-11  -2.6e-03]
#  [  6.7e-03   5.0e-11  -2.0e-01  -2.1e-11   1.3e-01  -1.6e-01]
#  [ -9.5e-03  -2.3e-04   2.0e-01  -2.6e-03  -1.6e-01   3.4e-01]]
# TEST 3.74656003647
# Attempted to get min FWHM: 3.09568658364, 15.9801264831, 19.0758130667
# Attempted to get max FWHM: 4.32247256908, 15.0051925075, 19.3276650766
# FWHM = 3.747, errors -0.6509, +0.5759
# ../data/profiles/good-3-allback/prf_10_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.1464933802
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 17.65, Cu = 0.3492, Cd = 2.098, wu = 0.9152, wd = 2.619, Au = 5.007
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 18.33, Cu = 0.3644, Cd = 1.623, wu = 0.483, wd = 4.301, Au = 4.941
# Errors: [ 0.12  0.03  1.    0.1   2.6   0.41]
# Reduced chi-squared: 1.07554218824
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.5e-02   3.6e-04  -2.3e-02  -9.9e-03   7.4e-02  -4.7e-03]
#  [  3.6e-04   6.3e-04  -5.1e-11  -5.5e-04   1.8e-10  -3.2e-04]
#  [ -2.3e-02  -5.1e-11   1.0e+00   3.0e-11  -2.5e+00   2.4e-01]
#  [ -9.9e-03  -5.5e-04   3.0e-11   1.0e-02  -6.8e-11  -7.9e-03]
#  [  7.4e-02   1.8e-10  -2.5e+00  -6.8e-11   6.7e+00  -7.5e-01]
#  [ -4.7e-03  -3.2e-04   2.4e-01  -7.9e-03  -7.5e-01   1.7e-01]]
# TEST 5.85264344234
# Attempted to get min FWHM: 2.14765460022, 16.3076396263, 18.4552942266
# Cannot calculate FWHM, peak not resolved in interval
# Attempted to get max FWHM: -1, 11.1007141989, 35.8250321874
# FWHM = 5.853, errors -3.705, +-6.853
# ../data/profiles/good-3-allback/prf_10_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.6510712984
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 18.15, Cu = 1.362, Cd = 10.71, wu = 0.6883, wd = 3.486, Au = 44.38
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 18.04, Cu = 1.357, Cd = 13.36, wu = 0.7137, wd = 2.583, Au = 48.02
#
# Errors: [ 0.03  0.05  1.25  0.02  0.31  1.48]
# Reduced chi-squared: 1.69563314685
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  9.1e-04   9.8e-05  -1.6e-02  -3.3e-04   5.3e-03  -2.5e-02]
#  [  9.8e-05   2.6e-03   2.5e-10  -3.1e-04  -7.1e-11  -1.2e-03]
#  [ -1.6e-02   2.5e-10   1.6e+00   7.9e-12  -3.7e-01   1.1e+00]
#  [ -3.3e-04  -3.1e-04   7.9e-12   5.7e-04  -3.6e-12  -4.3e-03]
#  [  5.3e-03  -7.1e-11  -3.7e-01  -3.6e-12   9.9e-02  -3.6e-01]
#  [ -2.5e-02  -1.2e-03   1.1e+00  -4.3e-03  -3.6e-01   2.2e+00]]
# TEST 3.50287852118
# Attempted to get min FWHM: 2.85153999, 15.600525274, 18.452065264
# Attempted to get max FWHM: 4.05355894232, 14.6087908246, 18.662349767
# FWHM = 3.503, errors -0.6513, +0.5507
# ../data/profiles/good-3-allback/prf_10_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.6510712984
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 18.15, Cu = 0.4304, Cd = 1.502, wu = 0.7537, wd = 3.947, Au = 20.38
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 17.96, Cu = 0.4264, Cd = 3.733, wu = 0.8031, wd = 2.552, Au = 22.93
#
# Errors: [ 0.05  0.03  0.75  0.04  0.35  0.9 ]
# Reduced chi-squared: 1.49184628586
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.1e-03   1.0e-04  -1.3e-02  -9.1e-04   8.1e-03  -1.7e-02]
#  [  1.0e-04   8.3e-04  -3.0e-10  -2.6e-04   1.1e-10  -5.6e-05]
#  [ -1.3e-02  -3.0e-10   5.6e-01   1.5e-10  -2.4e-01   3.7e-01]
#  [ -9.1e-04  -2.6e-04   1.5e-10   1.4e-03  -6.7e-11  -6.8e-03]
#  [  8.1e-03   1.1e-10  -2.4e-01  -6.7e-11   1.2e-01  -2.3e-01]
#  [ -1.7e-02  -5.6e-05   3.7e-01  -6.8e-03  -2.3e-01   8.1e-01]]
# TEST 2.87873229481
# Attempted to get min FWHM: 2.18145606711, 16.2018598563, 18.3833159234
# Attempted to get max FWHM: 3.47675934907, 15.2004521094, 18.6772114585
# FWHM = 2.879, errors -0.6973, +0.598
# ../data/profiles/good-3-allback/prf_11_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 4.02101327178
# Global smoothed maximum at: 9.04727986151
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 10.55, Cu = 0.3325, Cd = -24.63, wu = 0.7226, wd = 53.66, Au = 3.877
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 = 10.07, Cu = 0.3282, Cd = 0.1803, wu = 0.8893, wd = 3.446, Au = 4.853
#
# Errors: [ 0.13  0.02  0.71  0.13  1.17  0.35]
# Reduced chi-squared: 0.783514718343
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.8e-02   4.5e-04  -2.2e-02  -1.3e-02   4.4e-02   5.1e-03]
#  [  4.5e-04   5.7e-04  -3.6e-11  -8.7e-04   7.5e-11   9.4e-05]
#  [ -2.2e-02  -3.6e-11   5.1e-01  -2.9e-10  -8.1e-01   1.2e-01]
#  [ -1.3e-02  -8.7e-04  -2.9e-10   1.6e-02   4.8e-10  -1.8e-02]
#  [  4.4e-02   7.5e-11  -8.1e-01   4.8e-10   1.4e+00  -2.4e-01]
#  [  5.1e-03   9.4e-05   1.2e-01  -1.8e-02  -2.4e-01   1.2e-01]]
# TEST 3.19408894446
# Attempted to get min FWHM: 1.6948646983, 8.71302389439, 10.4078885927
# Attempted to get max FWHM: 4.2204860228, 6.88122976305, 11.1017157859
# FWHM = 3.194, errors -1.499, +1.026
# ../data/profiles/good-3-allback/prf_11_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 4.52363993076
# Global smoothed maximum at: 9.04727986151
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 10.55, Cu = 1.445, Cd = -12.51, wu = 0.6476, wd = 5.671, Au = 43.86
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 = 10.36, Cu = 1.436, Cd = 0.2437, wu = 0.6947, wd = 3.118, Au = 49.91
#
# Errors: [ 0.03  0.05  2.04  0.02  0.33  1.27]
# Reduced chi-squared: 2.63257961167
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  7.5e-04   1.2e-04  -2.2e-02  -3.5e-04   4.3e-03  -1.3e-02]
#  [  1.2e-04   2.4e-03   8.7e-11  -3.0e-04  -1.1e-11  -5.4e-04]
#  [ -2.2e-02   8.7e-11   4.2e+00  -8.4e-11  -6.5e-01   1.6e+00]
#  [ -3.5e-04  -3.0e-04  -8.4e-11   5.6e-04   1.5e-11  -5.5e-03]
#  [  4.3e-03  -1.1e-11  -6.5e-01   1.5e-11   1.1e-01  -3.1e-01]
#  [ -1.3e-02  -5.4e-04   1.6e+00  -5.5e-03  -3.1e-01   1.6e+00]]
# TEST 2.67780748151
# Attempted to get min FWHM: 2.29610487072, 8.48182371226, 10.777928583
# Attempted to get max FWHM: 3.01019388267, 7.93478854457, 10.9449824272
# FWHM = 2.678, errors -0.3817, +0.3324
# ../data/profiles/good-3-allback/prf_11_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 4.52363993076
# Global smoothed maximum at: 9.54990652049
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 11.05, Cu = 0.5315, Cd = -65.08, wu = 0.4465, wd = 30.08, Au =  17.5
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 10.75, Cu = 0.5226, Cd = -5.282, wu = 0.5531, wd = 4.797, Au = 21.41
#
# Errors: [ 0.05  0.03  2.4   0.04  0.85  0.73]
# Reduced chi-squared: 1.85897131395
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.0e-03   1.4e-04  -2.8e-02  -1.3e-03   1.1e-02  -2.9e-03]
#  [  1.4e-04   8.6e-04   1.6e-10  -2.3e-04  -6.3e-11  -5.8e-05]
#  [ -2.8e-02   1.6e-10   5.8e+00   9.3e-11  -2.0e+00   1.1e+00]
#  [ -1.3e-03  -2.3e-04   9.3e-11   1.4e-03  -3.1e-11  -6.9e-03]
#  [  1.1e-02  -6.3e-11  -2.0e+00  -3.1e-11   7.3e-01  -4.4e-01]
#  [ -2.9e-03  -5.8e-05   1.1e+00  -6.9e-03  -4.4e-01   5.4e-01]]
# TEST 2.87089756458
# Attempted to get min FWHM: 2.33144988105, 8.72797384368, 11.0594237247
# Attempted to get max FWHM: 3.4007151343, 7.85176150395, 11.2524766382
# FWHM = 2.871, errors -0.5394, +0.5298
# ../data/profiles/good-3-allback/prf_12_band_0.7-1kev.dat
# Left-of-peak smoothed minimum at: 6.01026000126
# Global smoothed maximum at: 12.0205200025
# 0.7-1kev fit (xs,x0,Cu,Cd frozen): x0 = 13.52, Cu = 0.3886, Cd = 0.1448, wu = 0.696, wd = 6.558, Au = 4.603
# 0.7-1kev fit (xs,x0,Cu,Cd thawed): x0 =  12.9, Cu = 0.3827, Cd = 1.819, wu = 0.8829, wd = 1.719, Au = 6.466
#
# Errors: [ 0.11  0.03  0.27  0.1   0.49  0.64]
# Reduced chi-squared: 0.91384330402
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.1e-02   2.3e-04  -1.1e-02  -4.3e-03   3.2e-02  -3.8e-02]
#  [  2.3e-04   1.0e-03  -6.5e-12  -9.0e-04   8.5e-12  -3.4e-04]
#  [ -1.1e-02  -6.5e-12   7.1e-02  -5.7e-11  -1.1e-01   8.4e-02]
#  [ -4.3e-03  -9.0e-04  -5.7e-11   9.0e-03   1.6e-10  -1.2e-02]
#  [  3.2e-02   8.5e-12  -1.1e-01   1.6e-10   2.4e-01  -2.4e-01]
#  [ -3.8e-02  -3.4e-04   8.4e-02  -1.2e-02  -2.4e-01   4.1e-01]]
# TEST 2.62873119048
# Attempted to get min FWHM: 0.964665572527, 12.1743829763, 13.1390485489
# Attempted to get max FWHM: 3.75236547264, 10.2097455118, 13.9621109845
# FWHM = 2.629, errors -1.664, +1.124
# ../data/profiles/good-3-allback/prf_12_band_1-2kev.dat
# Left-of-peak smoothed minimum at: 5.50940500116
# Global smoothed maximum at: 12.0205200025
# 1-2kev fit (xs,x0,Cu,Cd frozen): x0 = 13.52, Cu = 1.503, Cd = 1.348, wu = 0.6002, wd = 4.716, Au = 53.69
# 1-2kev fit (xs,x0,Cu,Cd thawed): x0 =  13.3, Cu = 1.486, Cd = 8.221, wu = 0.6646, wd = 2.929, Au = 62.04
#
# Errors: [ 0.03  0.06  1.26  0.02  0.23  1.56]
# Reduced chi-squared: 1.84552046697
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  8.4e-04   1.6e-04  -1.1e-02  -4.3e-04   2.8e-03  -1.3e-02]
#  [  1.6e-04   3.9e-03  -1.7e-10  -3.8e-04   9.5e-12  -7.6e-04]
#  [ -1.1e-02  -1.7e-10   1.6e+00   3.5e-11  -2.8e-01   1.1e+00]
#  [ -4.3e-04  -3.8e-04   3.5e-11   6.1e-04  -3.8e-12  -7.8e-03]
#  [  2.8e-03   9.5e-12  -2.8e-01  -3.8e-12   5.5e-02  -2.6e-01]
#  [ -1.3e-02  -7.6e-04   1.1e+00  -7.8e-03  -2.6e-01   2.4e+00]]
# TEST 2.97862953401
# Attempted to get min FWHM: 2.49206114, 11.1950360223, 13.6870971623
# Attempted to get max FWHM: 3.41271591371, 10.4545878634, 13.8673037771
# FWHM = 2.979, errors -0.4866, +0.4341
# ../data/profiles/good-3-allback/prf_12_band_2-7kev.dat
# Left-of-peak smoothed minimum at: 5.50940500116
# Global smoothed maximum at: 12.0205200025
# 2-7kev fit (xs,x0,Cu,Cd frozen): x0 = 13.52, Cu = 0.5068, Cd = 1.566, wu = 0.6129, wd = 3.399, Au = 29.86
# 2-7kev fit (xs,x0,Cu,Cd thawed): x0 = 13.29, Cu = 0.5002, Cd =  3.85, wu = 0.6696, wd =  2.23, Au = 35.37
#
# Errors: [ 0.04  0.04  0.52  0.03  0.18  1.2 ]
# Reduced chi-squared: 1.22355227846
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.3e-03   1.2e-04  -5.6e-03  -6.7e-04   2.9e-03  -1.1e-02]
#  [  1.2e-04   1.3e-03  -4.6e-11  -2.8e-04   3.7e-11   4.3e-04]
#  [ -5.6e-03  -4.6e-11   2.7e-01  -1.1e-11  -8.2e-02   3.0e-01]
#  [ -6.7e-04  -2.8e-04  -1.1e-11   9.5e-04   1.1e-15  -9.3e-03]
#  [  2.9e-03   3.7e-11  -8.2e-02   1.1e-15   3.2e-02  -1.5e-01]
#  [ -1.1e-02   4.3e-04   3.0e-01  -9.3e-03  -1.5e-01   1.4e+00]]
# TEST 2.30480167049
# Attempted to get min FWHM: 1.80033561997, 11.8457258414, 13.6460614613
# Attempted to get max FWHM: 2.73139976238, 11.1350658871, 13.8664656495
# FWHM = 2.305, errors -0.5045, +0.4266
