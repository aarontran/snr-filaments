# %% [markdown]
# # Profile fits and stuff

# %%
# %pylab --no-import-all
# %matplotlib inline
# ('gtk', 'inline', 'osx', 'qt', 'qt4', 'tk', 'wx')
from fplot import fplot, show_mplrc_settings

import os
import re
import scipy as sp
from scipy import optimize
from scipy import signal  # LAZINESS

import regparse  # Utility methods for region file parsing
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
show_mplrc_settings()
# Out:
# Using /Users/atran3/snr-research/code/matplotlibrc
# Font sizes for axes: 9; (x,y) ticks: (9, 9): legend 9
# Font family serif uses face ['Times']
# Figure size: (6.0, 4.0), dpi: 80

# %% [markdown]
# ## Individual profile work (i.e., fit/describe rims in each band)

# %% [markdown]
# ### Fitting functions

# %% [markdown]
# First, we need a profile function.  _Ressler et al._ [2014, _in press_] used a piecewise function to fit the upstream and downstream sides of the rim profiles:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right)
#                           + B \exp \left( \frac{-(x-x_1)^2}{2\pi \sigma^2} \right)
#                           + C_d
# \end{align*}
#
# Some outstanding questions -- how do you decide the location of up/down-stream?  Is this part of the fitting procedure?
# The peak intensity may be located at either $x_0$ or $x_1$ -- okay, seems physically reasonable given projection effects.  But how to decide where to split the fit.

# %%
# NOT FUNCTIONAL -- CONTINUITY IS NOT ENFORCED
def ressler_function(x, Au, x0, wu, Cu, xs, Ad, wd, B, x1, sigma, Cd):
    """Big fat piecewise function with a million parameters to try fitting.
    Note -- the functions should be piecewise continuous -- a constraint that has to be enforced!
    Inputs (all floats):
        x = radial position (arcsec.)
        Au, x0, wu, Cu = parameters for upstream function
        xs = location of upstream/downstream divide
        Ad, wd, B, x1, sigma, Cd = parameters for downstream function
    Output (float): value of function at radial position x
    """
    if x > xs:  # Upstream, ahead of shock
        return Au * np.exp((x0-x)/wu) + Cu
    else:
        return Ad * np.exp((x-x0)/wd) + B * np.exp( -(x-x1)**2 / (2*np.pi*sigma**2)) + Cd

# %% [markdown]
# ### Two exponential function

# %% [markdown]
# I first try a continuous piecewise two exponential function of form:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_0-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_0}{w_d}\right) + C_d
# \end{align*}
#
# where the upstream/downstream split occurs at $x=x_s$ and $x_s$ is used as a fit parameter instead of $A_u$.  Once $x_s$ is determined, $A_u$ is constrained to be:
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_0}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_0}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# Alternately we may constrain $A_d$ and use $A_u$ as a fit parameter:
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_0 - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_0 - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %%
def two_exp_function(x, xs, x0, Cu, Cd, wu, wd, Au):
    """Two exponential profile function, vectorized in x
    downstream amplitude Ad set by the split xs + continuity requirement
    """
    Ad = two_exp_function_Ad(xs, x0, Cu, Cd, wu, wd, Au)
    def two_exp_help(x, xs, x0, Cu, Cd, wu, wd, Au, Ad):
        if x > xs:  # Upstream, ahead of shock
            return Au * np.exp((x0-x)/wu) + Cu
        else:
            return Ad * np.exp((x-x0)/wd) + Cd
    two_exp_vec = np.vectorize(two_exp_help)
    return two_exp_vec(x, xs, x0, Cu, Cd, wu, wd, Au, Ad)

def two_exp_function_Au(xs, x0, Cu, Cd, wu, wd, Ad):
    """Value of Au set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xs-x0)/wu) * ( Ad * np.exp((xs-x0)/wd) + Cd - Cu )

def two_exp_function_Ad(xs, x0, Cu, Cd, wu, wd, Au):
    """Value of Ad set by split location xs + continuity requirement for two exponential function"""
    return np.exp((x0-xs)/wd) * ( Au * np.exp((x0-xs)/wu) + Cu - Cd )

# %% [markdown]
# ### Two exponential function, decoupled (one more free parameter)

# %% [markdown]
# I could also let one more parameter run free in the two exponential function:
#
# \begin{align*}
#     h_{\mathrm{up}}(x) &= A_u \exp \left(\frac{x_u-x}{w_u}\right) + C_u \\
#     h_{\mathrm{down}}(x) &= A_d \exp \left(\frac{x - x_d}{w_d}\right) + C_d
# \end{align*}
#
# Again, $x=x_s$ is a fit parameter for the upstream/downstream split, which can be used in place of $A_u$ or $A_d$.
# Because the upstream side is generally easier to fit / the data is better, it's probably better to pin $A_d$ and let $A_u$ be a free fit parameter.
#
# \begin{equation*}
#     A_u = \exp\left(\frac{x_s - x_u}{w_u}\right) \left[ A_d \exp\left(\frac{x_s - x_d}{w_d}\right) + C_d - C_u \right]
# \end{equation*}
#
# \begin{equation*}
#     A_d = \exp\left(\frac{x_d - x_s}{w_d}\right) \left[ A_u \exp\left(\frac{x_u - x_s}{w_u}\right) + C_u - C_d \right]
# \end{equation*}

# %%
def two_exp_function_dec(x, xs, xu, xd, Cu, Cd, wu, wd, Au):
    """Two exponential profile function, with one more free parameter, vectorized in x
    downstream amplitude Ad set by the split xs + continuity requirement
    """
    Ad = two_exp_function_dec_Ad(xs, xu, xd, Cu, Cd, wu, wd, Au)
    def two_exp_help(x, xs, xu, xd, Cu, Cd, wu, wd, Au, Ad):
        if x > xs:  # Upstream, ahead of shock
            return Au * np.exp((xu-x)/wu) + Cu
        else:
            return Ad * np.exp((x-xd)/wd) + Cd
    two_exp_vec = np.vectorize(two_exp_help)
    return two_exp_vec(x, xs, xu, xd, Cu, Cd, wu, wd, Au, Ad)

def two_exp_function_dec_Au(xs, xu, xd, Cu, Cd, wu, wd, Ad):
    """Value of Au set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xs-xu)/wu) * ( Ad * np.exp((xs-xd)/wd) + Cd - Cu )

def two_exp_function_dec_Ad(xs, xu, xd, Cu, Cd, wu, wd, Au):
    """Value of Ad set by split location xs + continuity requirement for two exponential function"""
    return np.exp((xd-xs)/wd) * ( Au * np.exp((xu-xs)/wu) + Cu - Cd )

# %% [markdown]
# ### Data manipulation (smooth profiles to identify minima/maxima for initial guesses, fit domain)

# %% [markdown]
# A cookbook on curve fitting with SciPy: [wiki.scipy.org/Cookbook/FittingData](http://wiki.scipy.org/Cookbook/FittingData).
#
# And, signal smoothing (maybe useful for peak/trough identification): [wiki.scipy.org/Cookbook/SignalSmooth](http://wiki.scipy.org/Cookbook/SignalSmooth).

# %%
def ind_first_smoothed_min(y):
    """Smooths data and returns index of first minimum to left of global max, in smoothed data
    If no such minimum is found, return 0 (i.e., don't cut the fit domain)"""
    # List of indices of relative minima in smoothed-y
    inds_relmin = sp.signal.argrelmin(std_smooth(y))[0]  # Unpack the tuple...
    if len(inds_relmin) is 0:
        return 0
    # Index of global (non-edge) maximum in y
    ind_max = ind_smoothed_max(y)
    
    # Want to find the largest value in inds_relmin, that's smaller than ind_max
    max_left_min = 0
    for ind_min in inds_relmin:
        if ind_min > max_left_min and ind_min < ind_max:
            max_left_min = ind_min
    
    return max_left_min


def ind_smoothed_max(y):
    """Smooths data and returns index of global maximum in smoothed data"""
    ysmooth = std_smooth(y)
    # Get indices of relative maxima
    inds_relmax = sp.signal.argrelmax(ysmooth)[0]  # Unpack the tuple...
    # Get index of the largest relative maximum
    best_ind = inds_relmax[0]
    for ind in inds_relmax[1:]:
        if ysmooth[best_ind] < ysmooth[ind]:
            best_ind = ind
    return best_ind


def std_smooth(x):
    """Standardized smoothing -- SMOOTHING WINDOW CHOICE AFFECTS FIT!!!!!"""
    wlen = 21  # Arbitrary pick
    xsmooth = smooth(x, window_len=wlen, window='hanning')
    padlen = (len(xsmooth) - len(x))/2  # Should be an integer
    return xsmooth[padlen:-padlen]


def smooth(x,window_len=11,window='hanning'):
    """stolen from scipy cookbook (reimplement whatever later)"""
    if window_len < 3:
        return x
    if not window in ['flat', 'hanning', 'hamming', 'bartlett', 'blackman']:
        raise ValueError, "Window is on of 'flat', 'hanning', 'hamming', 'bartlett', 'blackman'"
    
    s = numpy.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    if window == 'flat': #moving average
        w = numpy.ones(window_len,'d')
    else:
        w = eval('numpy.{}(window_len)'.format(window))
    
    y=numpy.convolve(w/w.sum(), s, mode='valid')
    return y

# %% [markdown]
# ### Routines to actually perform profile fit

# %% [markdown]
# Fit using two exponential model (with shared parameter $x_0$).

# %%
def fit_profile_2exp(x, y, y_err):
    """FIT THE PROFILE"""
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    ###################
    # First fit attempt
    ###################
    
    # Freeze: xs, x0
    xs_fr = x_of_max + 1.5  # Smoothing shifts peak slightly left
    x0_fr = xs_fr + 0.5  # xs left of x0 in good fit (empirically speaking)
    
    # Free parameters: x0, Cu, Cd, wu, wd, Au
    Cu_g = np.mean(y_fit[-3:])  # The obvious guess
    Cd_g = np.mean(y_fit[:3]) / 1.  # Usually shoots under trough
    wu_g = 0.5  # Upstream width
    wd_g = 2.5  # Downstream width
    Au_g = np.amax(y_fit)/3.  # Upstream amplitude
    init_guess = [Cu_g, Cd_g, wu_g, wd_g, Au_g]

    # Perform fit!
    fit_func = lambda xval, Cu,Cd,wu,wd,Au: two_exp_function(xval, xs_fr,x0_fr, Cu,Cd,wu,wd,Au)
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                       sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0,Cu,Cd frozen): xs = {:5.4g}, x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(clr, xs_fr, x0_fr, *popt)
    
    ####################
    # Second fit attempt
    ####################
    
    # Unfreeze: xs, x0, Cu, Cd
    # All parameters free
    init_guess = np.concatenate(([xs_fr, x0_fr], popt))
    
    # Perform fit!
    fit_func = two_exp_function
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True)
    print ('{} fit (xs,x0,Cu,Cd thawed): xs = {:5.4g}, x0 = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(clr, *popt)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y) - 7)  # Seven free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','x0','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, two_exp_function, leftcut

# %% [markdown]
# As above, but now for the decoupled model (modify guesses etc).

# %%
def fit_profile_2expdec(x, y, y_err):
    """FIT THE PROFILE
    
    VERY DIFFERENT METHOD THAN ABOVE
    """
    
    # Set fit domain, identify smoothed peak
    leftcut = ind_first_smoothed_min(y)
    x_fit, y_fit, y_err_fit = x[leftcut:], y[leftcut:], y_err[leftcut:]
    print 'Left-of-peak smoothed minimum at: {}'.format(x[leftcut])
    x_of_max = x[ind_smoothed_max(y)]
    print 'Global smoothed maximum at: {}'.format(x_of_max)
    
    ##################
    # Manually step xs
    ##################
    
    # Maybe pull out some old code
    
    xs_range = np.linspace(x_of_max - 1.5, x_of_max + 3.5, num=50)
    chi2_best = float('inf')
    chi2s = []
    
    for xs_fr in xs_range:
        
        # Free parameters: xu, xd, Cu, Cd, wu, wd, Au
        xu_g = xs_fr + 0.5
        xd_g = xs_fr - 0.5
        Cu_g = np.mean(y_fit[-3:])  # The obvious guess
        Cd_g = np.mean(y_fit[:3]) / 2.  # Usually shoots under trough
        wu_g = 0.5  # Upstream width
        wd_g = 2.5  # Downstream width
        Au_g = np.amax(y_fit)/3.  # Upstream amplitude
        init_guess = [xu_g, xd_g, Cu_g, Cd_g, wu_g, wd_g, Au_g]
        
        # Perform fit!
        fit_func = lambda xval, xu,xd,Cu,Cd,wu,wd,Au: two_exp_function_dec(xval, xs_fr, xu,xd,Cu,Cd,wu,wd,Au)
        popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess,
                                           sigma=y_err_fit, absolute_sigma=True,
                                           maxfev=3200)
                                           #maxfev=200*(len(init_guess)+1))  # DOUBLE THE MAX ITERATIONS to 3200
        print ('{} fit (xs frozen): xs = {:5.4g}, xu = {:5.4g}, xd = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
               'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(clr, xs_fr, *popt)
        
        # Check chi2, try to find best value of xs_fr
        chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
        chi2red = chi2 / (len(y) - 8)
        print 'chi2 = {:5.4g}, chi2red = {:5.4g}'.format(chi2, chi2red)
        chi2s.append(chi2)
        if chi2 < chi2_best:
            xs_fr_best = xs_fr
            popt_best = popt
            chi2_best = chi2
    
    # Plot the ch^2 space result
    f = plt.figure(figsize=(5,5))
    ax = f.add_subplot(111)
    ax.plot(xs_range, chi2s, '-o')
    
    # NOW, use best parameters to do stuff!
    # Unfreeze: xs
    # All parameters free
    init_guess = np.concatenate(([xs_fr_best], popt_best))

    # Perform fit!
    fit_func = two_exp_function_dec
    popt, pcov = sp.optimize.curve_fit(fit_func, x_fit, y_fit, p0=init_guess, sigma=y_err_fit, absolute_sigma=True)
    print ''
    print ('{} fit (xs thawed): xs = {:5.4g}, xu = {:5.4g}, xd = {:5.4g}, Cu = {:5.4g}, Cd = {:5.4g}, '
           'wu = {:5.4g}, wd = {:5.4g}, Au = {:5.4g}').format(clr, *popt)
    
    #######################
    # Print fit information
    #######################
    print ''
    np.set_printoptions(precision=2)
    print 'Errors: {}'.format(np.sqrt(np.diag(pcov)))
    
    chi2 = np.sum(((y_fit - fit_func(x_fit, *popt)) / y_err_fit)**2)
    chi2red = chi2 / (len(y) - 8)  # EIGHT free parameters
    print 'Reduced chi-squared: {}'.format(chi2red)

    print 'Covariance matrix, variables: ' + str(['xs','xu','xd','Cu','Cd','wu','wd','Au'])
    np.set_printoptions(precision=1)
    print pcov
    
    return popt, pcov, two_exp_function_dec, leftcut

# %% [markdown]
# ## Region work (i.e., assess energy dependence of FWHMs)

# %% [markdown]
# ## Main method

# %% [markdown]
# Structure of a region dict:
#
#     region = {'red': {},
#               'green': {},
#               'blue': {}}
#
# So that I can get useful information by, e.g., calling:
#
#     region['red']['r']  # Radial distance (units?)
#     region['green']['i']  # Intensity (units?)
#     region['blue']['fwhm']  # FWHM value (same units as radial distance)
#
# This script (as well as `ds9projplotter.py`) will need to be updated later if we are to try different energy bands.
# In principle I could deduce the bands from the filenames...

# %% [markdown]
# Roughly speaking:
# * (0.7-1 keV) count <--> 8e-9 intensity units (wat? -- this makes no sense, ask Brian what's going on)
# * (1-2 keV) count <--> 2.8e-9 intensity units
# * (2-7 keV) count <--> 5e-9 intensity units
#
# For further subdivided bands:
# * (2-3 keV) count <--> 4.5e-9 units
# * (2-4 keV) count <--> 4.5e-9 units
# * (3-4.5 keV) count <--> 4e-9 units
# * (4-7 keV) count <--> 6e-9 units
# * (4.5-7 keV) count <--> 6.5e-9 units

# %%
def get_proj_dims(regstrs):
    """Get projection dimensions from list of regions, must all be projections
    Input: list of region strings
    Output: list of 2-tuples
        1st element is length (radial distance)
        2nd element is thickness (dist. along which projection integrates)
        
    WARNING: DIMENSIONS ARE NOT THE SAME.  Length is in arcsec., thickness is in PIXELS / PHYSICAL UNITS.
    """
    pixel2arcsec = 0.5  # Chandra spatial resolution
    
    dims = []
    for line in regstrs:
        rtype, rnums, rprops = parse_regstr(line)
        if 'projection' not in rtype:
            print 'WARNING: region not of type projection encountered'
            print 'Type was: {}'.format(rtype)
        x1,y1,x2,y2,w = rnums
        length = np.sqrt((x2-x1)**2 + (y2-y1)**2) * pixel2arcsec
        dims.append((length, w))
    
    return dims

# %%
ds9physreg = '../data/regions-good-3-allback.physreg'
inroot = '../data/profiles/good-3-allback/prf'

flux2ct = [8e-9, 2.8e-9, 5e-9]

## Uncomment the appropriate set of labels / flux ct. estimates
## THREE BAND
# labels = ['0.7-1kev', '1-2kev', '2-7kev']
# flux2ct.extend([5e-9])
## FOUR BAND
labels = ['0.7-1kev', '1-2kev', '2-4kev', '4-7kev']
flux2ct.extend([4.5e-9, 6e-9])
## FIVE BAND
# labels = ['0.7-1kev', '1-2kev', '2-3kev', '3-4p5kev', '4p5-7kev']
# flux2ct.extend([4.5e-9, 4e-9, 6.5e-9])

# Count number of regions
n_regions = regparse.count_files_regexp(inroot + r'_[0-9]+_band_{}\.dat'.format(labels[0]))

# Get radial lengths of each region (convert physical pixels to arcseconds)
dims = regparse.get_proj_dims(regparse.load_ds9reg(ds9physreg))

# %%
# Process and store information on each region
for i in xrange(n_regions):
    
    region = {}
    length, thickness = dims[i]  # length is in arcsec., thickness is in PIXELS...!
    thickness = np.floor(thickness)  # Apply floor, following what DS9 does.
    # thickness is essentially integration length -- which scales errors as 1/sqrt(thickness)
    
    f, axes = plt.subplots(1, len(labels), figsize=(5*len(labels),5))
    label_axes = {lab:ax for (lab,ax) in zip(labels, axes)}
    
    for lab in labels:
        region[clr] = {}  # Energy band dictionary
        ax = eval('ax_{}'.format(clr))  # Subplot axis
        flux2ct = eval('flux2ct_{}'.format(clr))  # Ad hoc flux-count conversion
        
        ########################
        # Import projection data
        ########################
        infile = '{0}_{1:02d}_{2}.dat'.format(inroot, i+1, clr)
        print infile
        data = np.loadtxt(infile)
        x = (data[:,0] - 1) * length / (len(data[:,0]) - 0.9)  # Convert to arcsec
        # Intensity units
        # y = data[:,1]
        # y_err = 1./flux2ct * np.sqrt( y * flux2ct / thickness )
        # Est. count units
        y = data[:,1] * flux2ct
        y_err = np.sqrt(y / thickness)
        
        ################################
        # Apply fit to profiles and save
        # fit parameters/errors/chi^2
        ################################
        popt, pcov, fit_func, cut = fit_profile_2exp(x, y, y_err)
        x_fit, y_fit, y_err_fit = x[cut:], y[cut:], y_err[cut:]
        
        ####################################
        # Calculate FWHM (from fit function)
        ####################################
        # Note -- you cannot extrapolate outside the fit domain.
        # The FWHM must reside "within" the data.
        
        # FWHM calculation needs fit_func, x_fit, xs
        
        xs = popt[0]  # Call signature: two_exp_function(x, xs, x0, Cu, Cd, wu, wd, Au):
        
        y_min_left = fit_func(x_fit[0], *popt)
        y_max = fit_func(xs, *popt)
        y_halfmax = y_max / 2.
        print cut
        print y_min_left, y_max
        
        if y_min_left >= y_halfmax:
            print 'Cannot calculate FWHM, peak insufficiently resolved'
            region[clr]['fwhm'] = None
        else:
            x_left = sp.optimize.brentq(lambda x: fit_func(x, *popt) - y_halfmax, x_fit[0], xs)
            x_right = sp.optimize.brentq(lambda x: fit_func(x, *popt) - y_halfmax, xs, x_fit[-1])
            fwhm = region[clr]['fwhm'] = x_right - x_left
            print 'FWHM = {:5.4g}, interval [{:5.4g}, {:5.4g}]'.format(fwhm, x_left, x_right)
        print ''
        
        ###############################
        # Calculate uncertainty in FWHM
        ###############################
        
        # Lalalala
        
        ################################
        # Plot the data and fits
        ################################
        ax.errorbar(x[:cut], y[:cut], yerr=y_err[:cut], fmt=clr[0]+'x', alpha=0.4)  # Data NOT used in fit
        ax.errorbar(x_fit, y_fit, yerr=y_err_fit, fmt=clr[0]+'o', alpha=0.7)  # Data used in fit
        ax.plot(x, std_smooth(y), '-y', alpha = 0.4)  # Smoothed data used to help fit
        x_m = np.linspace(x[0], x[-1], num=200)  # x values for best fit model
        ax.plot(x_m, fit_func(x_m, *popt), '-k', alpha=0.7)  # Best fit model
    
    # Show the profile plots
    plt.show()
    
    # Plot FWHM dependence
    plt.figure(figsize=(5,5))
    for clr, n in zip(['red', 'green', 'blue'], [1,2,3]):
        fwhm = region[clr]['fwhm']
        if fwhm is not None:
            plt.plot(n, fwhm, clr[0]+'o')
    plt.xlim([0,4])
    plt.show()
    print ''
    
    # Do stuff to estimate FWHM dependence

# Compute average values of FWHM-energy scaling
# Out:
# ../data/profiles/good-3-allback/prf_01_red.dat
# Left-of-peak smoothed minimum at: 15.121068912
# Global smoothed maximum at: 21.1694964768
# red fit (xs,x0,Cu,Cd frozen): xs = 22.67, x0 = 23.17, Cu = 0.4049, Cd = 0.8978, wu = 0.7783, wd =  4.59, Au =  1.87
# red fit (xs,x0,Cu,Cd thawed): xs = 22.01, x0 = 22.57, Cu = 0.3991, Cd = 1.602, wu = 0.9831, wd = 1.474, Au = 2.784
# Errors: [  1.21e-01   4.41e+06   2.81e-02   1.71e-01   1.08e-01   4.16e-01
#    1.25e+07]
# Reduced chi-squared: 0.502740259644
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.5e-02  -2.2e+05   1.3e-04  -7.5e-03  -5.2e-03   3.2e-02   6.2e+05]
#  [ -2.2e+05   1.9e+13   1.1e+04   9.9e+04  -1.3e+04  -5.0e+05  -5.5e+13]
#  [  1.3e-04   1.1e+04   7.9e-04   5.6e-05  -1.0e-03  -2.8e-04  -3.1e+04]
#  [ -7.5e-03   9.9e+04   5.6e-05   2.9e-02  -6.6e-05  -5.6e-02  -2.8e+05]
#  [ -5.2e-03  -1.3e+04  -1.0e-03  -6.6e-05   1.2e-02   3.3e-04   3.7e+04]
#  [  3.2e-02  -5.0e+05  -2.8e-04  -5.6e-02   3.3e-04   1.7e-01   1.4e+06]
#  [  6.2e+05  -5.5e+13  -3.1e+04  -2.8e+05   3.7e+04   1.4e+06   1.6e+14]]
# 30
# 1.6366670338 5.35586931539
# FWHM = 2.605, interval [20.17, 22.77]
#
# ../data/profiles/good-3-allback/prf_01_green.dat
# Left-of-peak smoothed minimum at: 14.1129976512
# Global smoothed maximum at: 21.1694964768
# green fit (xs,x0,Cu,Cd frozen): xs = 22.67, x0 = 23.17, Cu =  1.58, Cd = 7.998, wu = 0.6551, wd = 2.828, Au =  20.5
# green fit (xs,x0,Cu,Cd thawed): xs = 22.45, x0 = 23.11, Cu = 1.565, Cd = 9.663, wu = 0.7185, wd = 2.059, Au = 20.21
# Errors: [ 0.03   nan  0.05  0.48  0.03  0.12   nan]
# Reduced chi-squared: 1.52641221047
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.8e-04  -7.0e+03   1.6e-04  -3.0e-03  -4.1e-04   1.3e-03   2.0e+05]
#  [ -7.0e+03  -5.5e+11   1.5e+03   4.7e+04  -1.6e+02  -1.8e+04   1.5e+13]
#  [  1.6e-04   1.5e+03   3.0e-03  -1.3e-04  -3.7e-04   4.8e-05  -4.2e+04]
#  [ -3.0e-03   4.7e+04  -1.3e-04   2.3e-01   1.4e-05  -4.9e-02  -1.3e+06]
#  [ -4.1e-04  -1.6e+02  -3.7e-04   1.4e-05   6.4e-04  -5.3e-06   4.6e+03]
#  [  1.3e-03  -1.8e+04   4.8e-05  -4.9e-02  -5.3e-06   1.5e-02   5.0e+05]
#  [  2.0e+05   1.5e+13  -4.2e+04  -1.3e+06   4.6e+03   5.0e+05  -4.3e+14]]
# 28
# 10.3990207424 51.9422976615
# FWHM = 2.482, interval [20.49, 22.97]
#
# ../data/profiles/good-3-allback/prf_01_blue.dat
# Left-of-peak smoothed minimum at: 8.56860571682
# Global smoothed maximum at: 21.1694964768
# blue fit (xs,x0,Cu,Cd frozen): xs = 22.67, x0 = 23.17, Cu = 0.5584, Cd = 4.142, wu = 0.6431, wd = 2.148, Au = 10.78
# blue fit (xs,x0,Cu,Cd thawed): xs = 22.38, x0 = 22.71, Cu = 0.5498, Cd = 4.333, wu = 0.7263, wd = 1.647, Au = 17.76
# Errors: [ 0.02   nan  0.03  0.05  0.03  0.08   nan]
# Reduced chi-squared: 1.24184388754
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  5.7e-04  -1.5e+05   1.1e-04   2.6e-03  -4.4e-04   1.4e-04   3.7e+06]
#  [ -1.5e+05  -3.1e+13  -1.7e+03   6.5e+05   6.9e+04  -2.2e+05   7.6e+14]
#  [  1.1e-04  -1.7e+03   1.1e-03   3.6e-05  -2.8e-04  -1.2e-05   4.2e+04]
#  [  2.6e-03   6.5e+05   3.6e-05   2.3e-03  -1.4e-03  -1.5e-03  -1.6e+07]
#  [ -4.4e-04   6.9e+04  -2.8e-04  -1.4e-03   9.8e-04   4.9e-04  -1.7e+06]
#  [  1.4e-04  -2.2e+05  -1.2e-05  -1.5e-03   4.9e-04   6.2e-03   5.4e+06]
#  [  3.7e+06   7.6e+14   4.2e+04  -1.6e+07  -1.7e+06   5.4e+06  -1.8e+16]]
# 17
# 4.3381006087 28.2670559014
# FWHM = 1.988, interval [20.91,  22.9]
# ../data/profiles/good-3-allback/prf_02_red.dat
# Left-of-peak smoothed minimum at: 6.08247129266
# Global smoothed maximum at: 8.10996172355
# red fit (xs,x0,Cu,Cd frozen): xs =  9.61, x0 = 10.11, Cu = 0.4267, Cd = 2.263, wu = 1.262, wd = 0.7641, Au = 2.456
# red fit (xs,x0,Cu,Cd thawed): xs = 10.61, x0 = 10.63, Cu = 0.4415, Cd = 0.2075, wu = 0.697, wd = 7.962, Au = 3.048
# Errors: [  1.17e-01        nan   2.34e-02   8.83e+00   9.82e-02   2.85e+01
#         nan]
# Reduced chi-squared: 0.72581764758
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.4e-02  -1.4e+05   1.3e-04  -6.8e-01  -3.6e-03   2.3e+00   6.3e+05]
#  [ -1.4e+05  -2.5e+13   2.1e+03  -2.1e+06   6.7e+04   1.1e+07   1.1e+14]
#  [  1.3e-04   2.1e+03   5.5e-04   1.8e-04  -6.5e-04  -8.9e-04  -9.2e+03]
#  [ -6.8e-01  -2.1e+06   1.8e-04   7.8e+01   5.6e-03  -2.5e+02   9.2e+06]
#  [ -3.6e-03   6.7e+04  -6.5e-04   5.6e-03   9.6e-03  -2.8e-02  -2.9e+05]
#  [  2.3e+00   1.1e+07  -8.9e-04  -2.5e+02  -2.8e-02   8.1e+02  -4.6e+07]
#  [  6.3e+05   1.1e+14  -9.2e+03   9.2e+06  -2.9e+05  -4.6e+07  -4.8e+14]]
# 12
# 2.12155158104 3.58822886699
# Cannot calculate FWHM, peak insufficiently resolved
#
# ../data/profiles/good-3-allback/prf_02_green.dat
# Left-of-peak smoothed minimum at: 5.06872607722
# Global smoothed maximum at: 8.61683433127
# green fit (xs,x0,Cu,Cd frozen): xs = 10.12, x0 = 10.62, Cu = 1.499, Cd = 13.89, wu = 0.9123, wd = 1.996, Au = 18.92
# green fit (xs,x0,Cu,Cd thawed): xs = 10.12, x0 = 10.61, Cu =   1.5, Cd = 13.81, wu = 0.9115, wd = 2.034, Au = 19.02
# Errors: [  4.71e-02   1.73e+06   4.45e-02   1.41e+00   2.95e-02   4.73e-01
#    3.60e+07]
# Reduced chi-squared: 3.51767057054
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.2e-03  -2.7e+04   8.9e-05  -3.8e-02  -4.9e-04   1.6e-02   5.5e+05]
#  [ -2.7e+04   3.0e+12  -2.5e+03   1.1e+05   1.8e+04  -5.8e+04  -6.2e+13]
#  [  8.9e-05  -2.5e+03   2.0e-03  -9.4e-05  -3.6e-04   4.8e-05   5.1e+04]
#  [ -3.8e-02   1.1e+05  -9.4e-05   2.0e+00   6.7e-04  -6.3e-01  -2.4e+06]
#  [ -4.9e-04   1.8e+04  -3.6e-04   6.7e-04   8.7e-04  -3.4e-04  -3.6e+05]
#  [  1.6e-02  -5.8e+04   4.8e-05  -6.3e-01  -3.4e-04   2.2e-01   1.2e+06]
#  [  5.5e+05  -6.2e+13   5.1e+04  -2.4e+06  -3.6e+05   1.2e+06   1.3e+15]]
# 10
# 15.4976846673 34.0963988319
# FWHM = 4.405, interval [6.392,  10.8]
#
# ../data/profiles/good-3-allback/prf_02_blue.dat
# Left-of-peak smoothed minimum at: 4.05498086177
# Global smoothed maximum at: 8.61683433127
# blue fit (xs,x0,Cu,Cd frozen): xs = 10.12, x0 = 10.62, Cu = 0.4914, Cd = 5.998, wu = 0.8422, wd = 1.869, Au = 10.78
# blue fit (xs,x0,Cu,Cd thawed): xs = 10.05, x0 = 10.22, Cu = 0.4906, Cd = 6.282, wu = 0.8544, wd = 1.623, Au = 16.77
# Errors: [ 0.05   nan  0.03  0.44  0.03  0.24   nan]
# Reduced chi-squared: 2.10600871201
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.1e-03   7.0e+03   4.9e-05  -1.0e-02  -5.0e-04   7.9e-03  -1.4e+05]
#  [  7.0e+03  -1.8e+12  -2.4e+02   1.5e+05  -2.7e+03  -8.5e+04   3.6e+13]
#  [  4.9e-05  -2.4e+02   6.4e-04   2.0e-05  -2.0e-04  -1.2e-05   4.8e+03]
#  [ -1.0e-02   1.5e+05   2.0e-05   1.9e-01   2.2e-04  -9.1e-02  -2.9e+06]
#  [ -5.0e-04  -2.7e+03  -2.0e-04   2.2e-04   1.0e-03  -1.3e-04   5.3e+04]
#  [  7.9e-03  -8.5e+04  -1.2e-05  -9.1e-02  -1.3e-04   5.8e-02   1.7e+06]
#  [ -1.4e+05   3.6e+13   4.8e+03  -2.9e+06   5.3e+04   1.7e+06  -7.0e+14]]
# 8
# 6.6461075427 20.9476734155
# FWHM = 2.646, interval [8.019, 10.66]
# ../data/profiles/good-3-allback/prf_03_red.dat
# Left-of-peak smoothed minimum at: 4.01901280002
# Global smoothed maximum at: 7.03327240004
# red fit (xs,x0,Cu,Cd frozen): xs = 8.533, x0 = 9.033, Cu = 0.5011, Cd = 2.043, wu = 0.8691, wd =   2.2, Au = 2.787
# red fit (xs,x0,Cu,Cd thawed): xs = 8.793, x0 = 9.107, Cu = 0.5069, Cd =  1.63, wu = 0.7039, wd = 3.109, Au = 3.133
#
# Errors: [ 0.1    nan  0.03  1.39  0.1   2.48   nan]
# Reduced chi-squared: 0.826847787776
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  9.6e-03  -2.6e+05   2.2e-04  -5.0e-02  -6.1e-03   1.1e-01   1.2e+06]
#  [ -2.6e+05  -2.6e+13  -5.1e+03   1.1e+06   4.8e+04  -1.2e+06   1.1e+14]
#  [  2.2e-04  -5.1e+03   7.5e-04   2.2e-04  -7.0e-04  -2.4e-04   2.3e+04]
#  [ -5.0e-02   1.1e+06   2.2e-04   1.9e+00  -2.0e-03  -3.4e+00  -4.8e+06]
#  [ -6.1e-03   4.8e+04  -7.0e-04  -2.0e-03   1.0e-02   2.3e-03  -2.1e+05]
#  [  1.1e-01  -1.2e+06  -2.4e-04  -3.4e+00   2.3e-03   6.2e+00   5.4e+06]
#  [  1.2e+06   1.1e+14   2.3e+04  -4.8e+06  -2.1e+05   5.4e+06  -5.1e+14]]
# 8
# 2.44175929957 5.3999773242
# FWHM =  4.48, interval [4.878, 9.358]
#
# ../data/profiles/good-3-allback/prf_03_green.dat
# Left-of-peak smoothed minimum at: 4.01901280002
# Global smoothed maximum at: 7.53564900004
# green fit (xs,x0,Cu,Cd frozen): xs = 9.036, x0 = 9.536, Cu =  1.76, Cd = -21.31, wu = 0.7783, wd = 8.015, Au = 21.16
# green fit (xs,x0,Cu,Cd thawed): xs = 8.824, x0 = 9.236, Cu = 1.748, Cd = 5.466, wu = 0.8333, wd = 2.838, Au = 28.13
#
# Errors: [ 0.03   nan  0.05  3.05  0.03  0.48   nan]
# Reduced chi-squared: 1.56335609531
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.2e-03  -2.8e+03   1.5e-04  -4.6e-02  -5.2e-04   8.5e-03   9.5e+04]
#  [ -2.8e+03  -6.5e+11  -4.3e+02  -1.8e+03   1.6e+03  -2.6e+03   2.2e+13]
#  [  1.5e-04  -4.3e+02   2.7e-03  -1.2e-06  -3.9e-04  -1.7e-06   1.4e+04]
#  [ -4.6e-02  -1.8e+03  -1.2e-06   9.3e+00   4.5e-06  -1.4e+00   6.1e+04]
#  [ -5.2e-04   1.6e+03  -3.9e-04   4.5e-06   8.2e-04   6.5e-06  -5.5e+04]
#  [  8.5e-03  -2.6e+03  -1.7e-06  -1.4e+00   6.5e-06   2.3e-01   8.8e+04]
#  [  9.5e+04   2.2e+13   1.4e+04   6.1e+04  -5.5e+04   8.8e+04  -7.5e+14]]
# 8
# 13.2683292699 47.8793331732
# FWHM = 2.968, interval [6.465, 9.433]
#
# ../data/profiles/good-3-allback/prf_03_blue.dat
# Left-of-peak smoothed minimum at: 3.51663620002
# Global smoothed maximum at: 8.03802560004
# blue fit (xs,x0,Cu,Cd frozen): xs = 9.538, x0 = 10.04, Cu = 0.5967, Cd = -138.5, wu = 0.5155, wd = 61.38, Au = 6.627
# blue fit (xs,x0,Cu,Cd thawed): xs = 9.164, x0 = 10.13, Cu = 0.5862, Cd = -0.5484, wu = 0.6465, wd = 3.432, Au = 4.963
# Errors: [  5.12e-02   6.77e+05   2.98e-02   1.75e+00   4.20e-02   5.91e-01
#    5.20e+06]
# Reduced chi-squared: 1.09516070066
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.6e-03   3.7e+03   1.6e-04  -2.2e-02  -1.6e-03   9.1e-03  -2.9e+04]
#  [  3.7e+03   4.6e+11  -5.0e+01  -7.7e+04   6.2e+02   3.2e+04  -3.5e+12]
#  [  1.6e-04  -5.0e+01   8.9e-04   8.5e-06  -2.6e-04  -3.5e-06   3.9e+02]
#  [ -2.2e-02  -7.7e+04   8.5e-06   3.1e+00  -1.0e-04  -1.0e+00   5.9e+05]
#  [ -1.6e-03   6.2e+02  -2.6e-04  -1.0e-04   1.8e-03   4.2e-05  -4.7e+03]
#  [  9.1e-03   3.2e+04  -3.5e-06  -1.0e+00   4.2e-05   3.5e-01  -2.4e+05]
#  [ -2.9e+04  -3.5e+12   3.9e+02   5.9e+05  -4.7e+03  -2.4e+05   2.7e+13]]
# 7
# 3.96051490905 22.8277934555
# FWHM = 2.764, interval [6.865, 9.629]
# ../data/profiles/good-3-allback/prf_04_red.dat
# Left-of-peak smoothed minimum at: 5.53445581508
# Global smoothed maximum at: 12.0751763238
# red fit (xs,x0,Cu,Cd frozen): xs = 13.58, x0 = 14.08, Cu = 0.4328, Cd = 1.212, wu = 1.011, wd = 6.052, Au = 4.208
# red fit (xs,x0,Cu,Cd thawed): xs = 12.62, x0 = 13.75, Cu = 0.4195, Cd = 3.231, wu = 1.282, wd =  1.16, Au = 4.478
# Errors: [  4.55e-02   1.97e+06   1.61e-02   1.05e-01   5.57e-02   9.80e-02
#    6.90e+06]
# Reduced chi-squared: 1.33824886322
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.1e-03  -9.7e+03   1.1e-04  -6.8e-04  -1.7e-03   1.6e-03   3.4e+04]
#  [ -9.7e+03   3.9e+12  -1.2e+03   1.7e+04   7.5e+03  -1.8e+04  -1.4e+13]
#  [  1.1e-04  -1.2e+03   2.6e-04  -5.4e-06  -2.9e-04   5.8e-06   4.3e+03]
#  [ -6.8e-04   1.7e+04  -5.4e-06   1.1e-02   3.3e-05  -6.8e-03  -5.9e+04]
#  [ -1.7e-03   7.5e+03  -2.9e-04   3.3e-05   3.1e-03  -3.5e-05  -2.6e+04]
#  [  1.6e-03  -1.8e+04   5.8e-06  -6.8e-03  -3.5e-05   9.6e-03   6.4e+04]
#  [  3.4e+04  -1.4e+13   4.3e+03  -5.9e+04  -2.6e+04   6.4e+04   4.8e+13]]
# 11
# 3.24907631051 11.2699017898
# FWHM =  2.34, interval [11.22, 13.56]
#
# ../data/profiles/good-3-allback/prf_04_green.dat
# Left-of-peak smoothed minimum at: 5.03132346826
# Global smoothed maximum at: 12.0751763238
# green fit (xs,x0,Cu,Cd frozen): xs = 13.58, x0 = 14.08, Cu = 1.362, Cd = 1.693, wu = 1.113, wd = 4.602, Au = 36.42
# green fit (xs,x0,Cu,Cd thawed): xs = 12.61, x0 = 14.72, Cu =  1.29, Cd = 13.37, wu = 1.363, wd =  1.36, Au = 18.39
# Errors: [  1.50e-02   5.08e+05   2.94e-02   2.31e-01   1.74e-02   2.90e-02
#    6.86e+06]
# Reduced chi-squared: 4.80793355153
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.3e-04   7.2e+02   6.3e-05  -5.5e-04  -1.7e-04   1.7e-04  -9.7e+03]
#  [  7.2e+02   2.6e+11  -8.8e+01  -3.4e+03   2.1e+02   6.7e+02  -3.5e+12]
#  [  6.3e-05  -8.8e+01   8.7e-04   1.2e-06  -1.7e-04  -2.3e-07   1.2e+03]
#  [ -5.5e-04  -3.4e+03   1.2e-06   5.3e-02  -2.8e-06  -4.6e-03   4.7e+04]
#  [ -1.7e-04   2.1e+02  -1.7e-04  -2.8e-06   3.0e-04   5.4e-07  -2.8e+03]
#  [  1.7e-04   6.7e+02  -2.3e-07  -4.6e-03   5.4e-07   8.4e-04  -9.1e+03]
#  [ -9.7e+03  -3.5e+12   1.2e+03   4.7e+04  -2.8e+03  -9.1e+03   4.7e+13]]
# 10
# 13.6496529817 87.6152188819
# FWHM = 2.178, interval [ 11.4, 13.58]
#
# ../data/profiles/good-3-allback/prf_04_blue.dat
# Left-of-peak smoothed minimum at: 5.03132346826
# Global smoothed maximum at: 12.5783086706
# blue fit (xs,x0,Cu,Cd frozen): xs = 14.08, x0 = 14.58, Cu = 0.4323, Cd = -8.715, wu = 1.133, wd =  9.89, Au = 12.79
# blue fit (xs,x0,Cu,Cd thawed): xs = 12.61, x0 = 15.71, Cu = 0.4054, Cd = 4.432, wu = 1.422, wd = 1.282, Au = 4.364
# Errors: [ 0.02   nan  0.02  0.13  0.03  0.04   nan]
# Reduced chi-squared: 3.01419817077
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  4.0e-04   6.8e+03   5.0e-05  -3.9e-04  -3.1e-04   2.9e-04  -2.1e+04]
#  [  6.8e+03  -9.1e+11   4.2e+02  -3.4e+03  -3.4e+03   2.7e+03   2.8e+12]
#  [  5.0e-05   4.2e+02   2.9e-04   1.6e-06  -1.4e-04  -1.2e-06  -1.3e+03]
#  [ -3.9e-04  -3.4e+03   1.6e-06   1.7e-02  -1.3e-05  -3.1e-03   1.0e+04]
#  [ -3.1e-04  -3.4e+03  -1.4e-04  -1.3e-05   6.4e-04   1.0e-05   1.1e+04]
#  [  2.9e-04   2.7e+03  -1.2e-06  -3.1e-03   1.0e-05   1.3e-03  -8.3e+03]
#  [ -2.1e+04   2.8e+12  -1.3e+03   1.0e+04   1.1e+04  -8.3e+03  -8.6e+12]]
# 10
# 4.52535062746 38.9361253394
# FWHM = 2.066, interval [11.55, 13.61]
# ../data/profiles/good-3-allback/prf_05_red.dat
# Left-of-peak smoothed minimum at: 3.49675828157
# Global smoothed maximum at: 6.99351656314
# red fit (xs,x0,Cu,Cd frozen): xs = 8.494, x0 = 8.994, Cu = 0.4875, Cd = 1.452, wu =   0.5, wd =   2.5, Au = 1.375
# red fit (xs,x0,Cu,Cd thawed): xs = 8.494, x0 = 8.994, Cu = 0.4875, Cd = 1.452, wu =   0.5, wd =   2.5, Au = 1.375
#
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: inf
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# 7
# 1.82788415388 4.2248600507
# FWHM = 4.004, interval [4.906,  8.91]
#
# ../data/profiles/good-3-allback/prf_05_green.dat
# Left-of-peak smoothed minimum at: 2.9972213842
# Global smoothed maximum at: 7.4930534605
# green fit (xs,x0,Cu,Cd frozen): xs = 8.993, x0 = 9.493, Cu = 1.203, Cd = -82.5, wu = 0.8282, wd =    34, Au = 13.08
# green fit (xs,x0,Cu,Cd thawed): xs = 9.083, x0 = 9.521, Cu = 1.222, Cd = -180.8, wu = 0.7723, wd = 69.05, Au = 13.52
# Errors: [  8.32e-02   4.33e+05   9.49e-02   9.74e+02   6.92e-02   3.43e+02
#    7.57e+06]
# Reduced chi-squared: 1.65093584251
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.9e-03  -6.2e+03   1.5e-03  -2.0e+01  -4.3e-03   7.0e+00   1.1e+05]
#  [ -6.2e+03   1.9e+11   8.0e+01  -5.8e+07  -3.0e+02   2.1e+07  -3.3e+12]
#  [  1.5e-03   8.0e+01   9.0e-03  -2.5e-02  -2.6e-03   9.1e-03  -1.4e+03]
#  [ -2.0e+01  -5.8e+07  -2.5e-02   9.5e+05   9.2e-02  -3.3e+05   1.0e+09]
#  [ -4.3e-03  -3.0e+02  -2.6e-03   9.2e-02   4.8e-03  -3.3e-02   5.2e+03]
#  [  7.0e+00   2.1e+07   9.1e-03  -3.3e+05  -3.3e-02   1.2e+05  -3.7e+08]
#  [  1.1e+05  -3.3e+12  -1.4e+03   1.0e+09   5.2e+03  -3.7e+08   5.7e+13]]
# 6
# 7.69945895484 25.0621376473
# FWHM = 4.914, interval [4.745, 9.659]
#
# ../data/profiles/good-3-allback/prf_05_blue.dat
# Left-of-peak smoothed minimum at: 2.9972213842
# Global smoothed maximum at: 7.99259035787
# blue fit (xs,x0,Cu,Cd frozen): xs = 9.493, x0 = 9.993, Cu = 0.3577, Cd = -9.495, wu = 0.601, wd =  11.1, Au = 5.094
# blue fit (xs,x0,Cu,Cd thawed): xs = 9.626, x0 = 10.03, Cu = 0.3692, Cd = -11.09, wu = 0.5141, wd = 12.34, Au = 5.395
#
# Errors: [  1.02e-01   5.00e+05   4.93e-02   1.71e+01   8.05e-02   1.20e+01
#    5.23e+06]
# Reduced chi-squared: 1.7163619707
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.0e-02  -3.3e+03   8.7e-04  -3.6e-01  -6.7e-03   2.7e-01   3.5e+04]
#  [ -3.3e+03   2.5e+11   2.6e+01   2.0e+06   1.8e+02  -1.4e+06  -2.6e+12]
#  [  8.7e-04   2.6e+01   2.4e-03   2.0e-04  -1.2e-03  -1.4e-04  -2.7e+02]
#  [ -3.6e-01   2.0e+06   2.0e-04   2.9e+02   1.4e-03  -2.0e+02  -2.1e+07]
#  [ -6.7e-03   1.8e+02  -1.2e-03   1.4e-03   6.5e-03  -9.8e-04  -1.9e+03]
#  [  2.7e-01  -1.4e+06  -1.4e-04  -2.0e+02  -9.8e-04   1.4e+02   1.4e+07]
#  [  3.5e+04  -2.6e+12  -2.7e+02  -2.1e+07  -1.9e+03   1.4e+07   2.7e+13]]
# 6
# 2.50392032728 12.1685982123
# FWHM = 4.116, interval [5.883, 9.998]
# ../data/profiles/good-3-allback/prf_06_red.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 15.1095389611
# red fit (xs,x0,Cu,Cd frozen): xs = 16.61, x0 = 17.11, Cu = 0.3765, Cd = 1.489, wu = 1.112, wd = 2.617, Au = 2.498
# red fit (xs,x0,Cu,Cd thawed): xs = 17.42, x0 = 17.47, Cu = 0.3983, Cd = 0.8889, wu = 0.5615, wd = 4.977, Au = 3.544
#
# Errors: [  1.35e-01   1.14e+07   2.73e-02   1.61e+00   1.07e-01   5.65e+00
#    7.21e+07]
# Reduced chi-squared: 0.696869981873
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.8e-02   1.0e+06   6.4e-04  -1.4e-01  -1.0e-02   5.4e-01  -6.5e+06]
#  [  1.0e+06   1.3e+14   4.8e+04  -1.4e+07  -5.2e+05   5.3e+07  -8.2e+14]
#  [  6.4e-04   4.8e+04   7.5e-04  -5.2e-03  -8.6e-04   2.0e-02  -3.1e+05]
#  [ -1.4e-01  -1.4e+07  -5.2e-03   2.6e+00   5.5e-02  -9.0e+00   8.8e+07]
#  [ -1.0e-02  -5.2e+05  -8.6e-04   5.5e-02   1.1e-02  -2.1e-01   3.3e+06]
#  [  5.4e-01   5.3e+07   2.0e-02  -9.0e+00  -2.1e-01   3.2e+01  -3.3e+08]
#  [ -6.5e+06  -8.2e+14  -3.1e+05   8.8e+07   3.3e+06  -3.3e+08   5.2e+15]]
# 20
# 1.65221198749 4.23159079046
# FWHM = 5.439, interval [12.44, 17.87]
#
# ../data/profiles/good-3-allback/prf_06_green.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 16.1168415585
# green fit (xs,x0,Cu,Cd frozen): xs = 17.62, x0 = 18.12, Cu =  1.45, Cd = -10.98, wu = 0.5993, wd = 7.488, Au = 13.64
# green fit (xs,x0,Cu,Cd thawed): xs = 17.28, x0 =  17.9, Cu = 1.424, Cd = -0.08286, wu = 0.7227, wd = 3.741, Au = 15.83
# Errors: [  3.81e-02   1.12e+06   5.33e-02   1.40e+00   3.32e-02   3.53e-01
#    2.44e+07]
# Reduced chi-squared: 4.69587254038
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.5e-03   1.1e+04   2.5e-04  -1.4e-02  -9.2e-04   4.4e-03  -2.4e+05]
#  [  1.1e+04   1.3e+12  -5.6e+02  -1.7e+05  -6.4e+03   5.3e+04  -2.7e+13]
#  [  2.5e-04  -5.6e+02   2.8e-03   7.4e-05  -4.9e-04  -2.4e-05   1.2e+04]
#  [ -1.4e-02  -1.7e+05   7.4e-05   2.0e+00   8.5e-04  -4.8e-01   3.6e+06]
#  [ -9.2e-04  -6.4e+03  -4.9e-04   8.5e-04   1.1e-03  -2.7e-04   1.4e+05]
#  [  4.4e-03   5.3e+04  -2.4e-05  -4.8e-01  -2.7e-04   1.2e-01  -1.1e+06]
#  [ -2.4e+05  -2.7e+13   1.2e+04   3.6e+06   1.4e+05  -1.1e+06   6.0e+14]]
# 20
# 5.5006483442 38.2993662878
# FWHM = 3.114, interval [ 14.7, 17.81]
#
# ../data/profiles/good-3-allback/prf_06_blue.dat
# Left-of-peak smoothed minimum at: 10.073025974
# Global smoothed maximum at: 16.1168415585
# blue fit (xs,x0,Cu,Cd frozen): xs = 17.62, x0 = 18.12, Cu = 0.4654, Cd = -1.471, wu = 0.6328, wd = 4.292, Au = 6.974
# blue fit (xs,x0,Cu,Cd thawed): xs = 17.19, x0 = 17.96, Cu = 0.4499, Cd = 0.7405, wu = 0.7963, wd = 2.479, Au = 7.016
# Errors: [  5.50e-02   1.96e+06   3.06e-02   4.23e-01   4.90e-02   2.15e-01
#    1.73e+07]
# Reduced chi-squared: 2.42224580943
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  3.0e-03   1.7e+04   2.4e-04  -4.8e-03  -2.0e-03   3.5e-03  -1.5e+05]
#  [  1.7e+04   3.8e+12   5.9e+02  -1.7e+05  -2.8e+03   9.7e+04  -3.4e+13]
#  [  2.4e-04   5.9e+02   9.4e-04  -2.6e-05  -4.3e-04   1.5e-05  -5.2e+03]
#  [ -4.8e-03  -1.7e+05  -2.6e-05   1.8e-01   1.2e-04  -8.4e-02   1.5e+06]
#  [ -2.0e-03  -2.8e+03  -4.3e-04   1.2e-04   2.4e-03  -7.2e-05   2.5e+04]
#  [  3.5e-03   9.7e+04   1.5e-05  -8.4e-02  -7.2e-05   4.6e-02  -8.6e+05]
#  [ -1.5e+05  -3.4e+13  -5.2e+03   1.5e+06   2.5e+04  -8.6e+05   3.0e+14]]
# 20
# 1.77823785751 19.036297052
# FWHM = 2.392, interval [15.37, 17.76]
# ../data/profiles/good-3-allback/prf_07_red.dat
# Left-of-peak smoothed minimum at: 5.99784629527
# Global smoothed maximum at: 15.9942567874
# red fit (xs,x0,Cu,Cd frozen): xs = 17.49, x0 = 17.99, Cu = 0.2911, Cd = 1.774, wu =   0.5, wd =   2.5, Au = 1.137
# red fit (xs,x0,Cu,Cd thawed): xs = 17.49, x0 = 17.99, Cu = 0.2911, Cd = 1.774, wu =   0.5, wd =   2.5, Au = 1.137
#
# Errors: [ inf  inf  inf  inf  inf  inf  inf]
# Reduced chi-squared: inf
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]
#  [ inf  inf  inf  inf  inf  inf  inf]]
# 12
# 1.78988967091 3.38154413623
# Cannot calculate FWHM, peak insufficiently resolved
#
# ../data/profiles/good-3-allback/prf_07_green.dat
# Left-of-peak smoothed minimum at: 5.49802577066
# Global smoothed maximum at: 16.494077312
# green fit (xs,x0,Cu,Cd frozen): xs = 17.99, x0 = 18.49, Cu = 1.108, Cd = 6.733, wu = 1.372, wd = 5.829, Au = 17.73
# green fit (xs,x0,Cu,Cd thawed): xs = 18.99, x0 = 18.78, Cu = 1.226, Cd = -1.468, wu = 0.8145, wd = 13.71, Au = 30.54
# Errors: [  4.06e-02   7.04e+05   5.37e-02   4.70e+00   3.74e-02   4.08e+00
#    2.64e+07]
# Reduced chi-squared: 1.76031425043
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.6e-03   4.4e+03   1.5e-04  -7.9e-02  -7.0e-04   7.6e-02  -1.7e+05]
#  [  4.4e+03   5.0e+11   7.8e+02   1.8e+05  -8.3e+02  -1.3e+05  -1.9e+13]
#  [  1.5e-04   7.8e+02   2.9e-03   2.8e-04  -6.2e-04  -2.1e-04  -2.9e+04]
#  [ -7.9e-02   1.8e+05   2.8e-04   2.2e+01  -3.0e-04  -1.9e+01  -6.7e+06]
#  [ -7.0e-04  -8.3e+02  -6.2e-04  -3.0e-04   1.4e-03   2.2e-04   3.1e+04]
#  [  7.6e-02  -1.3e+05  -2.1e-04  -1.9e+01   2.2e-04   1.7e+01   5.0e+06]
#  [ -1.7e+05  -1.9e+13  -2.9e+04  -6.7e+06   3.1e+04   5.0e+06   7.0e+14]]
# 11
# 8.41392594215 24.9608609324
# FWHM = 9.372, interval [10.22,  19.6]
#
# ../data/profiles/good-3-allback/prf_07_blue.dat
# Left-of-peak smoothed minimum at: 4.99820524606
# Global smoothed maximum at: 16.9938978366
# blue fit (xs,x0,Cu,Cd frozen): xs = 18.49, x0 = 18.99, Cu = 0.3524, Cd = 2.231, wu = 1.343, wd = 7.009, Au = 7.767
# blue fit (xs,x0,Cu,Cd thawed): xs = 18.97, x0 = 19.14, Cu = 0.375, Cd = 0.7093, wu = 1.076, wd = 10.44, Au =   9.2
# Errors: [  7.32e-02   1.25e+06   3.15e-02   1.61e+00   6.24e-02   3.19e+00
#    1.07e+07]
# Reduced chi-squared: 1.48522417476
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  5.4e-03   2.5e+03   1.8e-04  -5.0e-02  -2.2e-03   1.1e-01  -2.1e+04]
#  [  2.5e+03   1.6e+12   1.8e+02   1.1e+05   4.6e+03  -1.9e+05  -1.3e+13]
#  [  1.8e-04   1.8e+02   9.9e-04   1.3e-05  -6.3e-04  -2.2e-05  -1.6e+03]
#  [ -5.0e-02   1.1e+05   1.3e-05   2.6e+00   3.4e-04  -5.1e+00  -9.6e+05]
#  [ -2.2e-03   4.6e+03  -6.3e-04   3.4e-04   3.9e-03  -5.6e-04  -4.0e+04]
#  [  1.1e-01  -1.9e+05  -2.2e-05  -5.1e+00  -5.6e-04   1.0e+01   1.6e+06]
#  [ -2.1e+04  -1.3e+13  -1.6e+03  -9.6e+05  -4.0e+04   1.6e+06   1.1e+14]]
# 10
# 3.45511742541 11.1715017973
# FWHM = 8.755, interval [   11, 19.75]
# ../data/profiles/good-3-allback/prf_08_red.dat
# Left-of-peak smoothed minimum at: 4.55828286501
# Global smoothed maximum at: 8.10361398224
# red fit (xs,x0,Cu,Cd frozen): xs = 9.604, x0 =  10.1, Cu = 0.3284, Cd = 2.535, wu = 1.303, wd = 0.6049, Au = 3.188
# red fit (xs,x0,Cu,Cd thawed): xs = 9.608, x0 =  10.1, Cu = 0.3284, Cd = 2.534, wu = 1.302, wd = 0.612, Au = 3.209
#
# Errors: [ 0.23   nan  0.02  0.03  0.1   0.4    nan]
# Reduced chi-squared: 1.29222678607
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  5.2e-02   1.0e+06   2.9e-04   8.4e-04  -1.7e-03   7.9e-02  -2.6e+06]
#  [  1.0e+06  -8.9e+13  -1.6e+04  -1.3e+06  -9.7e+04   2.2e+06   2.2e+14]
#  [  2.9e-04  -1.6e+04   4.7e-04  -2.4e-04  -8.0e-04   4.0e-04   4.0e+04]
#  [  8.4e-04  -1.3e+06  -2.4e-04   7.0e-04  -1.5e-03  -6.3e-03   3.3e+06]
#  [ -1.7e-03  -9.7e+04  -8.0e-04  -1.5e-03   1.0e-02   2.4e-03   2.4e+05]
#  [  7.9e-02   2.2e+06   4.0e-04  -6.3e-03   2.4e-03   1.6e-01  -5.4e+06]
#  [ -2.6e+06   2.2e+14   4.0e+04   3.3e+06   2.4e+05  -5.4e+06  -5.4e+14]]
# 9
# 2.53475862188 4.9921282824
# Cannot calculate FWHM, peak insufficiently resolved
#
# ../data/profiles/good-3-allback/prf_08_green.dat
# Left-of-peak smoothed minimum at: 4.05180699112
# Global smoothed maximum at: 8.61008985613
# green fit (xs,x0,Cu,Cd frozen): xs = 10.11, x0 = 10.61, Cu =  1.34, Cd = 17.28, wu = 1.055, wd = 1.249, Au = 25.35
# green fit (xs,x0,Cu,Cd thawed): xs = 10.05, x0 = 10.66, Cu = 1.338, Cd = 17.53, wu = 1.064, wd = 1.097, Au = 24.02
#
# Errors: [ 0.04   nan  0.04  0.45  0.03  0.14   nan]
# Reduced chi-squared: 2.67924470317
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.7e-03  -8.2e+03   7.9e-05  -7.5e-03  -3.0e-04   4.2e-03   1.9e+05]
#  [ -8.2e+03  -2.2e+12   1.3e+03  -7.7e+03   1.3e+03  -8.8e+03   4.9e+13]
#  [  7.9e-05   1.3e+03   1.9e-03   4.5e-06  -3.4e-04   5.2e-06  -2.9e+04]
#  [ -7.5e-03  -7.7e+03   4.5e-06   2.0e-01   4.7e-06  -4.5e-02   1.7e+05]
#  [ -3.0e-04   1.3e+03  -3.4e-04   4.7e-06   7.1e-04   5.4e-06  -3.0e+04]
#  [  4.2e-03  -8.8e+03   5.2e-06  -4.5e-02   5.4e-06   1.9e-02   2.0e+05]
#  [  1.9e+05   4.9e+13  -2.9e+04   1.7e+05  -3.0e+04   2.0e+05  -1.1e+15]]
# 8
# 17.6408232894 43.7956770448
# FWHM =  2.74, interval [8.081, 10.82]
#
# ../data/profiles/good-3-allback/prf_08_blue.dat
# Left-of-peak smoothed minimum at: 3.54533111723
# Global smoothed maximum at: 9.11656573002
# blue fit (xs,x0,Cu,Cd frozen): xs = 10.62, x0 = 11.12, Cu = 0.4228, Cd = 5.705, wu = 0.8501, wd = 2.212, Au =  9.99
# blue fit (xs,x0,Cu,Cd thawed): xs = 10.41, x0 = 11.16, Cu = 0.4186, Cd = 6.307, wu = 0.9007, wd = 1.535, Au = 8.871
#
# Errors: [ 0.04   nan  0.02  0.31  0.04  0.18   nan]
# Reduced chi-squared: 1.27340288257
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.4e-03  -5.6e+04   1.1e-04  -5.8e-03  -8.6e-04   4.7e-03   5.5e+05]
#  [ -5.6e+04  -5.4e+12   2.2e+03  -1.4e+05  -1.5e+03   2.4e+04   5.4e+13]
#  [  1.1e-04   2.2e+03   5.7e-04   5.7e-05  -2.4e-04  -9.7e-06  -2.2e+04]
#  [ -5.8e-03  -1.4e+05   5.7e-05   9.4e-02  -3.9e-05  -4.5e-02   1.4e+06]
#  [ -8.6e-04  -1.5e+03  -2.4e-04  -3.9e-05   1.4e-03   6.6e-06   1.5e+04]
#  [  4.7e-03   2.4e+04  -9.7e-06  -4.5e-02   6.6e-06   3.4e-02  -2.4e+05]
#  [  5.5e+05   5.4e+13  -2.2e+04   1.4e+06   1.5e+04  -2.4e+05  -5.3e+14]]
# 7
# 6.4723166853 20.8084038028
# FWHM = 2.583, interval [8.474, 11.06]
# ../data/profiles/good-3-allback/prf_09_red.dat
# Left-of-peak smoothed minimum at: 8.58618379588
# Global smoothed maximum at: 16.6672979567
# red fit (xs,x0,Cu,Cd frozen): xs = 18.17, x0 = 18.67, Cu = 0.3511, Cd = 1.641, wu = 1.164, wd = 4.252, Au = 3.007
# red fit (xs,x0,Cu,Cd thawed): xs = 18.54, x0 = 18.68, Cu = 0.3587, Cd = 1.315, wu = 0.9326, wd = 5.787, Au = 3.852
#
# Errors: [  9.86e-02   3.49e+06   1.96e-02   6.66e-01   8.69e-02   2.52e+00
#    1.44e+07]
# Reduced chi-squared: 0.763362405445
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  9.7e-03   9.3e+04   1.5e-04  -2.9e-02  -4.6e-03   1.3e-01  -3.8e+05]
#  [  9.3e+04   1.2e+13  -1.9e+01  -7.3e+05  -9.5e+03   2.7e+06  -5.0e+13]
#  [  1.5e-04  -1.9e+01   3.9e-04   1.1e-06  -4.9e-04  -4.2e-06   7.9e+01]
#  [ -2.9e-02  -7.3e+05   1.1e-06   4.4e-01   5.7e-04  -1.6e+00   3.0e+06]
#  [ -4.6e-03  -9.5e+03  -4.9e-04   5.7e-04   7.6e-03  -2.1e-03   3.9e+04]
#  [  1.3e-01   2.7e+06  -4.2e-06  -1.6e+00  -2.1e-03   6.3e+00  -1.1e+07]
#  [ -3.8e+05  -5.0e+13   7.9e+01   3.0e+06   3.9e+04  -1.1e+07   2.1e+14]]
# 17
# 1.94744907628 4.84733974968
# FWHM =  7.43, interval [11.83, 19.26]
#
# ../data/profiles/good-3-allback/prf_09_green.dat
# Left-of-peak smoothed minimum at: 9.09125343094
# Global smoothed maximum at: 17.1723675918
# green fit (xs,x0,Cu,Cd frozen): xs = 18.67, x0 = 19.17, Cu = 1.303, Cd = 3.265, wu = 0.8483, wd = 5.278, Au = 24.25
# green fit (xs,x0,Cu,Cd thawed): xs = 18.59, x0 = 19.05, Cu = 1.298, Cd = 5.078, wu = 0.8717, wd = 4.574, Au = 26.74
#
# Errors: [  2.62e-02   6.98e+05   3.79e-02   1.20e+00   2.09e-02   3.71e-01
#    2.14e+07]
# Reduced chi-squared: 2.55285651007
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  6.9e-04   5.2e+03   6.5e-05  -1.4e-02  -2.5e-04   5.1e-03  -1.6e+05]
#  [  5.2e+03   4.9e+11   1.4e+02  -1.1e+05  -2.6e+02   3.1e+04  -1.5e+13]
#  [  6.5e-05   1.4e+02   1.4e-03  -3.0e-05  -2.1e-04   8.9e-06  -4.3e+03]
#  [ -1.4e-02  -1.1e+05  -3.0e-05   1.4e+00   5.7e-05  -4.3e-01   3.3e+06]
#  [ -2.5e-04  -2.6e+02  -2.1e-04   5.7e-05   4.4e-04  -1.7e-05   8.1e+03]
#  [  5.1e-03   3.1e+04   8.9e-06  -4.3e-01  -1.7e-05   1.4e-01  -9.6e+05]
#  [ -1.6e+05  -1.5e+13  -4.3e+03   3.3e+06   8.1e+03  -9.6e+05   4.6e+14]]
# 18
# 10.2778511734 46.604493904
# FWHM = 4.397, interval [14.83, 19.22]
#
# ../data/profiles/good-3-allback/prf_09_blue.dat
# Left-of-peak smoothed minimum at: 9.09125343094
# Global smoothed maximum at: 17.1723675918
# blue fit (xs,x0,Cu,Cd frozen): xs = 18.67, x0 = 19.17, Cu = 0.4806, Cd = 0.8358, wu = 0.8685, wd = 4.714, Au = 11.52
# blue fit (xs,x0,Cu,Cd thawed): xs = 18.56, x0 = 19.18, Cu = 0.4782, Cd = 1.747, wu = 0.901, wd = 3.961, Au = 10.84
#
# Errors: [ 0.03   nan  0.02  0.57  0.03  0.36   nan]
# Reduced chi-squared: 1.87462495552
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.0e-03  -3.4e+04   6.7e-05  -6.4e-03  -5.6e-04   5.7e-03   4.1e+05]
#  [ -3.4e+04  -3.7e+12   5.8e+02   2.0e+05  -1.4e+03  -1.0e+05   4.5e+13]
#  [  6.7e-05   5.8e+02   5.4e-04  -3.2e-05  -1.9e-04   1.6e-05  -7.0e+03]
#  [ -6.4e-03   2.0e+05  -3.2e-05   3.2e-01   7.7e-05  -1.9e-01  -2.4e+06]
#  [ -5.6e-04  -1.4e+03  -1.9e-04   7.7e-05   9.1e-04  -3.9e-05   1.7e+04]
#  [  5.7e-03  -1.0e+05   1.6e-05  -1.9e-01  -3.9e-05   1.3e-01   1.2e+06]
#  [  4.1e+05   4.5e+13  -7.0e+03  -2.4e+06   1.7e+04   1.2e+06  -5.4e+14]]
# 18
# 3.6071969379 22.0475160063
# FWHM = 3.747, interval [15.46,  19.2]
# ../data/profiles/good-3-allback/prf_10_red.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.1464933802
# red fit (xs,x0,Cu,Cd frozen): xs = 17.65, x0 = 18.15, Cu = 0.3492, Cd = 2.098, wu = 0.9152, wd = 2.619, Au =   2.9
# red fit (xs,x0,Cu,Cd thawed): xs = 18.33, x0 = 18.59, Cu = 0.3644, Cd = 1.623, wu = 0.483, wd =   4.3, Au = 2.855
#
# Errors: [ 0.12   nan  0.03  0.98  0.1   2.55   nan]
# Reduced chi-squared: 0.728059327462
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.4e-02  -3.9e+04   3.9e-04  -2.0e-02  -9.7e-03   6.7e-02   2.3e+05]
#  [ -3.9e+04  -7.3e+12   5.8e+03   5.9e+05   4.0e+04  -1.3e+06   4.3e+13]
#  [  3.9e-04   5.8e+03   6.3e-04  -4.7e-04  -5.9e-04   1.0e-03  -3.4e+04]
#  [ -2.0e-02   5.9e+05  -4.7e-04   9.5e-01  -3.2e-03  -2.4e+00  -3.5e+06]
#  [ -9.7e-03   4.0e+04  -5.9e-04  -3.2e-03   1.0e-02   7.0e-03  -2.3e+05]
#  [  6.7e-02  -1.3e+06   1.0e-03  -2.4e+00   7.0e-03   6.5e+00   7.7e+06]
#  [  2.3e+05   4.3e+13  -3.4e+04  -3.5e+06  -2.3e+05   7.7e+06  -2.5e+14]]
# 22
# 2.30896185419 5.30535173752
# FWHM = 5.853, interval [12.85,  18.7]
# ../data/profiles/good-3-allback/prf_10_green.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.6510712984
# green fit (xs,x0,Cu,Cd frozen): xs = 18.15, x0 = 18.65, Cu = 1.362, Cd = 10.71, wu = 0.6883, wd = 3.486, Au = 21.46
# green fit (xs,x0,Cu,Cd thawed): xs = 18.04, x0 = 18.64, Cu = 1.357, Cd = 13.36, wu = 0.7137, wd = 2.583, Au = 20.84
# Errors: [  3.01e-02   1.74e+06   5.06e-02   1.25e+00   2.44e-02   3.18e-01
#    5.08e+07]
# Reduced chi-squared: 1.14781320713
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  9.1e-04   1.8e+03   9.9e-05  -1.6e-02  -3.3e-04   5.2e-03  -5.1e+04]
#  [  1.8e+03   3.0e+12   1.2e+03   8.8e+04  -7.7e+03  -8.8e+04  -8.8e+13]
#  [  9.9e-05   1.2e+03   2.6e-03   3.4e-05  -3.1e-04  -3.4e-05  -3.5e+04]
#  [ -1.6e-02   8.8e+04   3.4e-05   1.6e+00  -2.2e-04  -3.7e-01  -2.6e+06]
#  [ -3.3e-04  -7.7e+03  -3.1e-04  -2.2e-04   5.9e-04   2.2e-04   2.2e+05]
#  [  5.2e-03  -8.8e+04  -3.4e-05  -3.7e-01   2.2e-04   1.0e-01   2.6e+06]
#  [ -5.1e+04  -8.8e+13  -3.5e+04  -2.6e+06   2.2e+05   2.6e+06   2.6e+15]]
# 22
# 15.8127651166 49.3814200476
# FWHM = 3.503, interval [15.06, 18.56]
#
# ../data/profiles/good-3-allback/prf_10_blue.dat
# Left-of-peak smoothed minimum at: 11.1007141989
# Global smoothed maximum at: 16.6510712984
# blue fit (xs,x0,Cu,Cd frozen): xs = 18.15, x0 = 18.65, Cu = 0.4304, Cd = 1.502, wu = 0.7537, wd = 3.947, Au =  10.5
# blue fit (xs,x0,Cu,Cd thawed): xs = 17.96, x0 =  18.7, Cu = 0.4264, Cd = 3.733, wu = 0.8031, wd = 2.552, Au = 9.097
# Errors: [  4.68e-02   1.23e+06   2.88e-02   7.48e-01   3.78e-02   3.48e-01
#    1.40e+07]
# Reduced chi-squared: 1.00986517812
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.2e-03  -1.1e+04   1.0e-04  -1.3e-02  -9.7e-04   8.2e-03   1.2e+05]
#  [ -1.1e+04   1.5e+12   7.5e+01   5.6e+04   8.2e+03  -2.1e+04  -1.7e+13]
#  [  1.0e-04   7.5e+01   8.3e-04   2.8e-06  -2.6e-04  -1.0e-06  -8.5e+02]
#  [ -1.3e-02   5.6e+04   2.8e-06   5.6e-01   3.0e-04  -2.4e-01  -6.3e+05]
#  [ -9.7e-04   8.2e+03  -2.6e-04   3.0e-04   1.4e-03  -1.1e-04  -9.3e+04]
#  [  8.2e-03  -2.1e+04  -1.0e-06  -2.4e-01  -1.1e-04   1.2e-01   2.4e+05]
#  [  1.2e+05  -1.7e+13  -8.5e+02  -6.3e+05  -9.3e+04   2.4e+05   1.9e+14]]
# 22
# 5.06729363351 23.3587415096
# FWHM = 2.879, interval [15.65, 18.53]
# ../data/profiles/good-3-allback/prf_11_red.dat
# Left-of-peak smoothed minimum at: 4.02101327178
# Global smoothed maximum at: 9.04727986151
# red fit (xs,x0,Cu,Cd frozen): xs = 10.55, x0 = 11.05, Cu = 0.3325, Cd = -24.59, wu = 0.7226, wd = 53.57, Au = 1.941
# red fit (xs,x0,Cu,Cd thawed): xs = 10.07, x0 = 10.91, Cu = 0.3282, Cd = 0.1804, wu = 0.8893, wd = 3.446, Au =   1.9
# Errors: [ 0.13   nan  0.02  0.71  0.13  1.17   nan]
# Reduced chi-squared: 0.673822659351
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.8e-02  -2.7e+04   4.4e-04  -2.2e-02  -1.3e-02   4.5e-02   5.7e+04]
#  [ -2.7e+04  -7.6e+12  -2.7e+03   1.3e+04  -1.3e+04   4.8e+04   1.6e+13]
#  [  4.4e-04  -2.7e+03   5.6e-04   4.6e-06  -8.7e-04   1.7e-05   5.8e+03]
#  [ -2.2e-02   1.3e+04   4.6e-06   5.1e-01   2.3e-05  -8.1e-01  -2.8e+04]
#  [ -1.3e-02  -1.3e+04  -8.7e-04   2.3e-05   1.6e-02   8.4e-05   2.9e+04]
#  [  4.5e-02   4.8e+04   1.7e-05  -8.1e-01   8.4e-05   1.4e+00  -1.0e+05]
#  [  5.7e+04   1.6e+13   5.8e+03  -2.8e+04   2.9e+04  -1.0e+05  -3.5e+13]]
# 8
# 1.04458782883 5.18164736503
# FWHM = 3.194, interval [7.556, 10.75]
#
# ../data/profiles/good-3-allback/prf_11_green.dat
# Left-of-peak smoothed minimum at: 4.52363993076
# Global smoothed maximum at: 9.04727986151
# green fit (xs,x0,Cu,Cd frozen): xs = 10.55, x0 = 11.05, Cu = 1.445, Cd = -12.51, wu = 0.6476, wd = 5.672, Au = 20.27
# green fit (xs,x0,Cu,Cd thawed): xs = 10.36, x0 = 11.03, Cu = 1.436, Cd = 0.2448, wu = 0.6947, wd = 3.118, Au = 18.95
# Errors: [  2.79e-02   7.13e+05   4.94e-02   2.04e+00   2.36e-02   3.28e-01
#    1.94e+07]
# Reduced chi-squared: 2.21136688529
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  7.8e-04   3.8e+03   1.3e-04  -2.3e-02  -3.6e-04   4.4e-03  -1.0e+05]
#  [  3.8e+03   5.1e+11   1.5e+03  -7.1e+04  -1.1e+03   9.6e+03  -1.4e+13]
#  [  1.3e-04   1.5e+03   2.4e-03  -2.1e-04  -3.1e-04   2.9e-05  -4.1e+04]
#  [ -2.3e-02  -7.1e+04  -2.1e-04   4.2e+00   1.5e-04  -6.5e-01   1.9e+06]
#  [ -3.6e-04  -1.1e+03  -3.1e-04   1.5e-04   5.6e-04  -2.0e-05   2.9e+04]
#  [  4.4e-03   9.6e+03   2.9e-05  -6.5e-01  -2.0e-05   1.1e-01  -2.6e+05]
#  [ -1.0e+05  -1.4e+13  -4.1e+04   1.9e+06   2.9e+04  -2.6e+05   3.8e+14]]
# 9
# 8.10464947091 51.350728154
# FWHM = 2.678, interval [8.184, 10.86]
#
# ../data/profiles/good-3-allback/prf_11_blue.dat
# Left-of-peak smoothed minimum at: 4.52363993076
# Global smoothed maximum at: 9.54990652049
# blue fit (xs,x0,Cu,Cd frozen): xs = 11.05, x0 = 11.55, Cu = 0.5315, Cd = -65.09, wu = 0.4465, wd = 30.09, Au = 5.712
# blue fit (xs,x0,Cu,Cd thawed): xs = 10.75, x0 = 11.51, Cu = 0.5226, Cd = -5.282, wu = 0.5531, wd = 4.797, Au = 5.398
# Errors: [ 0.04   nan  0.03  2.37  0.04  0.83   nan]
# Reduced chi-squared: 1.56153590512
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  2.0e-03  -4.3e+03   1.3e-04  -2.6e-02  -1.2e-03   1.0e-02   4.2e+04]
#  [ -4.3e+03  -6.7e+11  -1.1e+03   3.5e+05   1.4e+03  -1.5e+05   6.5e+12]
#  [  1.3e-04  -1.1e+03   8.5e-04   5.7e-04  -2.3e-04  -2.4e-04   1.1e+04]
#  [ -2.6e-02   3.5e+05   5.7e-04   5.6e+00  -7.5e-04  -1.9e+00  -3.4e+06]
#  [ -1.2e-03   1.4e+03  -2.3e-04  -7.5e-04   1.4e-03   3.2e-04  -1.4e+04]
#  [  1.0e-02  -1.5e+05  -2.4e-04  -1.9e+00   3.2e-04   6.9e-01   1.5e+06]
#  [  4.2e+04   6.5e+12   1.1e+04  -3.4e+06  -1.4e+04   1.5e+06  -6.4e+13]]
# 9
# 2.14839240508 21.930181149
# FWHM = 2.871, interval [8.276, 11.15]
# ../data/profiles/good-3-allback/prf_12_red.dat
# Left-of-peak smoothed minimum at: 6.01026000126
# Global smoothed maximum at: 12.0205200025
# red fit (xs,x0,Cu,Cd frozen): xs = 13.52, x0 = 14.02, Cu = 0.3886, Cd = 0.1447, wu = 0.696, wd = 6.558, Au = 2.244
# red fit (xs,x0,Cu,Cd thawed): xs = 13.02, x0 = 13.96, Cu = 0.384, Cd = 1.672, wu = 0.8513, wd = 2.147, Au = 1.985
#
# Errors: [ 0.13   nan  0.03  0.32  0.13  0.56   nan]
# Reduced chi-squared: 0.747635458032
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.8e-02  -7.9e+04   6.6e-04  -8.1e-03  -1.3e-02   2.2e-02   1.9e+05]
#  [ -7.9e+04  -6.2e+12   3.2e+02  -7.1e+04   4.7e+04   1.5e+05   1.5e+13]
#  [  6.6e-04   3.2e+02   1.0e-03   3.7e-06  -1.3e-03  -7.8e-06  -7.6e+02]
#  [ -8.1e-03  -7.1e+04   3.7e-06   1.0e-01   5.4e-04  -1.6e-01   1.7e+05]
#  [ -1.3e-02   4.7e+04  -1.3e-03   5.4e-04   1.7e-02  -1.1e-03  -1.1e+05]
#  [  2.2e-02   1.5e+05  -7.8e-06  -1.6e-01  -1.1e-03   3.1e-01  -3.5e+05]
#  [  1.9e+05   1.5e+13  -7.6e+02   1.7e+05  -1.1e+05  -3.5e+05  -3.4e+13]]
# 12
# 1.85144486144 6.3668803882
# FWHM = 3.081, interval [10.59, 13.67]
#
# ../data/profiles/good-3-allback/prf_12_green.dat
# Left-of-peak smoothed minimum at: 5.50940500116
# Global smoothed maximum at: 12.0205200025
# green fit (xs,x0,Cu,Cd frozen): xs = 13.52, x0 = 14.02, Cu = 1.503, Cd = 1.348, wu = 0.6002, wd = 4.716, Au = 23.34
# green fit (xs,x0,Cu,Cd thawed): xs =  13.3, x0 = 13.89, Cu = 1.486, Cd = 8.221, wu = 0.6646, wd = 2.929, Au = 25.65
# Errors: [ 0.03   nan  0.06  1.21  0.02  0.23   nan]
# Reduced chi-squared: 1.4973090602
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  7.6e-04   9.9e+03   1.5e-04  -1.4e-02  -3.9e-04   3.4e-03  -3.8e+05]
#  [  9.9e+03  -1.3e+12   2.3e+03   4.0e+05  -6.0e+03  -7.5e+04   5.1e+13]
#  [  1.5e-04   2.3e+03   3.9e-03  -7.1e-04  -3.7e-04   1.3e-04  -9.0e+04]
#  [ -1.4e-02   4.0e+05  -7.1e-04   1.5e+00   1.8e-03  -2.5e-01  -1.6e+07]
#  [ -3.9e-04  -6.0e+03  -3.7e-04   1.8e-03   5.9e-04  -3.4e-04   2.3e+05]
#  [  3.4e-03  -7.5e+04   1.3e-04  -2.5e-01  -3.4e-04   5.1e-02   2.9e+06]
#  [ -3.8e+05   5.1e+13  -9.0e+04  -1.6e+07   2.3e+05   2.9e+06  -2.0e+15]]
# 11
# 12.0922503706 63.5287648679
# FWHM = 2.979, interval [ 10.8, 13.78]
#
# ../data/profiles/good-3-allback/prf_12_blue.dat
# Left-of-peak smoothed minimum at: 5.50940500116
# Global smoothed maximum at: 12.0205200025
# blue fit (xs,x0,Cu,Cd frozen): xs = 13.52, x0 = 14.02, Cu = 0.5068, Cd = 1.566, wu = 0.6129, wd = 3.399, Au = 13.21
# blue fit (xs,x0,Cu,Cd thawed): xs = 13.29, x0 = 14.02, Cu = 0.5002, Cd =  3.85, wu = 0.6696, wd =  2.23, Au = 11.86
# Errors: [ 0.04   nan  0.04  0.39  0.03  0.06   nan]
# Reduced chi-squared: 0.992693357894
# Covariance matrix, variables: ['xs', 'x0', 'Cu', 'Cd', 'wu', 'wd', 'Au']
# [[  1.3e-03   2.7e+04   7.8e-05  -3.4e-03  -6.4e-04   1.8e-03  -4.7e+05]
#  [  2.7e+04  -1.8e+13   3.1e+04  -1.5e+06  -2.1e+04   7.1e+05   3.2e+14]
#  [  7.8e-05   3.1e+04   1.3e-03   2.6e-03  -2.4e-04  -1.2e-03  -5.5e+05]
#  [ -3.4e-03  -1.5e+06   2.6e-03   1.5e-01  -1.7e-03  -2.3e-02   2.7e+07]
#  [ -6.4e-04  -2.1e+04  -2.4e-04  -1.7e-03   9.3e-04   8.1e-04   3.7e+05]
#  [  1.8e-03   7.1e+05  -1.2e-03  -2.3e-02   8.1e-04   4.2e-03  -1.3e+07]
#  [ -4.7e+05   3.2e+14  -5.5e+05   2.7e+07   3.7e+05  -1.3e+07  -5.7e+15]]
# 11
# 4.8292212743 35.8723482641
# FWHM = 2.305, interval [11.45, 13.76]
